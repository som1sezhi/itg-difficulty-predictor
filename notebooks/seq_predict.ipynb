# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
from torch import nn
from torch.utils.data import DataLoader, Dataset

# %%
# Check if CUDA is available
device = torch.device('cpu')
# if torch.cuda.is_available():
#    device = torch.device('cuda:0')

torch.set_default_device(device)
print(f"Using device = {torch.get_default_device()}")
# Out:
# Using device = cpu

# %%
import json

def nps_seq_to_tensor(seq):
    return torch.tensor(seq, dtype=torch.float32)#.reshape((-1, 1, 1))

class ChartDataset(Dataset):

    def __init__(self, df, convert_to_tensor=False):

        if convert_to_tensor:
            self.data = list(map(
                lambda seq: nps_seq_to_tensor(json.loads(seq)),
                df['Seq']
            ))
            self.meters = list(map(
                lambda m: torch.tensor([[float(m)]], dtype=torch.float32),
                df['Meter']
            ))
        else:
            self.data = list(map(
                # lambda seq: nps_seq_to_tensor(json.loads(seq)),
                lambda seq: np.array(json.loads(seq)),
                df['Seq']
            ))
            self.meters = df['Meter'].to_list()
        
    
    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, i):
        return self.meters[i], self.data[i]

# %%
df = pd.read_csv('seq_dataset.csv')
print(f'loaded {len(df)} items')
# Out:
# loaded 3137 items

# %%
df[df['Meter'] == 43]
# Out:
#                                                 Name  \
# 1676  ECS13 - Speed/[43] [450] Another Lovely Beyond
# 1677       ECS13 - Speed/[43] [440] Jehovah's YaHVeH
# 1678              ECS13 - Speed/[43] [464] Never Die
#
#                                           Hash  Meter  \
# 1676  85a6c1f24afbfb9deb780121c0354c1dae6fa608     43
# 1677  7f741aab0c49424a0b6d3d825de0c41bcf62d014     43
# 1678  2732e936cff5038a7cbfa68431fe55df9c73e57d     43
#
#                                                     Seq
# 1676  [0.15890322222222222, 2.274088888888889, 3.725...
# 1677  [0.46300166528925707, 2.9017867685950414, 3.66...
# 1678  [0.6929048889714626, 1.8785980836801424, 1.944...

# %%
all_data = ChartDataset(df)

# %%
from bokeh.plotting import figure, show, output_notebook
from bokeh.models import HoverTool, ColumnDataSource, LinearColorMapper
from bokeh import palettes

output_notebook()
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="f5be09c3-c004-40c1-9b62-a6a1624af3b0">Loading BokehJS ...</span>
#     </div>

# %%
def ewma_vectorized(data, alpha, offset=None, dtype=None, order='C', out=None):
    """
    Calculates the exponential moving average over a vector.
    Will fail for large inputs.
    :param data: Input data
    :param alpha: scalar float in range (0,1)
        The alpha parameter for the moving average.
    :param offset: optional
        The offset for the moving average, scalar. Defaults to data[0].
    :param dtype: optional
        Data type used for calculations. Defaults to float64 unless
        data.dtype is float32, then it will use float32.
    :param order: {'C', 'F', 'A'}, optional
        Order to use when flattening the data. Defaults to 'C'.
    :param out: ndarray, or None, optional
        A location into which the result is stored. If provided, it must have
        the same shape as the input. If not provided or `None`,
        a freshly-allocated array is returned.
    """
    data = np.array(data, copy=False)

    if dtype is None:
        if data.dtype == np.float32:
            dtype = np.float32
        else:
            dtype = np.float64
    else:
        dtype = np.dtype(dtype)

    if data.ndim > 1:
        # flatten input
        data = data.reshape(-1, order)

    if out is None:
        out = np.empty_like(data, dtype=dtype)
    else:
        assert out.shape == data.shape
        assert out.dtype == dtype

    if data.size < 1:
        # empty input, return empty array
        return out

    if offset is None:
        offset = data[0]

    alpha = np.array(alpha, copy=False).astype(dtype, copy=False)

    # scaling_factors -> 0 as len(data) gets large
    # this leads to divide-by-zeros below
    scaling_factors = np.power(1. - alpha, np.arange(data.size + 1, dtype=dtype),
                               dtype=dtype)
    # create cumulative sum array
    np.multiply(data, (alpha * scaling_factors[-2]) / scaling_factors[:-1],
                dtype=dtype, out=out)
    np.cumsum(out, dtype=dtype, out=out)

    # cumsums / scaling
    out /= scaling_factors[-2::-1]

    if offset != 0:
        offset = np.array(offset, copy=False).astype(dtype, copy=False)
        # add offsets
        out += offset * scaling_factors[1:]

    return out

def ewma_vectorized_2d(data, alpha, axis=None, offset=None, dtype=None, order='C', out=None):
    """
    Calculates the exponential moving average over a given axis.
    :param data: Input data, must be 1D or 2D array.
    :param alpha: scalar float in range (0,1)
        The alpha parameter for the moving average.
    :param axis: The axis to apply the moving average on.
        If axis==None, the data is flattened.
    :param offset: optional
        The offset for the moving average. Must be scalar or a
        vector with one element for each row of data. If set to None,
        defaults to the first value of each row.
    :param dtype: optional
        Data type used for calculations. Defaults to float64 unless
        data.dtype is float32, then it will use float32.
    :param order: {'C', 'F', 'A'}, optional
        Order to use when flattening the data. Ignored if axis is not None.
    :param out: ndarray, or None, optional
        A location into which the result is stored. If provided, it must have
        the same shape as the desired output. If not provided or `None`,
        a freshly-allocated array is returned.
    """
    data = np.array(data, copy=False)

    assert data.ndim <= 2

    if dtype is None:
        if data.dtype == np.float32:
            dtype = np.float32
        else:
            dtype = np.float64
    else:
        dtype = np.dtype(dtype)

    if out is None:
        out = np.empty_like(data, dtype=dtype)
    else:
        assert out.shape == data.shape
        assert out.dtype == dtype

    if data.size < 1:
        # empty input, return empty array
        return out

    if axis is None or data.ndim < 2:
        # use 1D version
        if isinstance(offset, np.ndarray):
            offset = offset[0]
        return ewma_vectorized(data, alpha, offset, dtype=dtype, order=order,
                               out=out)

    assert -data.ndim <= axis < data.ndim

    # create reshaped data views
    out_view = out
    if axis < 0:
        axis = data.ndim - int(axis)

    if axis == 0:
        # transpose data views so columns are treated as rows
        data = data.T
        out_view = out_view.T

    if offset is None:
        # use the first element of each row as the offset
        offset = np.copy(data[:, 0])
    elif np.size(offset) == 1:
        offset = np.reshape(offset, (1,))

    alpha = np.array(alpha, copy=False).astype(dtype, copy=False)

    # calculate the moving average
    row_size = data.shape[1]
    row_n = data.shape[0]
    scaling_factors = np.power(1. - alpha, np.arange(row_size + 1, dtype=dtype),
                               dtype=dtype)
    # create a scaled cumulative sum array
    np.multiply(
        data,
        np.multiply(alpha * scaling_factors[-2], np.ones((row_n, 1), dtype=dtype),
                    dtype=dtype)
        / scaling_factors[np.newaxis, :-1],
        dtype=dtype, out=out_view
    )
    np.cumsum(out_view, axis=1, dtype=dtype, out=out_view)
    out_view /= scaling_factors[np.newaxis, -2::-1]

    if not (np.size(offset) == 1 and offset == 0):
        offset = offset.astype(dtype, copy=False)
        # add the offsets to the scaled cumulative sums
        out_view += offset[:, np.newaxis] * scaling_factors[np.newaxis, 1:]

    return out

# https://stackoverflow.com/a/52998713
def ewma_vectorized_safe(data, alpha, row_size=None, dtype=None, order='C', out=None):
    """
    Reshapes data before calculating EWMA, then iterates once over the rows
    to calculate the offset without precision issues
    :param data: Input data, will be flattened.
    :param alpha: scalar float in range (0,1)
        The alpha parameter for the moving average.
    :param row_size: int, optional
        The row size to use in the computation. High row sizes need higher precision,
        low values will impact performance. The optimal value depends on the
        platform and the alpha being used. Higher alpha values require lower
        row size. Default depends on dtype.
    :param dtype: optional
        Data type used for calculations. Defaults to float64 unless
        data.dtype is float32, then it will use float32.
    :param order: {'C', 'F', 'A'}, optional
        Order to use when flattening the data. Defaults to 'C'.
    :param out: ndarray, or None, optional
        A location into which the result is stored. If provided, it must have
        the same shape as the desired output. If not provided or `None`,
        a freshly-allocated array is returned.
    :return: The flattened result.
    """
    data = np.array(data, copy=False)

    if dtype is None:
        if data.dtype == np.float32:
            dtype = np.float32
        else:
            dtype = float
    else:
        dtype = np.dtype(dtype)

    row_size = int(row_size) if row_size is not None \
               else get_max_row_size(alpha, dtype)

    if data.size <= row_size:
        # The normal function can handle this input, use that
        return ewma_vectorized(data, alpha, dtype=dtype, order=order, out=out)

    if data.ndim > 1:
        # flatten input
        data = np.reshape(data, -1, order=order)

    if out is None:
        out = np.empty_like(data, dtype=dtype)
    else:
        assert out.shape == data.shape
        assert out.dtype == dtype

    row_n = int(data.size // row_size)  # the number of rows to use
    trailing_n = int(data.size % row_size)  # the amount of data leftover
    first_offset = data[0]

    if trailing_n > 0:
        # set temporary results to slice view of out parameter
        out_main_view = np.reshape(out[:-trailing_n], (row_n, row_size))
        data_main_view = np.reshape(data[:-trailing_n], (row_n, row_size))
    else:
        out_main_view = out
        data_main_view = data

    # get all the scaled cumulative sums with 0 offset
    ewma_vectorized_2d(data_main_view, alpha, axis=1, offset=0, dtype=dtype,
                       order='C', out=out_main_view)

    scaling_factors = (1 - alpha) ** np.arange(1, row_size + 1)
    last_scaling_factor = scaling_factors[-1]

    # create offset array
    offsets = np.empty(out_main_view.shape[0], dtype=dtype)
    offsets[0] = first_offset
    # iteratively calculate offset for each row
    for i in range(1, out_main_view.shape[0]):
        offsets[i] = offsets[i - 1] * last_scaling_factor + out_main_view[i - 1, -1]

    # add the offsets to the result
    out_main_view += offsets[:, np.newaxis] * scaling_factors[np.newaxis, :]

    if trailing_n > 0:
        # process trailing data in the 2nd slice of the out parameter
        ewma_vectorized(data[-trailing_n:], alpha, offset=out_main_view[-1, -1],
                        dtype=dtype, order='C', out=out[-trailing_n:])
    return out

def get_max_row_size(alpha, dtype=float):
    assert 0. <= alpha < 1.
    # This will return the maximum row size possible on 
    # your platform for the given dtype. I can find no impact on accuracy
    # at this value on my machine.
    # Might not be the optimal value for speed, which is hard to predict
    # due to numpy's optimizations
    # Use np.finfo(dtype).eps if you  are worried about accuracy
    # and want to be extra safe.
    epsilon = np.finfo(dtype).tiny
    # If this produces an OverflowError, make epsilon larger
    return int(np.log(epsilon)/np.log(1-alpha)) + 1

# %% [markdown]
# ## Notes for myself
#
# [Link to article](https://sportsmedicine-open.springeropen.com/articles/10.1186/s40798-019-0230-z)
#
# $$
# P = CP + \frac{W^\prime}{t_\mathrm{Lim}}
# $$
#
# - $P$: power able to be sustained for a period of time before exhaustion
# - $CP$: power that can be sustained indefinitely via aerobic processes
# - $W^\prime$: anaerobic energy reserve
# - $t_\mathrm{Lim}$: time at which power $P$ can be sustained before exhaustion

# %%
from sklearn.linear_model import LogisticRegression, LinearRegression

class ConstructedLogistic:
    def __init__(self, coef, threshold):
        self.coef = coef
        self.intercept = threshold*coef
    
    def predict_proba(self, X):
        probs = 1 / (1 + np.exp(-(X*self.coef - self.intercept)))
        return np.hstack([1-probs, probs])

class Predictor:
    def __init__(self, max_diff, params):
        self.max_diff = max_diff
        self.params = params
        self.regs: list[LogisticRegression] = []
        self.extrap_reg_coef = 0
        self.extrap_threshold_reg = None

    def fit(self, X_train, y_train):
        self.regs.clear()
        for m in range(1, self.max_diff):
            reg = LogisticRegression(random_state=1)
            reg.fit(X_train, y_train > m)
            self.regs.append(reg)
        # extrapolation information
        idxs = list(range(24, 35))
        coefs = np.asarray([self.regs[i].coef_[0][0] for i in idxs])
        thresholds = np.asarray([-self.regs[i].intercept_[0] for i in idxs]) / coefs
        self.extrap_reg_coef = coefs.mean()
        self.extrap_threshold_reg = LinearRegression().fit(np.asarray(idxs).reshape(-1, 1), thresholds)
    
    def _get_extrapolated_logistic(self, meter):
        return ConstructedLogistic(self.extrap_reg_coef, self.extrap_threshold_reg.predict([[meter]])[0])

    def _X_to_approx_extrap_meter(self, X):
        return (X - self.extrap_threshold_reg.intercept_) / self.extrap_threshold_reg.coef_
    
    def predict_proba(self, X, extrapolate=False):
        class_probas = [] # list of (N,)
        if extrapolate:
            regs = self.regs[:35]
            max_approx_meter = np.max(self._X_to_approx_extrap_meter(X)).astype(int)
            regs.extend([self._get_extrapolated_logistic(m) for m in range(35, max_approx_meter + 5)])
        else:
            regs = self.regs
        for reg in regs:
            class_probas.append(reg.predict_proba(X)[:,1])
        
        probas = [1 - class_probas[0]]
        for i in range(len(class_probas) - 1):
            p1, p2 = class_probas[i], class_probas[i+1]
            probas.append(p1 - p2)
        probas.append(class_probas[-1])
        return np.stack(probas, -1)
    
    def predict_weighted_avg(self, X, extrapolate=False):
        probas = self.predict_proba(X, extrapolate)
        return np.sum((probas * np.arange(1, probas.shape[-1] + 1)), -1)

    def predict_likeliest(self, X, extrapolate=False):
        probas = self.predict_proba(X, extrapolate)
        return probas.argmax(1) + 1

    def mae(self, X, y):
        pred_avg = self.predict_weighted_avg(X)
        return np.abs(y - pred_avg).mean()
    
    def mse(self, X, y):
        pred_avg = self.predict_weighted_avg(X)
        return ((y - pred_avg) ** 2).mean()
    
    def acc(self, X, y):
        pred_choice = self.predict_likeliest(X)
        return (y == pred_choice).mean()

    def to_score(self, seq):
        return predict_one(seq, *self.params)

# %%
print(predictor.extrap_reg_coef)
print(predictor.extrap_threshold_reg.coef_[0])
print(predictor.extrap_threshold_reg.intercept_)
# Out:
# 3.967698804884678
# 0.8007727638808104
# 5.430623689762928

# %%
df
# Out:
#                                                    Name  \
# 0                 Stamina RPG 6/[11] [128] Alcohol-Free
# 1                       Stamina RPG 6/[11] [136] Cowboy
# 2         Stamina RPG 6/[11] [136] Flutterwonder (Hard)
# 3                   Stamina RPG 6/[11] [124] Glory Days
# 4     Stamina RPG 6/[11] [145] Hawaiian Roller Coast...
# ...                                                 ...
# 3132                        _misc/140BPM Stamina Killer
# 3133            _misc/[Marathon] Life Starts At 200 BPM
# 3134                          _misc/[2017] Pure Madness
# 3135            _misc/[2017] XS Project Collection Full
# 3136                   _misc/[M] Pendulum Essential Mix
#
#                                           Hash  Meter  \
# 0     0b020e29c3919c10c1d3fb2776e813b18af30114     11
# 1     f2bc769bdf7addfc64d7e46643e194f184820a56     11
# 2     fc05556c0b501fabafe79a16923e910518d5d03d     11
# 3     c0b5988bae418d86ccac7c7209f605932857bb81     11
# 4     d0b51e7437f6705f45bf6d9c1254964330bfcc4e     11
# ...                                        ...    ...
# 3132  b9c0db86a2e1346db5967b712aeb1ff876154c28     21
# 3133  c2dcb36e047968bc2ece44ae23503e5b3b1e9bb9     23
# 3134  99c6d44a2f7c78ef43116759c30013aaf04cee5a     24
# 3135  74c5e5a6f705318b47b969ef158a3b448faa04ee     21
# 3136  4a511adbc68bca8fef9bc2806cdec4de896402df     20
#
#                                                     Seq
# 0     [4.050000000000307e-05, 1.7252810859375018, 7....
# 1     [0.3188346366782005, 4.846108878892734, 7.9326...
# 2     [0.044209385813148656, 0.7089341695501729, 0.5...
# 3     [0.19957966077003164, 2.5900707221644113, 4.11...
# 4     [0.5023429762187873, 5.083400186682522, 6.9295...
# ...                                                 ...
# 3132  [0.7937520714285716, 6.686947795918368, 9.3222...
# 3133  [0.04500000000000001, 0.7949999999999999, 2.02...
# 3134  [3.199999999999295e-05, 2.049368531249995, 8.3...
# 3135  [0.21470472866087098, 1.529906647380748, 1.443...
# 3136  [0.5369263676038811, 4.290434046169049, 5.7901...
#
# [3137 rows x 4 columns]

# %%
df[df['Name'].str.contains(r'\[29\] \[291\]')].index[0]
# Out:
# 2355

# %%
import math

def get_exhaust(density, cp, recovery_fac, curve_fac, overall_fac):
    exhaust = 0
    #overall_exhaust = 0
    exhaust_arr = []
    for d in density:
        exhaust_arr.append(exhaust)
        if d <= cp:
            exhaust *= recovery_fac + (1-recovery_fac)*d/cp
            #exhaust *= recovery_fac * (1 - (1-recovery_fac)*0.57*d/cp)
            #exhaust *= recovery_fac
        else:
            exhaust += math.exp(-exhaust / curve_fac) * (d-cp)
            #exhaust += math.exp(-exhaust) * (d-cp) * curve_fac
            #exhaust += 1/(exhaust+1) * (d-cp) * curve_fac
            #exhaust += (d-cp) * curve_fac
        #overall_exhaust += d * overall_fac
        #overall_exhaust += 1/(overall_exhaust+1) * d * overall_fac
    overall_exhaust = overall_fac * np.log(np.cumsum(density) + 1)
    return (np.array(exhaust_arr) + overall_exhaust)*0.01

def do_plots(ax, density):
    x = np.arange(0, len(density))
    # density
    ax[0].plot(x, density, lw=0.5)
    # exhaust
    exh = get_exhaust(density, 7.390e+00, 9.99e-01, 10.999e+00, 1.075e-2)
    ax[1].plot(x, exh, lw=0.5)
    # diff points over time
    p = np.log(np.cumsum((np.power(3.034e+00, density*(1 + exh))-1))+1)
    ax[2].plot(np.log(x+1), p, lw=0.5)

idx1 = df[df['Name'].str.contains(r'\[29\] \[291\]')].index[0]
idx2 = df[df['Name'].str.contains(r'Arc Stream Works')].index[0]
d1 = all_data[idx1][1]
d2 = all_data[idx2][1]

# 6, 0.92, 0.05
fig, ax = plt.subplots(3)
do_plots(ax, d1)
do_plots(ax, d2)
plt.show()

# %%
from statsmodels.miscmodels.ordinal_model import OrderedModel

def predict_one(data, a, cp, recovery_fac, curve_fac, overall_fac):
    #print(data)
    # tired = ewma_vectorized_safe(data, 2/(span+1))
    exhaust = 1 + get_exhaust(data, cp, recovery_fac, curve_fac, overall_fac)
    score = np.log(((np.power(a, data*exhaust) - 1)).sum() + 1)
    #score = np.log((np.power(a, data*exhaust) - 1).sum() + 1)
    #score = np.log(np.power(data, 2).sum())
    return score


def predict(a, cp, recovery_fac, curve_fac, overall_fac, dataset=all_data):
    meters = dataset.meters
    scores = []
    for data in dataset.data:
        score = predict_one(data, a, cp, recovery_fac, curve_fac, overall_fac)
        scores.append(score)
    x = np.array(scores).reshape((-1, 1))
    y = np.array(meters)
    return x, y

# x, y = predict(2.28744856, 41.85642433)
#x, y = predict(2.28744856, 6, 0.92, 0.05)

#x, y = predict(2.443e+00,  1.613e+01,  9.166e-01,  1.862e-02)
#x, y = predict(3.42119342, 7.37242798, 0.94126975, 0.15030075, 0)
# 0.6720312118995367 0.4174418007280254
# balanced: 0.5562058034625701 0.549607495849428

#params = [3.529e+00,  6.816e+00,  9.433e-01,  2.669e+00,  2.286e-04]
# 0.6659351377712753 0.42104402417689946

# with 1/x exhaust, linear overall exhaust
#params = [3.034e+00,  5.070e+00,  8.871e-01,  2.995e+00,  1.524e-05]

# with trimmed down data
#params = [3.034e+00, 5.661e+00, 8.329e-01, 2.890e+00, 6.859e-04]
# 0.6662416321326108 0.41417643537840865 0.28652988696439685
# with mse
#params = [3.034e+00, 5.209e+00, 8.332e-01, 2.951e+00, 6.859e-04]
# 0.665604080331527 0.4156943674421414 0.28719529008438466

# with moving exhaust mult into the exponent
params = [3.034e+00, 7.390e+00, 9.444e-01, 4, 1.075e-03]
# 0.649346509403889 0.4253711221630721 0.28925628386094165
# expand bounds for curve_fac
params = [3.356e+00, 9.446e+00, 9.725e-01, 5.560e+00, 1.760e-03]
# 0.6318138348740835 0.4442055718067327 0.3183737000875278

# changed how logarithmic growth works? i dont remember
params = [2.387e+00, 7.309e+00, 9.702e-01, 4.660e+00, 4.047e-03]
# 0.7095951546063117 0.3803224565289485 0.24545786923064408

# fixed exhaust
params = [2.347e+00, 7.481e+00, 8.597e-01, 4.352e+00, 6.859e-05]
# 0.7000318775900541 0.3895510421406892 0.2551061169020688
x, y = predict(*params)

# %%
x, y
# Out:
# (array([[12.37360105],
#         [12.63532054],
#         [12.46328982],
#         ...,
#         [23.06191229],
#         [19.36008744],
#         [20.74200458]]),
#  array([11, 11, 11, ..., 24, 21, 20]))

# %%
rates = predictor.predict_weighted_avg(x, extrapolate=True)

# %%
idx = df[df['Name'].str.contains(r'XS Project')].index[0]
print(idx, x[idx][0], rates[idx])
ys = all_data[idx][1]
xs = np.arange(len(ys))
print(len(ys))
plt.plot(xs, ys)
plt.show()
# Out:
# 3135 19.67224711267022 18.006930260470824
# 25129

# %%
predictor = Predictor(43, params)
predictor.fit(x, y)
ps = predictor.predict_proba(x)
pred_avg = np.sum((ps * np.arange(1, 44)), -1)
print(predictor.acc(x, y), predictor.mae(x, y), predictor.mse(x, y))
print(y)
# Out:
# 0.7000318775900541 0.3895510421406892 0.2551061169020688
# [11 11 11 ... 24 21 20]

# %%
print([[reg.coef_[0][0], reg.intercept_[0]] for reg in predictor.regs])
# Out:
# [[3.0021976724730197, -15.887243773515838], [3.139795596807306, -17.978060383808433], [2.9168325249878815, -19.18849464439009], [3.1867092283802583, -22.52660341510839], [3.1245415132591265, -23.293082368317098], [3.3542951457773102, -26.813603221300298], [3.1687496381195492, -27.296271930671573], [3.4090110819240373, -32.18142066956098], [3.4136768042013563, -35.30556284597489], [3.0985216915606606, -35.381026398722334], [3.6778755279817226, -47.02861579862745], [3.8951938585154635, -55.66922850876312], [4.546151754239344, -69.93492451450177], [4.506641192336295, -73.27924208035904], [4.493253725335278, -76.9532881257546], [4.702262932088255, -84.36645751893069], [5.833666134063467, -109.80855464565315], [6.048235046348649, -118.6054535867811], [5.40569811834366, -109.37063182921443], [5.210393191605142, -108.65208424464093], [5.677480104182051, -121.53841112244204], [4.761494766072956, -104.71452257809307], [4.574478799789876, -103.38222923975502], [4.548466885079563, -105.71153113202244], [4.9453485943109206, -118.59227596290634], [3.969130632136659, -98.1989371791469], [3.9494421382597746, -101.0528623534964], [4.2065178613514655, -111.21413072995337], [4.141834877771352, -112.35935366678069], [3.830650058429967, -107.07652451137847], [3.604766025266547, -103.45228563872001], [4.035709109755321, -118.7571138534855], [3.71994962552464, -112.30402016467593], [3.759578668689995, -116.03841670209036], [3.9741529881438926, -126.52313537481496], [3.7310577385000108, -122.37161467255487], [3.2731694705662333, -109.66282225118444], [3.1348728634345866, -107.43024555741636], [2.8092848635803804, -97.74045040528728], [2.5877198728282313, -91.96824600394088], [2.3755189392450595, -85.9377967630192], [1.8364277589440203, -68.1884245817962]]

# %%
from bokeh.models.tickers import BasicTicker
def bokeh_display(X, y, names_df=None, predictor=None, palette=palettes.Turbo256*2):

    disp_df = pd.DataFrame(index=names_df.index)
    disp_df['y'] = y
    disp_df['x'] = X
    disp_df = disp_df.merge(names_df[['Name', 'Meter']], left_index=True, right_index=True)

    datasource = ColumnDataSource(disp_df)
    color_mapping = LinearColorMapper(
        palette=palette
    )

    plot_figure = figure(
        width=500,
        height=500,
        tools=('pan, wheel_zoom, reset')
    )

    hvr = HoverTool(tooltips="""
    <div>
        <div>
            <span style='font-size: 12px; color: #224499'>[@x]</span>
            <span style='font-size: 12px; color: #994422'>[@y]</span>
            <span style='font-size: 12px'>@Name</span>
        </div>
    </div>
    """)
    plot_figure.add_tools(hvr)

    scatter = plot_figure.scatter(
        'x',
        'y',
        source=datasource,
        color=dict(field='Meter', transform=color_mapping),
        #color='black',
        line_alpha=0,
        fill_alpha=0.1,
        size=8
    )
    hvr.renderers = [scatter]
    
    if predictor:
        xs = np.arange(0, 45, 0.1)
        ys = predictor.predict_weighted_avg(xs.reshape(-1, 1), True)
        
        plot_figure.line(x=ys, y=xs, color='#f008')
        plot_figure.line(x=np.round(ys), y=xs, color='#0008')
    plot_figure.ygrid.ticker = BasicTicker(min_interval=1, max_interval=1)
    show(plot_figure)

# %%
bokeh_display(y, x.reshape((-1,)), df, predictor=predictor)
# Out:
#   <div id="a73e56af-853d-4974-9202-28a36045b45e" data-root-id="p1137" style="display: contents;"></div>

# %%
import matplotlib.ticker as pltticker

box_df = pd.DataFrame({'Score': x.reshape((-1,)), 'Meter': df['Meter']})
labels = list(range(1, 44))
box_data = []
for i in labels:
    box_data.append(box_df[box_df['Meter'] == i]['Score'])
fig, ax = plt.subplots()
fig.set_size_inches(10, 10)


xs = np.arange(5, 39, 0.02)
ys = predictor.predict_weighted_avg(xs.reshape(-1, 1))

#ax.plot(ys, xs, color='#f008')

ax.boxplot(box_data, patch_artist=True, widths=0.75, boxprops=dict(linewidth=0, facecolor='black'), whiskerprops=dict(linewidth=0.5), flierprops=dict(markersize=1))
# vs = ax.violinplot(box_data)
# for pc in vs['bodies']:
#     pc.set_color('red')
# vs['cbars'].set_linewidth(0.5)
ax.plot(np.round(ys), xs, color='blue', linewidth=0.5)
ticks = np.arange(5, 44, 5)
plt.xticks(ticks, ticks)
ax.grid(True)
plt.show()

# %%
xs = np.arange(0, 40, 0.1).reshape(-1, 1)
for reg in predictor.regs:
    res = reg.predict_proba(xs)[:,1]
    plt.plot(xs, res)
#ys = predictor.predict_weighted_avg(xs.reshape(-1, 1))

plt.show()

# %%
idxs = list(range(25, 42))
coefs = np.asarray([predictor.regs[i].coef_[0][0] for i in idxs])
intercepts = np.asarray([predictor.regs[i].intercept_[0] for i in idxs])
#coefs, intercepts
plt.plot(idxs, intercepts/coefs)
plt.show()

# %%
print([r.intercept_ for r in predictor.regs])
dir(predictor.regs[2])
# Out:
# [array([-28.5187554]), array([-27.7942981]), array([-23.41877928]), array([-22.30373903]), array([-24.4339308]), array([-23.92707757]), array([-20.65319651]), array([-18.33054903]), array([-24.53128771]), array([-37.8485838]), array([-43.68767743]), array([-64.44408746]), array([-80.40411704]), array([-82.39889377]), array([-90.3695584]), array([-99.91593422]), array([-129.21249378]), array([-135.75991641]), array([-123.55788618]), array([-125.89190948]), array([-141.68497957]), array([-118.90293241]), array([-120.25853515]), array([-119.74812503]), array([-128.83170019]), array([-110.43537161]), array([-111.45605563]), array([-121.6582268]), array([-116.21148361]), array([-111.43930035]), array([-105.91851472]), array([-121.20225133]), array([-109.77569155]), array([-115.6616418]), array([-132.77413384]), array([-123.39536456]), array([-121.30616211]), array([-114.33303117]), array([-108.32807672]), array([-79.26577998]), array([-88.09672278]), array([-63.07567339])]
# ['C',
#  '__annotations__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__sklearn_clone__',
#  '__sklearn_tags__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_build_request_for_signature',
#  '_doc_link_module',
#  '_doc_link_template',
#  '_doc_link_url_param_generator',
#  '_estimator_type',
#  '_get_default_requests',
#  '_get_doc_link',
#  '_get_metadata_request',
#  '_get_param_names',
#  '_get_params_html',
#  '_html_repr',
#  '_parameter_constraints',
#  '_predict_proba_lr',
#  '_repr_html_',
#  '_repr_html_inner',
#  '_repr_mimebundle_',
#  '_validate_params',
#  'class_weight',
#  'classes_',
#  'coef_',
#  'decision_function',
#  'densify',
#  'dual',
#  'fit',
#  'fit_intercept',
#  'get_metadata_routing',
#  'get_params',
#  'intercept_',
#  'intercept_scaling',
#  'l1_ratio',
#  'max_iter',
#  'multi_class',
#  'n_features_in_',
#  'n_iter_',
#  'n_jobs',
#  'penalty',
#  'predict',
#  'predict_log_proba',
#  'predict_proba',
#  'random_state',
#  'score',
#  'set_fit_request',
#  'set_params',
#  'set_score_request',
#  'solver',
#  'sparsify',
#  'tol',
#  'verbose',
#  'warm_start']

# %%
mod_log = OrderedModel(y, x, distr='logit')
res_log = mod_log.fit(method='bgfs', disp=False)
res_log.summary()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5288\178453538.py in ?()
#       1 mod_log = OrderedModel(y, x, distr='logit')
# ----> 2 res_log = mod_log.fit(method='powell', disp=False)
#       3 res_log.summary()
#
# c:\Users\Lenovo\Documents\code_projs\itg-difficulty-predictor\.venv\Lib\site-packages\statsmodels\miscmodels\ordinal_model.py in ?(self, start_params, method, maxiter, full_output, disp, callback, retall, **kwargs)
#     584     def fit(self, start_params=None, method='nm', maxiter=500, full_output=1,
#     585             disp=1, callback=None, retall=0, **kwargs):
#     586
#     587         fit_method = super().fit
# --> 588         mlefit = fit_method(start_params=start_params,
#     589                             method=method, maxiter=maxiter,
#     590                             full_output=full_output,
#     591                             disp=disp, callback=callback, **kwargs)
#
# c:\Users\Lenovo\Documents\code_projs\itg-difficulty-predictor\.venv\Lib\site-packages\statsmodels\base\model.py in ?(self, start_params, method, maxiter, full_output, disp, callback, retall, **kwargs)
#    1011             # this will add default cov_type name and description
#    1012             kwargs["cov_type"] = 'nonrobust'
#    1013
#    1014         fit_method = super().fit
# -> 1015         mlefit = fit_method(start_params=start_params,
#    1016                             method=method, maxiter=maxiter,
#    1017                             full_output=full_output,
#    1018                             disp=disp, callback=callback, **kwargs)
#
# c:\Users\Lenovo\Documents\code_projs\itg-difficulty-predictor\.venv\Lib\site-packages\statsmodels\base\model.py in ?(self, start_params, method, maxiter, full_output, disp, fargs, callback, retall, skip_hessian, **kwargs)
#     562             kwds['use_t'] = kwargs['use_t']
#     563             del kwargs["use_t"]
#     564
#     565         optimizer = Optimizer()
# --> 566         xopt, retvals, optim_settings = optimizer._fit(f, score, start_params,
#     567                                                        fargs, kwargs,
#     568                                                        hessian=hess,
#     569                                                        method=method,
#
# c:\Users\Lenovo\Documents\code_projs\itg-difficulty-predictor\.venv\Lib\site-packages\statsmodels\base\optimizer.py in ?(self, objective, gradient, start_params, fargs, kwargs, hessian, method, maxiter, full_output, disp, callback, retall)
#     241         if extra_fit_funcs:
#     242             fit_funcs.update(extra_fit_funcs)
#     243
#     244         func = fit_funcs[method]
# --> 245         xopt, retvals = func(objective, gradient, start_params, fargs, kwargs,
#     246                              disp=disp, maxiter=maxiter, callback=callback,
#     247                              retall=retall, full_output=full_output,
#     248                              hess=hessian)
#
# c:\Users\Lenovo\Documents\code_projs\itg-difficulty-predictor\.venv\Lib\site-packages\statsmodels\base\optimizer.py in ?(f, score, start_params, fargs, kwargs, disp, maxiter, callback, retall, full_output, hess)
#     966     xtol = kwargs.setdefault('xtol', 0.0001)
#     967     ftol = kwargs.setdefault('ftol', 0.0001)
#     968     maxfun = kwargs.setdefault('maxfun', None)
#     969     start_direc = kwargs.setdefault('start_direc', None)
# --> 970     retvals = optimize.fmin_powell(f, start_params, args=fargs, xtol=xtol,
#     971                                    ftol=ftol, maxiter=maxiter, maxfun=maxfun,
#     972                                    full_output=full_output, disp=disp,
#     973                                    retall=retall, callback=callback,
#
# c:\Users\Lenovo\Documents\code_projs\itg-difficulty-predictor\.venv\Lib\site-packages\scipy\optimize\_optimize.py in ?(func, x0, args, xtol, ftol, maxiter, maxfun, full_output, disp, retall, callback, direc)
#    3394             'direc': direc,
#    3395             'return_all': retall}
#    3396
#    3397     callback = _wrap_callback(callback)
# -> 3398     res = _minimize_powell(func, x0, args, callback=callback, **opts)
#    3399
#    3400     if full_output:
#    3401         retlist = (res['x'], res['fun'], res['direc'], res['nit'],
#
# c:\Users\Lenovo\Documents\code_projs\itg-difficulty-predictor\.venv\Lib\site-packages\scipy\optimize\_optimize.py in ?(func, x0, args, callback, bounds, xtol, ftol, maxiter, maxfev, disp, direc, return_all, **unknown_options)
#    3616                     )
#    3617                     if np.any(direc1):
#    3618                         direc[bigind] = direc[-1]
#    3619                         direc[-1] = direc1
# -> 3620         except _MaxFuncCallError:
#    3621             break
#    3622
#    3623     warnflag = 0
#
# c:\Users\Lenovo\Documents\code_projs\itg-difficulty-predictor\.venv\Lib\site-packages\scipy\optimize\_optimize.py in ?(func, p, xi, tol, lower_bound, upper_bound, fval)
#    3239     if not np.any(xi):
#    3240         return ((fval, p, xi) if fval is not None else (func(p), p, xi))
#    3241     elif lower_bound is None and upper_bound is None:
#    3242         # non-bounded minimization
# -> 3243         res = _recover_from_bracket_error(_minimize_scalar_brent,
#    3244                                           myfunc, None, tuple(), xtol=tol)
#    3245         alpha_min, fret = res.x, res.fun
#    3246         xi = alpha_min * xi
#
# c:\Users\Lenovo\Documents\code_projs\itg-difficulty-predictor\.venv\Lib\site-packages\scipy\optimize\_optimize.py in ?(solver, fun, bracket, args, **options)
#    3133     # storing the information needed by `minimize_scalar` in the error object,
#    3134     # and intercepting it here.
#    3135     try:
#    3136         res = solver(fun, bracket, args, **options)
# -> 3137     except BracketError as e:
#    3138         msg = str(e)
#    3139         xa, xb, xc, fa, fb, fc, funcalls = e.data
#    3140         xs, fs = [xa, xb, xc], [fa, fb, fc]
#
# c:\Users\Lenovo\Documents\code_projs\itg-difficulty-predictor\.venv\Lib\site-packages\scipy\optimize\_optimize.py in ?(func, brack, args, xtol, maxiter, disp, **unknown_options)
#    2731
#    2732     brent = Brent(func=func, args=args, tol=tol,
#    2733                   full_output=True, maxiter=maxiter, disp=disp)
#    2734     brent.set_bracket(brack)
# -> 2735     brent.optimize()
#    2736     x, fval, nit, nfev = brent.get_result(full_output=True)
#    2737
#    2738     success = nit < maxiter and not (np.isnan(x) or np.isnan(fval))
#
# c:\Users\Lenovo\Documents\code_projs\itg-difficulty-predictor\.venv\Lib\site-packages\scipy\optimize\_optimize.py in ?(self)
#    2568                 else:
#    2569                     u = x - tol1
#    2570             else:
#    2571                 u = x + rat
# -> 2572             fu = func(*((u,) + self.args))      # calculate new output value
#    2573             funcalls += 1
#    2574
#    2575             if (fu > fx):                 # if it's bigger than current
#
# c:\Users\Lenovo\Documents\code_projs\itg-difficulty-predictor\.venv\Lib\site-packages\scipy\optimize\_optimize.py in ?(alpha)
#    3235     def myfunc(alpha):
# -> 3236         return func(p + alpha*xi)
#
# c:\Users\Lenovo\Documents\code_projs\itg-difficulty-predictor\.venv\Lib\site-packages\scipy\optimize\_optimize.py in ?(x, *wrapper_args)
#     556         if ncalls[0] >= maxfun:
#     557             raise _MaxFuncCallError("Too many function calls")
#     558         ncalls[0] += 1
#     559         # A copy of x is sent to the user function (gh13740)
# --> 560         fx = function(np.copy(x), *(wrapper_args + args))
#     561         # Ideally, we'd like to a have a true scalar returned from f(x). For
#     562         # backwards-compatibility, also allow np.array([1.3]),
#     563         # np.array([[1.3]]) etc.
#
# c:\Users\Lenovo\Documents\code_projs\itg-difficulty-predictor\.venv\Lib\site-packages\statsmodels\base\model.py in ?(params, *args)
#     533         def f(params, *args):
# --> 534             return -self.loglike(params, *args) / nobs
#
# c:\Users\Lenovo\Documents\code_projs\itg-difficulty-predictor\.venv\Lib\site-packages\statsmodels\miscmodels\ordinal_model.py in ?(self, params)
#     512     @Appender(GenericLikelihoodModel.loglike.__doc__)
#     513     def loglike(self, params):
#     514
# --> 515         return self.loglikeobs(params).sum()
#
# c:\Users\Lenovo\Documents\code_projs\itg-difficulty-predictor\.venv\Lib\site-packages\statsmodels\miscmodels\ordinal_model.py in ?(self, params)
#     529             The log likelihood for each observation of the model evaluated
#     530             at ``params``.
#     531         """
#     532         low, upp = self._bounds(params)
# --> 533         prob = self.prob(low, upp)
#     534         return np.log(prob + 1e-20)
#
# c:\Users\Lenovo\Documents\code_projs\itg-difficulty-predictor\.venv\Lib\site-packages\statsmodels\miscmodels\ordinal_model.py in ?(self, low, upp)
#     323         float or ndarray
#     324             Probability that value falls in interval (low, upp]
#     325
#     326         """
# --> 327         return np.maximum(self.cdf(upp) - self.cdf(low), 0)
#
# c:\Users\Lenovo\Documents\code_projs\itg-difficulty-predictor\.venv\Lib\site-packages\statsmodels\miscmodels\ordinal_model.py in ?(self, x)
#     285         -------
#     286         Value of the cumulative distribution function of the underlying latent
#     287         variable evaluated at x.
#     288         """
# --> 289         return self.distr.cdf(x)
#
# c:\Users\Lenovo\Documents\code_projs\itg-difficulty-predictor\.venv\Lib\site-packages\scipy\stats\_distn_infrastructure.py in ?(self, x, *args, **kwds)
#    2154         place(output, (1-cond0)+np.isnan(x), self.badvalue)
#    2155         place(output, cond2, 1.0)
#    2156         if np.any(cond):  # call only if at least 1 entry
#    2157             goodargs = argsreduce(cond, *((x,)+args))
# -> 2158             place(output, cond, self._cdf(*goodargs))
#    2159         if output.ndim == 0:
#    2160             return output[()]
#    2161         return output
#
# c:\Users\Lenovo\Documents\code_projs\itg-difficulty-predictor\.venv\Lib\site-packages\scipy\stats\_continuous_distns.py in ?(self, x)
#    6496     def _cdf(self, x):
# -> 6497         return sc.expit(x)
#
# KeyboardInterrupt:

# %%
preds = res_log.model.predict(res_log.params, exog=x)

# %%
pred_choice = preds.argmax(1) + 1
print((y == pred_choice).mean())
pred_avg = np.sum((preds * np.arange(1, 44)), -1)
print(np.abs(y - pred_avg).mean())
# Out:
# 0.6408193123628383
# 0.4529980444391331

# %%
from scipy.optimize import minimize, basinhopping, direct, shgo

def get_acc(a):
    x, y = predict(a[0], a[1], a[2], a[3], a[4])
    #mod_log = OrderedModel(y, x, distr='logit')
    #res_log = mod_log.fit(method='bfgs', disp=False)
    #preds = res_log.model.predict(res_log.params, exog=x)
    #pred_choice = preds.argmax(1) + 1
    #acc = (y == pred_choice).mean()
    p = Predictor(43, a)
    p.fit(x, y)
    acc = p.mae(x, y)
    print('call:', a, acc)
    return acc

#res = minimize(get_acc, [1.5, 60], bounds=[(1, 4), (20, 100)])
#res = basinhopping(get_acc, [2, 60])
# call: [ 2.33193333 40.96718446] 0.4532350091963813

res2 = direct(get_acc, bounds=[(1.1, 4), (1, 15), (0.8, 1), (1, 10), (0, 0.1)], vol_tol=1e-17, maxfun=10000)
#res = shgo(get_acc, bounds=[(1.1, 4), (1, 20), (0.5, 1), (0, 3), (0, 0.1)])
# res = basinhopping(get_acc, [2.28744856, 6, 0.92, 0.05])


# res = [get_acc((2.2, span)) for span in np.arange(10, 60, 5)]
# call: (2.2, 10) 0.6100414330977334
# call: (2.2, 15) 0.6212527418961735
# call: (2.2, 20) 0.628808189129905
# call: (2.2, 25) 0.6353887399463807
# call: (2.2, 30) 0.6390446015110894
# call: (2.2, 35) 0.6392883256154034
# call: (2.2, 40) 0.6405069461369729
# call: (2.2, 45) 0.6409943943456008
# call: (2.2, 50) 0.6400194979283451
# call: (2.2, 55) 0.6395320497197173
# Out:
# call: [2.55 8.   0.9  5.5  0.05] 0.39840646360748927
# call: [3.51666667 8.         0.9        5.5        0.05      ] 0.4524246109163469
# call: [1.58333333 8.         0.9        5.5        0.05      ] 0.7407121468032984
# call: [ 2.55       12.66666667  0.9         5.5         0.05      ] 0.4429076067338839
# call: [2.55       3.33333333 0.9        5.5        0.05      ] 0.43897341633636616
# call: [2.55       8.         0.96666667 5.5        0.05      ] 0.4025652358500611
# call: [2.55       8.         0.83333333 5.5        0.05      ] 0.40183414794931993
# call: [2.55 8.   0.9  8.5  0.05] 0.429818323012491
# call: [2.55 8.   0.9  2.5  0.05] 0.4255946985454041
# call: [2.55       8.         0.9        5.5        0.08333333] 0.3983323062382882
# call: [2.55       8.         0.9        5.5        0.01666667] 0.3983876263016289
# call: [3.51666667 8.         0.9        5.5        0.08333333] 0.4519665082208825
# call: [1.58333333 8.         0.9        5.5        0.08333333] 0.7402631985879329
# call: [ 2.55       12.66666667  0.9         5.5         0.08333333] 0.44276356937564537
# call: [2.55       3.33333333 0.9        5.5        0.08333333] 0.43902811346809995
# call: [2.55       8.         0.96666667 5.5        0.08333333] 0.4026333476536747
# call: [2.55       8.         0.83333333 5.5        0.08333333] 0.4017493612215898
# call: [2.55       8.         0.9        8.5        0.08333333] 0.4297620161579302
# call: [2.55       8.         0.9        2.5        0.08333333] 0.42508044220667307
# call: [3.51666667 8.         0.9        5.5        0.01666667] 0.4528730066683786
# call: [1.58333333 8.         0.9        5.5        0.01666667] 0.7413713986873005
# call: [ 2.55       12.66666667  0.9         5.5         0.01666667] 0.4431834862171407
# call: [2.55       3.33333333 0.9        5.5        0.01666667] 0.4388523515880896
# call: [2.55       8.         0.96666667 5.5        0.01666667] 0.4025888406070448
# call: [2.55       8.         0.83333333 5.5        0.01666667] 0.40201118517764783
# call: [2.55       8.         0.9        8.5        0.01666667] 0.4298876282833412
# call: [2.55       8.         0.9        2.5        0.01666667] 0.4255453035614171
# call: [3.51666667 8.         0.83333333 5.5        0.08333333] 0.4568739804865358
# call: [1.58333333 8.         0.83333333 5.5        0.08333333] 0.7379307850295891
# call: [ 2.55       12.66666667  0.83333333  5.5         0.08333333] 0.44942332043043903
# call: [2.55       3.33333333 0.83333333 5.5        0.08333333] 0.43968596487459033
# call: [2.55       8.         0.83333333 8.5        0.08333333] 0.4375683574473514
# call: [2.55       8.         0.83333333 2.5        0.08333333] 0.42546116717600047
# call: [2.87222222 8.         0.9        5.5        0.08333333] 0.4135938840730393
# call: [2.22777778 8.         0.9        5.5        0.08333333] 0.40145343582702603
# call: [2.55       9.55555556 0.9        5.5        0.08333333] 0.41400763057697115
# call: [2.55       6.44444444 0.9        5.5        0.08333333] 0.39956558085473015
# call: [2.55       8.         0.92222222 5.5        0.08333333] 0.3978936787931336
# call: [2.55       8.         0.87777778 5.5        0.08333333] 0.39941285668475557
# call: [2.55       8.         0.9        6.5        0.08333333] 0.40506889871476004
# call: [2.55       8.         0.9        4.5        0.08333333] 0.39776964280976806
# call: [2.55       8.         0.9        5.5        0.09444444] 0.3983493383403851
# call: [2.55       8.         0.9        5.5        0.07222222] 0.39836626393932356
# call: [3.51666667 8.         0.83333333 5.5        0.05      ] 0.45719821485842355
# call: [1.58333333 8.         0.83333333 5.5        0.05      ] 0.7383621263653226
# call: [ 2.55       12.66666667  0.83333333  5.5         0.05      ] 0.4495075164767064
# call: [2.55       3.33333333 0.83333333 5.5        0.05      ] 0.43964086933938373
# call: [2.55       8.         0.83333333 8.5        0.05      ] 0.4375913810934215
# call: [2.55       8.         0.83333333 2.5        0.05      ] 0.4257297679972395
# call: [2.87222222 8.         0.9        4.5        0.08333333] 0.4179728008157852
# call: [2.22777778 8.         0.9        4.5        0.08333333] 0.3960449359221254
# call: [2.55       9.55555556 0.9        4.5        0.08333333] 0.41218145917632054
# call: [2.55       6.44444444 0.9        4.5        0.08333333] 0.39883971252404776
# call: [2.55       8.         0.92222222 4.5        0.08333333] 0.39802711031175664
# call: [2.55       8.         0.87777778 4.5        0.08333333] 0.3982008558263916
# call: [2.55       8.         0.9        4.5        0.09444444] 0.3980708324971838
# call: [2.55       8.         0.9        4.5        0.07222222] 0.39796506237203727
# call: [3.51666667 8.         0.83333333 5.5        0.01666667] 0.4577114215935725
# call: [1.58333333 8.         0.83333333 5.5        0.01666667] 0.7388503939787532
# call: [ 2.55       12.66666667  0.83333333  5.5         0.01666667] 0.4497285818851687
# call: [2.55       3.33333333 0.83333333 5.5        0.01666667] 0.43963583289536
# call: [2.55       8.         0.83333333 8.5        0.01666667] 0.4377479202710081
# call: [2.55       8.         0.83333333 2.5        0.01666667] 0.4261362463643347
# call: [2.22777778 9.55555556 0.9        4.5        0.08333333] 0.40744767681785987
# call: [2.22777778 6.44444444 0.9        4.5        0.08333333] 0.39918168969319456
# call: [2.22777778 8.         0.92222222 4.5        0.08333333] 0.39771421158273607
# call: [2.22777778 8.         0.87777778 4.5        0.08333333] 0.3959712627328666
# call: [2.22777778 8.         0.9        4.5        0.09444444] 0.3961678033370351
# call: [2.22777778 8.         0.9        4.5        0.07222222] 0.3961378843540727
# call: [3.51666667 8.         0.96666667 5.5        0.05      ] 0.4508344094508449
# call: [1.58333333 8.         0.96666667 5.5        0.05      ] 0.7510736882634155
# call: [ 2.55       12.66666667  0.96666667  5.5         0.05      ] 0.44334993425871877
# call: [2.55       3.33333333 0.96666667 5.5        0.05      ] 0.44118487360888625
# call: [2.55       8.         0.96666667 8.5        0.05      ] 0.42302573536454946
# call: [2.55       8.         0.96666667 2.5        0.05      ] 0.4340939776583397
# call: [2.22777778 9.55555556 0.87777778 4.5        0.08333333] 0.40697423900381857
# call: [2.22777778 6.44444444 0.87777778 4.5        0.08333333] 0.3983491053052729
# call: [2.22777778 8.         0.87777778 4.5        0.09444444] 0.39550758610197695
# call: [2.22777778 8.         0.87777778 4.5        0.07222222] 0.3953770460615429
# call: [3.51666667 8.         0.96666667 5.5        0.01666667] 0.4512076521901817
# call: [1.58333333 8.         0.96666667 5.5        0.01666667] 0.7515113043045224
# call: [ 2.55       12.66666667  0.96666667  5.5         0.01666667] 0.44347344867873956
# call: [2.55       3.33333333 0.96666667 5.5        0.01666667] 0.44101470636068363
# call: [2.55       8.         0.96666667 8.5        0.01666667] 0.4229402433344851
# call: [2.55       8.         0.96666667 2.5        0.01666667] 0.43430499966092145
# call: [2.22777778 9.55555556 0.87777778 4.5        0.07222222] 0.40693293135742786
# call: [2.22777778 6.44444444 0.87777778 4.5        0.07222222] 0.39821096377512627
# call: [3.51666667 8.         0.96666667 5.5        0.08333333] 0.450623569029351
# call: [1.58333333 8.         0.96666667 5.5        0.08333333] 0.7506146382082716
# call: [ 2.55       12.66666667  0.96666667  5.5         0.08333333] 0.44338286547072975
# call: [2.55       3.33333333 0.96666667 5.5        0.08333333] 0.44148864813433486
# call: [2.55       8.         0.96666667 8.5        0.08333333] 0.4233326689677801
# call: [2.55       8.         0.96666667 2.5        0.08333333] 0.43429194355494055
# call: [2.22777778 9.55555556 0.87777778 4.5        0.09444444] 0.40734123623333884
# call: [2.22777778 6.44444444 0.87777778 4.5        0.09444444] 0.3983378791564644
# call: [2.33518519 8.         0.87777778 4.5        0.07222222] 0.3924655005452673
# call: [2.12037037 8.         0.87777778 4.5        0.07222222] 0.4050388424345105
# call: [2.22777778 8.51851852 0.87777778 4.5        0.07222222] 0.3992469007888269
# call: [2.22777778 7.48148148 0.87777778 4.5        0.07222222] 0.39339572145524915
# call: [2.22777778 8.         0.88518519 4.5        0.07222222] 0.3954760163468529
# call: [2.22777778 8.         0.87037037 4.5        0.07222222] 0.395192538879403
# call: [2.22777778 8.         0.87777778 4.83333333 0.07222222] 0.3967671033717632
# call: [2.22777778 8.         0.87777778 4.16666667 0.07222222] 0.3949591014327903
# call: [2.22777778 8.         0.87777778 4.5        0.07592593] 0.3953614208846715
# call: [2.22777778 8.         0.87777778 4.5        0.06851852] 0.3953344537018646
# call: [3.51666667 8.         0.96666667 8.5        0.01666667] 0.439259181056685
# call: [1.58333333 8.         0.96666667 8.5        0.01666667] 0.7608582496854527
# call: [ 2.55       12.66666667  0.96666667  8.5         0.01666667] 0.4589468210038962
# call: [2.55       3.33333333 0.96666667 8.5        0.01666667] 0.4617009287735549
# call: [2.22777778 9.55555556 0.9        4.5        0.07222222] 0.4074041145770242
# call: [2.22777778 6.44444444 0.9        4.5        0.07222222] 0.3991314428940047
# call: [2.33518519 8.51851852 0.87777778 4.5        0.07222222] 0.3965531048616294
# call: [2.33518519 7.48148148 0.87777778 4.5        0.07222222] 0.39004353215837345
# call: [2.33518519 8.         0.88518519 4.5        0.07222222] 0.39234254166648413
# call: [2.33518519 8.         0.87037037 4.5        0.07222222] 0.39231607021227843
# call: [2.33518519 8.         0.87777778 4.83333333 0.07222222] 0.39307929093675753
# call: [2.33518519 8.         0.87777778 4.16666667 0.07222222] 0.39239394200114563
# call: [2.33518519 8.         0.87777778 4.5        0.07592593] 0.392380523978664
# call: [2.33518519 8.         0.87777778 4.5        0.06851852] 0.3923008209516462
# call: [3.51666667 8.         0.96666667 8.5        0.05      ] 0.43908165644328284
# call: [1.58333333 8.         0.96666667 8.5        0.05      ] 0.7603118776292108
# call: [ 2.55       12.66666667  0.96666667  8.5         0.05      ] 0.4589711585803328
# call: [2.55       3.33333333 0.96666667 8.5        0.05      ] 0.4618663612123532
# call: [2.22777778 9.55555556 0.9        4.5        0.09444444] 0.40776031703506393
# call: [2.22777778 6.44444444 0.9        4.5        0.09444444] 0.3992469354666452
# call: [2.33518519 7.48148148 0.88518519 4.5        0.07222222] 0.39021500854899843
# call: [2.33518519 7.48148148 0.87037037 4.5        0.07222222] 0.39006036752240325
# call: [2.33518519 7.48148148 0.87777778 4.83333333 0.07222222] 0.39060522397316705
# call: [2.33518519 7.48148148 0.87777778 4.16666667 0.07222222] 0.39013898319324364
# call: [2.33518519 7.48148148 0.87777778 4.5        0.07592593] 0.39004885771397513
# call: [2.33518519 7.48148148 0.87777778 4.5        0.06851852] 0.39046204410202
# call: [3.51666667 8.         0.96666667 8.5        0.08333333] 0.43897506782807155
# call: [1.58333333 8.         0.96666667 8.5        0.08333333] 0.7597157893066638
# call: [ 2.55       12.66666667  0.96666667  8.5         0.08333333] 0.45898840114282613
# call: [2.55       3.33333333 0.96666667 8.5        0.08333333] 0.46204511851919056
# call: [2.22777778 9.55555556 0.92222222 4.5        0.08333333] 0.40881423341553047
# call: [2.22777778 6.44444444 0.92222222 4.5        0.08333333] 0.4009325027920123
# call: [2.22777778 8.         0.92222222 4.5        0.09444444] 0.3980785819596171
# call: [2.22777778 8.         0.92222222 4.5        0.07222222] 0.397659852630153
# call: [2.33518519 7.48148148 0.88518519 4.5        0.07592593] 0.3901392046348304
# call: [2.33518519 7.48148148 0.87037037 4.5        0.07592593] 0.3899779229750176
# call: [2.33518519 7.48148148 0.87777778 4.83333333 0.07592593] 0.39060750211085155
# call: [2.33518519 7.48148148 0.87777778 4.16666667 0.07592593] 0.39001672805730647
# call: [3.51666667 8.         0.9        2.5        0.08333333] 0.5187666117725804
# call: [1.58333333 8.         0.9        2.5        0.08333333] 0.7556642534215755
# call: [ 2.55       12.66666667  0.9         2.5         0.08333333] 0.4609156103265102
# call: [2.55       3.33333333 0.9        2.5        0.08333333] 0.447137380048413
# call: [2.22777778 9.55555556 0.92222222 4.5        0.07222222] 0.4084820683307291
# call: [2.22777778 6.44444444 0.92222222 4.5        0.07222222] 0.4008904009646693
# call: [2.33518519 7.48148148 0.87037037 4.83333333 0.07592593] 0.39076993217535766
# call: [2.33518519 7.48148148 0.87037037 4.16666667 0.07592593] 0.3899090331918584
# call: [3.51666667 8.         0.83333333 2.5        0.08333333] 0.5205808714943818
# call: [1.58333333 8.         0.83333333 2.5        0.08333333] 0.7529033282579592
# call: [ 2.55       12.66666667  0.83333333  2.5         0.08333333] 0.4635884805037559
# call: [2.55       3.33333333 0.83333333 2.5        0.08333333] 0.44458311310487125
# call: [2.87222222 8.         0.92222222 5.5        0.08333333] 0.4128066827622756
# call: [2.22777778 8.         0.92222222 5.5        0.08333333] 0.40225321616296883
# call: [2.55       9.55555556 0.92222222 5.5        0.08333333] 0.4130592373714986
# call: [2.55       6.44444444 0.92222222 5.5        0.08333333] 0.3998907371605746
# call: [2.55       8.         0.92222222 5.5        0.09444444] 0.39816470951814387
# call: [2.55       8.         0.92222222 5.5        0.07222222] 0.3979015613421995
# call: [2.33518519 7.48148148 0.87037037 4.83333333 0.07222222] 0.39064227522527994
# call: [2.33518519 7.48148148 0.87037037 4.16666667 0.07222222] 0.3900417676495942
# call: [2.37098765 7.48148148 0.87037037 4.16666667 0.07592593] 0.3902237851120472
# call: [2.29938272 7.48148148 0.87037037 4.16666667 0.07592593] 0.39059410200702654
# call: [2.33518519 7.65432099 0.87037037 4.16666667 0.07592593] 0.3900177598621436
# call: [2.33518519 7.30864198 0.87037037 4.16666667 0.07592593] 0.3908065711536046
# call: [2.33518519 7.48148148 0.87283951 4.16666667 0.07592593] 0.39007975340985285
# call: [2.33518519 7.48148148 0.86790123 4.16666667 0.07592593] 0.38997398678866063
# call: [2.33518519 7.48148148 0.87037037 4.27777778 0.07592593] 0.38998491006925806
# call: [2.33518519 7.48148148 0.87037037 4.05555556 0.07592593] 0.39069387479133344
# call: [2.33518519 7.48148148 0.87037037 4.16666667 0.07716049] 0.3900691273901433
# call: [2.33518519 7.48148148 0.87037037 4.16666667 0.07469136] 0.3900017863914118
# call: [3.51666667 8.         0.9        2.5        0.01666667] 0.5205608205407855
# call: [1.58333333 8.         0.9        2.5        0.01666667] 0.756944853705978
# call: [ 2.55       12.66666667  0.9         2.5         0.01666667] 0.46161033686512015
# call: [2.55       3.33333333 0.9        2.5        0.01666667] 0.44736944445353277
# call: [2.87222222 8.         0.92222222 5.5        0.07222222] 0.41290047057144164
# call: [2.22777778 8.         0.92222222 5.5        0.07222222] 0.4026188463126779
# call: [2.55       9.55555556 0.92222222 5.5        0.07222222] 0.4130964723949246
# call: [2.55       6.44444444 0.92222222 5.5        0.07222222] 0.39977495282585296
# call: [2.33518519 7.48148148 0.88518519 4.83333333 0.07592593] 0.39086326334904387
# call: [2.33518519 7.48148148 0.88518519 4.16666667 0.07592593] 0.3901685216384282
# call: [3.51666667 8.         0.9        2.5        0.05      ] 0.5197246341208265
# call: [1.58333333 8.         0.9        2.5        0.05      ] 0.756306671610852
# call: [ 2.55       12.66666667  0.9         2.5         0.05      ] 0.46122124486005434
# call: [2.55       3.33333333 0.9        2.5        0.05      ] 0.4473701249262424
# call: [2.55       9.55555556 0.9        4.5        0.07222222] 0.4121644987134173
# call: [2.55       6.44444444 0.9        4.5        0.07222222] 0.39875616440714273
# call: [2.55       8.         0.92222222 4.5        0.07222222] 0.3978037302447073
# call: [2.55       8.         0.87777778 4.5        0.07222222] 0.39828878254173755
# call: [2.33518519 7.48148148 0.88518519 4.83333333 0.07222222] 0.39066643970546555
# call: [2.33518519 7.48148148 0.88518519 4.16666667 0.07222222] 0.3901211087659597
# call: [2.37098765 7.48148148 0.86790123 4.16666667 0.07592593] 0.3902879575010278
# call: [2.29938272 7.48148148 0.86790123 4.16666667 0.07592593] 0.3905534074401771
# call: [2.33518519 7.65432099 0.86790123 4.16666667 0.07592593] 0.39002488942022906
# call: [2.33518519 7.30864198 0.86790123 4.16666667 0.07592593] 0.39035627608533946
# call: [2.33518519 7.48148148 0.86790123 4.27777778 0.07592593] 0.38993330382984054
# call: [2.33518519 7.48148148 0.86790123 4.05555556 0.07592593] 0.39076977970066085
# call: [2.33518519 7.48148148 0.86790123 4.16666667 0.07716049] 0.3899562135801059
# call: [2.33518519 7.48148148 0.86790123 4.16666667 0.07469136] 0.3900464933489209
# call: [3.51666667 8.         0.83333333 2.5        0.05      ] 0.521564586499953
# call: [1.58333333 8.         0.83333333 2.5        0.05      ] 0.7531820977871382
# call: [ 2.55       12.66666667  0.83333333  2.5         0.05      ] 0.4637307052885092
# call: [2.55       3.33333333 0.83333333 2.5        0.05      ] 0.4447422169755507
# call: [2.55       9.55555556 0.92222222 4.5        0.07222222] 0.4118286622457947
# call: [2.55       6.44444444 0.92222222 4.5        0.07222222] 0.3996124353272311
# call: [2.33518519 7.48148148 0.88518519 4.5        0.06851852] 0.39037113645610844
# call: [2.33518519 7.48148148 0.87037037 4.5        0.06851852] 0.39032651926396555
# call: [2.33518519 7.48148148 0.87777778 4.83333333 0.06851852] 0.3905916923070439
# call: [2.33518519 7.48148148 0.87777778 4.16666667 0.06851852] 0.3903887221181941
# call: [2.37098765 7.48148148 0.86790123 4.27777778 0.07592593] 0.39002052909681323
# call: [2.29938272 7.48148148 0.86790123 4.27777778 0.07592593] 0.39049773273685906
# call: [2.33518519 7.65432099 0.86790123 4.27777778 0.07592593] 0.39003120841874256
# call: [2.33518519 7.30864198 0.86790123 4.27777778 0.07592593] 0.39022752025436
# call: [2.33518519 7.48148148 0.86790123 4.27777778 0.07716049] 0.3899082156145615
# call: [2.33518519 7.48148148 0.86790123 4.27777778 0.07469136] 0.3899077954738782
# call: [3.51666667 8.         0.83333333 2.5        0.01666667] 0.5224286933674472
# call: [1.58333333 8.         0.83333333 2.5        0.01666667] 0.7535033570396934
# call: [ 2.55       12.66666667  0.83333333  2.5         0.01666667] 0.46431180666042243
# call: [2.55       3.33333333 0.83333333 2.5        0.01666667] 0.44481621171545466
# call: [2.55       9.55555556 0.92222222 4.5        0.08333333] 0.4118042755516818
# call: [2.55       6.44444444 0.92222222 4.5        0.08333333] 0.3996642620829471
# call: [2.33518519 7.48148148 0.87037037 4.83333333 0.06851852] 0.39056449719513664
# call: [2.33518519 7.48148148 0.87037037 4.16666667 0.06851852] 0.3899792488373978
# call: [2.37098765 7.48148148 0.86790123 4.27777778 0.07469136] 0.39001308482196767
# call: [2.29938272 7.48148148 0.86790123 4.27777778 0.07469136] 0.3904841435636934
# call: [2.33518519 7.65432099 0.86790123 4.27777778 0.07469136] 0.38990418684952793
# call: [2.33518519 7.30864198 0.86790123 4.27777778 0.07469136] 0.3902176641740515
# call: [3.51666667 8.         0.9        8.5        0.08333333] 0.4527935024632441
# call: [1.58333333 8.         0.9        8.5        0.08333333] 0.7549665005826038
# call: [ 2.55       12.66666667  0.9         8.5         0.08333333] 0.467218131563755
# call: [2.55       3.33333333 0.9        8.5        0.08333333] 0.47052910337399295
# call: [2.55       9.55555556 0.9        4.5        0.09444444] 0.4121217350517634
# call: [2.55       6.44444444 0.9        4.5        0.09444444] 0.3987627464110903
# call: [2.55       8.         0.92222222 4.5        0.09444444] 0.3982026692155708
# call: [2.55       8.         0.87777778 4.5        0.09444444] 0.3981793665977722
# call: [2.33518519 7.48148148 0.88518519 4.83333333 0.06851852] 0.39067191105889965
# call: [2.33518519 7.48148148 0.88518519 4.16666667 0.06851852] 0.3901563062083724
# call: [2.37098765 7.65432099 0.86790123 4.27777778 0.07469136] 0.39003485737392923
# call: [2.29938272 7.65432099 0.86790123 4.27777778 0.07469136] 0.3904951695204127
# call: [3.51666667 8.         0.9        8.5        0.05      ] 0.4530766706715942
# call: [1.58333333 8.         0.9        8.5        0.05      ] 0.7552113629543796
# call: [ 2.55       12.66666667  0.9         8.5         0.05      ] 0.46724436584997575
# call: [2.55       3.33333333 0.9        8.5        0.05      ] 0.47011840100288504
# call: [2.22777778 9.55555556 0.92222222 4.5        0.09444444] 0.40866985860703264
# call: [2.22777778 6.44444444 0.92222222 4.5        0.09444444] 0.40106629119484694
# call: [2.33518519 8.         0.88518519 4.5        0.06851852] 0.39256102974539203
# call: [2.33518519 8.         0.87037037 4.5        0.06851852] 0.39300506888119346
# call: [2.33518519 8.         0.87777778 4.83333333 0.06851852] 0.3930906776867207
# call: [2.33518519 8.         0.87777778 4.16666667 0.06851852] 0.39238656031224567
# call: [2.37098765 7.48148148 0.86790123 4.27777778 0.07716049] 0.39003589615394213
# call: [2.29938272 7.48148148 0.86790123 4.27777778 0.07716049] 0.3906327488041311
# call: [2.33518519 7.65432099 0.86790123 4.27777778 0.07716049] 0.389878928614025
# call: [2.33518519 7.30864198 0.86790123 4.27777778 0.07716049] 0.39024523948598405
# call: [3.51666667 8.         0.9        8.5        0.01666667] 0.45340946967976187
# call: [1.58333333 8.         0.9        8.5        0.01666667] 0.7558027096566163
# call: [ 2.55       12.66666667  0.9         8.5         0.01666667] 0.4677156420767283
# call: [2.55       3.33333333 0.9        8.5        0.01666667] 0.4700732313454135
# call: [2.87222222 8.         0.92222222 5.5        0.09444444] 0.4127302858536238
# call: [2.22777778 8.         0.92222222 5.5        0.09444444] 0.40227282143303744
# call: [2.55       9.55555556 0.92222222 5.5        0.09444444] 0.4130271927135868
# call: [2.55       6.44444444 0.92222222 5.5        0.09444444] 0.3998713452563192
# call: [2.33518519 8.         0.87037037 4.83333333 0.07222222] 0.39312580773232125
# call: [2.33518519 8.         0.87037037 4.16666667 0.07222222] 0.3924039078130118
# call: [2.37098765 7.65432099 0.86790123 4.27777778 0.07716049] 0.3900790127737068
# call: [2.29938272 7.65432099 0.86790123 4.27777778 0.07716049] 0.3905331457349805
# call: [3.51666667 8.         0.96666667 2.5        0.05      ] 0.523197576212433
# call: [1.58333333 8.         0.96666667 2.5        0.05      ] 0.7657572551728539
# call: [ 2.55       12.66666667  0.96666667  2.5         0.05      ] 0.46648578576991817
# call: [2.55       3.33333333 0.96666667 2.5        0.05      ] 0.4542558561303718
# call: [2.55       9.55555556 0.87777778 4.5        0.09444444] 0.4131046220423331
# call: [2.55       6.44444444 0.87777778 4.5        0.09444444] 0.3984973382339874
# call: [2.33518519 8.         0.88518519 4.83333333 0.07222222] 0.39313894948044914
# call: [2.33518519 8.         0.88518519 4.16666667 0.07222222] 0.3924199307333221
# call: [2.37098765 7.48148148 0.86790123 4.16666667 0.07716049] 0.39017094906329575
# call: [2.29938272 7.48148148 0.86790123 4.16666667 0.07716049] 0.39064586229576154
# call: [2.33518519 7.65432099 0.86790123 4.16666667 0.07716049] 0.3900120547006674
# call: [2.33518519 7.30864198 0.86790123 4.16666667 0.07716049] 0.39046853726537845
# call: [3.51666667 8.         0.96666667 2.5        0.08333333] 0.5224084455326719
# call: [1.58333333 8.         0.96666667 2.5        0.08333333] 0.7653158007060692
# call: [ 2.55       12.66666667  0.96666667  2.5         0.08333333] 0.46630754345264647
# call: [2.55       3.33333333 0.96666667 2.5        0.08333333] 0.4538075867078803
# call: [2.55       9.55555556 0.87777778 4.5        0.08333333] 0.4137869472876189
# call: [2.55       6.44444444 0.87777778 4.5        0.08333333] 0.3984928282134884
# call: [2.33518519 8.         0.88518519 4.5        0.07592593] 0.39235030092473216
# call: [2.33518519 8.         0.87037037 4.5        0.07592593] 0.39236118744034065
# call: [2.33518519 8.         0.87777778 4.83333333 0.07592593] 0.3930791385554282
# call: [2.33518519 8.         0.87777778 4.16666667 0.07592593] 0.3923976569020278
# call: [2.37098765 7.48148148 0.87037037 4.5        0.07592593] 0.3903825251669644
# call: [2.29938272 7.48148148 0.87037037 4.5        0.07592593] 0.3903728436811936
# call: [2.33518519 7.65432099 0.87037037 4.5        0.07592593] 0.389895049096455
# call: [2.33518519 7.30864198 0.87037037 4.5        0.07592593] 0.3903091423967052
# call: [2.33518519 7.48148148 0.87283951 4.5        0.07592593] 0.3900793427445726
# call: [2.33518519 7.48148148 0.86790123 4.5        0.07592593] 0.39005440576467093
# call: [2.33518519 7.48148148 0.87037037 4.61111111 0.07592593] 0.3900097027383388
# call: [2.33518519 7.48148148 0.87037037 4.38888889 0.07592593] 0.3898015252166572
# call: [2.33518519 7.48148148 0.87037037 4.5        0.07716049] 0.3900549941106039
# call: [2.33518519 7.48148148 0.87037037 4.5        0.07469136] 0.39006700165608005
# call: [2.34711934 7.65432099 0.86790123 4.27777778 0.07716049] 0.38982602052981624
# call: [2.32325103 7.65432099 0.86790123 4.27777778 0.07716049] 0.38990340766401527
# call: [2.33518519 7.71193416 0.86790123 4.27777778 0.07716049] 0.38994926467531316
# call: [2.33518519 7.59670782 0.86790123 4.27777778 0.07716049] 0.3902611544521989
# call: [2.33518519 7.65432099 0.86872428 4.27777778 0.07716049] 0.3899008202176607
# call: [2.33518519 7.65432099 0.86707819 4.27777778 0.07716049] 0.3901835406124829
# call: [2.33518519 7.65432099 0.86790123 4.31481481 0.07716049] 0.39020444623138634
# call: [2.33518519 7.65432099 0.86790123 4.24074074 0.07716049] 0.3899386153976646
# call: [2.33518519 7.65432099 0.86790123 4.27777778 0.07757202] 0.3898835395268961
# call: [2.33518519 7.65432099 0.86790123 4.27777778 0.07674897] 0.3899699643000601
# call: [3.51666667 8.         0.96666667 2.5        0.01666667] 0.5240378774163422
# call: [1.58333333 8.         0.96666667 2.5        0.01666667] 0.7662966408177148
# call: [ 2.55       12.66666667  0.96666667  2.5         0.01666667] 0.46676556692998455
# call: [2.55       3.33333333 0.96666667 2.5        0.01666667] 0.45399091083205567
# call: [2.55       9.55555556 0.92222222 4.5        0.09444444] 0.411859910460638
# call: [2.55       6.44444444 0.92222222 4.5        0.09444444] 0.3998351870793738
# call: [2.33518519 8.         0.88518519 4.83333333 0.07592593] 0.3931120779870788
# call: [2.33518519 8.         0.88518519 4.16666667 0.07592593] 0.3928578345573752
# call: [2.37098765 7.48148148 0.87037037 4.38888889 0.07592593] 0.39002682539499095
# call: [2.29938272 7.48148148 0.87037037 4.38888889 0.07592593] 0.39034063898249083
# call: [2.33518519 7.65432099 0.87037037 4.38888889 0.07592593] 0.38993238831679167
# call: [2.33518519 7.30864198 0.87037037 4.38888889 0.07592593] 0.390597912497244
# call: [2.33518519 7.48148148 0.87283951 4.38888889 0.07592593] 0.39004629484286185
# call: [2.33518519 7.48148148 0.86790123 4.38888889 0.07592593] 0.38979122095812285
# call: [2.33518519 7.48148148 0.87037037 4.38888889 0.07716049] 0.3902017570842327
# call: [2.33518519 7.48148148 0.87037037 4.38888889 0.07469136] 0.3900752739781131
# call: [3.51666667 8.         0.83333333 8.5        0.08333333] 0.4628472451189978
# call: [1.58333333 8.         0.83333333 8.5        0.08333333] 0.7551972668636648
# call: [ 2.55       12.66666667  0.83333333  8.5         0.08333333] 0.47588948399211434
# call: [2.55       3.33333333 0.83333333 8.5        0.08333333] 0.4760145597816481
# call: [2.55       9.55555556 0.87777778 4.5        0.07222222] 0.41318392439664764
# call: [2.55       6.44444444 0.87777778 4.5        0.07222222] 0.39850288227142977
# call: [2.33518519 8.         0.87037037 4.83333333 0.07592593] 0.39311805918684894
# call: [2.33518519 8.         0.87037037 4.16666667 0.07592593] 0.39242203767845873
# call: [2.37098765 7.48148148 0.86790123 4.38888889 0.07592593] 0.38979491764164725
# call: [2.29938272 7.48148148 0.86790123 4.38888889 0.07592593] 0.3902056234243585
# call: [2.33518519 7.65432099 0.86790123 4.38888889 0.07592593] 0.3898736635967254
# call: [2.33518519 7.30864198 0.86790123 4.38888889 0.07592593] 0.3908319615284657
# call: [2.33518519 7.48148148 0.86790123 4.38888889 0.07716049] 0.3899487742958471
# call: [2.33518519 7.48148148 0.86790123 4.38888889 0.07469136] 0.3897853986868141
# call: [3.51666667 8.         0.83333333 8.5        0.05      ] 0.46314276131377097
# call: [1.58333333 8.         0.83333333 8.5        0.05      ] 0.7557404756483839
# call: [ 2.55       12.66666667  0.83333333  8.5         0.05      ] 0.4765764097744409
# call: [2.55       3.33333333 0.83333333 8.5        0.05      ] 0.4759732308883268
# call: [2.87222222 8.         0.9        5.5        0.09444444] 0.4135709721680477
# call: [2.22777778 8.         0.9        5.5        0.09444444] 0.401591136817675
# call: [2.55       9.55555556 0.9        5.5        0.09444444] 0.414011563923111
# call: [2.55       6.44444444 0.9        5.5        0.09444444] 0.3996440802290737
# call: [2.33518519 8.         0.88518519 4.16666667 0.06851852] 0.39241985617613534
# call: [2.33518519 8.         0.87037037 4.16666667 0.06851852] 0.39239179738329927
# call: [2.37098765 7.48148148 0.86790123 4.38888889 0.07469136] 0.3900597511153426
# call: [2.29938272 7.48148148 0.86790123 4.38888889 0.07469136] 0.39032821720392036
# call: [2.33518519 7.65432099 0.86790123 4.38888889 0.07469136] 0.3899392430281941
# call: [2.33518519 7.30864198 0.86790123 4.38888889 0.07469136] 0.39074726381706143
# call: [3.51666667 8.         0.83333333 8.5        0.01666667] 0.4634737442065965
# call: [1.58333333 8.         0.83333333 8.5        0.01666667] 0.7562102951825942
# call: [ 2.55       12.66666667  0.83333333  8.5         0.01666667] 0.47635131302087835
# call: [2.55       3.33333333 0.83333333 8.5        0.01666667] 0.47598145912882767
# call: [2.87222222 8.         0.9        5.5        0.07222222] 0.41366050652175296
# call: [2.22777778 8.         0.9        5.5        0.07222222] 0.4014532658407433
# call: [2.55       9.55555556 0.9        5.5        0.07222222] 0.4141741422335483
# call: [2.55       6.44444444 0.9        5.5        0.07222222] 0.3996588484123253
# call: [2.33518519 8.         0.88518519 4.83333333 0.06851852] 0.3930356739588626
# call: [2.33518519 8.         0.87037037 4.83333333 0.06851852] 0.39310159753654317
# call: [2.37098765 7.65432099 0.86790123 4.38888889 0.07592593] 0.3905029544710023
# call: [2.37098765 7.30864198 0.86790123 4.38888889 0.07592593] 0.3903090490425374
# call: [3.51666667 3.33333333 0.9        5.5        0.01666667] 0.4910643785201238
# call: [1.58333333 3.33333333 0.9        5.5        0.01666667] 0.7660014721303681
# call: [2.87222222 8.         0.9        5.5        0.01666667] 0.414022467879829
# call: [2.22777778 8.         0.9        5.5        0.01666667] 0.40121200951455294
# call: [2.55       9.55555556 0.9        5.5        0.01666667] 0.41427188390566566
# call: [2.55       6.44444444 0.9        5.5        0.01666667] 0.39974560373189955
# call: [2.55       8.         0.92222222 5.5        0.01666667] 0.39804663764778797
# call: [2.55       8.         0.87777778 5.5        0.01666667] 0.3993080105899697
# call: [2.55       8.         0.9        6.5        0.01666667] 0.4052006905045641
# call: [2.55       8.         0.9        4.5        0.01666667] 0.3978853585669134
# call: [2.55       8.         0.9        5.5        0.02777778] 0.39837035183087016
# call: [2.55000000e+00 8.00000000e+00 9.00000000e-01 5.50000000e+00
#  5.55555556e-03] 0.3984157606401093
# call: [2.22777778 7.48148148 0.88518519 4.5        0.07222222] 0.393666651049288
# call: [2.22777778 7.48148148 0.87037037 4.5        0.07222222] 0.393835021137562
# call: [2.22777778 7.48148148 0.87777778 4.83333333 0.07222222] 0.39452855841875395
# call: [2.22777778 7.48148148 0.87777778 4.16666667 0.07222222] 0.39292854378209563
# call: [2.22777778 7.48148148 0.87777778 4.5        0.07592593] 0.3934098422486615
# call: [2.22777778 7.48148148 0.87777778 4.5        0.06851852] 0.3933974501163114
# call: [2.37098765 7.65432099 0.87037037 4.5        0.07592593] 0.38981741228253586
# call: [2.29938272 7.65432099 0.87037037 4.5        0.07592593] 0.39039152726223714
# call: [2.33518519 7.65432099 0.87283951 4.5        0.07592593] 0.39005004753861444
# call: [2.33518519 7.65432099 0.86790123 4.5        0.07592593] 0.3899634282077979
# call: [2.33518519 7.65432099 0.87037037 4.5        0.07716049] 0.3900200850985046
# call: [2.33518519 7.65432099 0.87037037 4.5        0.07469136] 0.39029793980383937
# call: [2.34711934 7.48148148 0.86790123 4.38888889 0.07469136] 0.38992423830029604
# call: [2.32325103 7.48148148 0.86790123 4.38888889 0.07469136] 0.38987069879542224
# call: [2.33518519 7.53909465 0.86790123 4.38888889 0.07469136] 0.38977994805470173
# call: [2.33518519 7.42386831 0.86790123 4.38888889 0.07469136] 0.3899431449812595
# call: [2.33518519 7.48148148 0.86872428 4.38888889 0.07469136] 0.3898300163846194
# call: [2.33518519 7.48148148 0.86707819 4.38888889 0.07469136] 0.38977499898984214
# call: [2.33518519 7.48148148 0.86790123 4.42592593 0.07469136] 0.38979843213218074
# call: [2.33518519 7.48148148 0.86790123 4.35185185 0.07469136] 0.39011476321735555
# call: [2.33518519 7.48148148 0.86790123 4.38888889 0.07510288] 0.38984241287392857
# call: [2.33518519 7.48148148 0.86790123 4.38888889 0.07427984] 0.3897874525448205
# call: [3.51666667 3.33333333 0.9        5.5        0.05      ] 0.49071742686112846
# call: [1.58333333 3.33333333 0.9        5.5        0.05      ] 0.7653924269917942
# call: [2.87222222 8.         0.9        4.5        0.01666667] 0.41859432772681376
# call: [2.22777778 8.         0.9        4.5        0.01666667] 0.39573299083918634
# call: [2.55       9.55555556 0.9        4.5        0.01666667] 0.41237635770430664
# call: [2.55       6.44444444 0.9        4.5        0.01666667] 0.3990556507191496
# call: [2.55       8.         0.92222222 4.5        0.01666667] 0.39829519510621175
# call: [2.55       8.         0.87777778 4.5        0.01666667] 0.3980938655340924
# call: [2.55       8.         0.9        4.5        0.02777778] 0.39794110834730717
# call: [2.55000000e+00 8.00000000e+00 9.00000000e-01 4.50000000e+00
#  5.55555556e-03] 0.39786338937884463
# call: [2.22777778 7.48148148 0.88518519 4.16666667 0.07222222] 0.3931346870918843
# call: [2.22777778 7.48148148 0.87037037 4.16666667 0.07222222] 0.39281223821889233
# call: [2.22777778 7.48148148 0.87777778 4.16666667 0.07592593] 0.39301702595339216
# call: [2.22777778 7.48148148 0.87777778 4.16666667 0.06851852] 0.39291405421039727
# call: [2.37098765 7.65432099 0.87283951 4.5        0.07592593] 0.38994957291296595
# call: [2.37098765 7.65432099 0.86790123 4.5        0.07592593] 0.3898380376861777
# call: [2.37098765 7.65432099 0.87037037 4.5        0.07716049] 0.3899207987842649
# call: [2.37098765 7.65432099 0.87037037 4.5        0.07469136] 0.3898195124688451
# call: [ 3.51666667 12.66666667  0.96666667  8.5         0.08333333] 0.5010082366296233
# call: [3.51666667 3.33333333 0.96666667 8.5        0.08333333] 0.4766995071481534
# call: [2.22777778 9.55555556 0.9        4.5        0.01666667] 0.4072892678110053
# call: [2.22777778 6.44444444 0.9        4.5        0.01666667] 0.39928236607638806
# call: [2.22777778 8.         0.92222222 4.5        0.01666667] 0.3971559033973468
# call: [2.22777778 8.         0.87777778 4.5        0.01666667] 0.3952930213125215
# call: [2.22777778 8.         0.9        4.5        0.02777778] 0.3959553324588215
# call: [2.22777778e+00 8.00000000e+00 9.00000000e-01 4.50000000e+00
#  5.55555556e-03] 0.395681441706384
# call: [2.22777778 7.48148148 0.87037037 4.16666667 0.07592593] 0.39279489935792367
# call: [2.22777778 7.48148148 0.87037037 4.16666667 0.06851852] 0.3927664146519854
# call: [2.37098765 7.65432099 0.87283951 4.5        0.07469136] 0.3897870118453011
# call: [2.37098765 7.65432099 0.86790123 4.5        0.07469136] 0.38989672933013325
# call: [3.51666667 3.33333333 0.9        5.5        0.08333333] 0.49037103108340735
# call: [1.58333333 3.33333333 0.9        5.5        0.08333333] 0.7649536320753593
# call: [2.22777778 9.55555556 0.87777778 4.5        0.01666667] 0.4067828613832659
# call: [2.22777778 6.44444444 0.87777778 4.5        0.01666667] 0.39842284309901477
# call: [2.22777778 8.         0.87777778 4.5        0.02777778] 0.39516586487149713
# call: [2.22777778e+00 8.00000000e+00 8.77777778e-01 4.50000000e+00
#  5.55555556e-03] 0.39505701530521886
# call: [2.22777778 7.48148148 0.88518519 4.16666667 0.07592593] 0.39314749797637016
# call: [2.22777778 7.48148148 0.88518519 4.16666667 0.06851852] 0.393130792227166
# call: [2.37098765 7.65432099 0.87283951 4.5        0.07716049] 0.38980590055557984
# call: [2.37098765 7.65432099 0.86790123 4.5        0.07716049] 0.3898554009526081
# call: [2.34711934 7.48148148 0.86707819 4.38888889 0.07469136] 0.3899078744346658
# call: [2.32325103 7.48148148 0.86707819 4.38888889 0.07469136] 0.38986460408461954
# call: [2.33518519 7.53909465 0.86707819 4.38888889 0.07469136] 0.3897667819165507
# call: [2.33518519 7.42386831 0.86707819 4.38888889 0.07469136] 0.3899570368769212
# call: [2.33518519 7.48148148 0.86707819 4.42592593 0.07469136] 0.38994743639544943
# call: [2.33518519 7.48148148 0.86707819 4.35185185 0.07469136] 0.3901385690245444
# call: [2.33518519 7.48148148 0.86707819 4.38888889 0.07510288] 0.38981270612605634
# call: [2.33518519 7.48148148 0.86707819 4.38888889 0.07427984] 0.38975546081077717
# call: [ 3.51666667 12.66666667  0.96666667  8.5         0.05      ] 0.5012670989668846
# call: [3.51666667 3.33333333 0.96666667 8.5        0.05      ] 0.4767289152662599
# call: [2.22777778e+00 9.55555556e+00 8.77777778e-01 4.50000000e+00
#  5.55555556e-03] 0.40685012544786603
# call: [2.22777778e+00 6.44444444e+00 8.77777778e-01 4.50000000e+00
#  5.55555556e-03] 0.39821236461329
# call: [2.22777778 7.48148148 0.88518519 4.5        0.06851852] 0.3936399218358003
# call: [2.22777778 7.48148148 0.87037037 4.5        0.06851852] 0.39330443053316433
# call: [2.37098765 7.65432099 0.87037037 4.38888889 0.07592593] 0.389963066347008
# call: [2.29938272 7.65432099 0.87037037 4.38888889 0.07592593] 0.3902024109839646
# call: [2.33518519 7.65432099 0.87037037 4.38888889 0.07716049] 0.38983179703276444
# call: [2.33518519 7.65432099 0.87037037 4.38888889 0.07469136] 0.39020314403683704
# call: [2.34711934 7.48148148 0.86707819 4.38888889 0.07427984] 0.38999250560247223
# call: [2.32325103 7.48148148 0.86707819 4.38888889 0.07427984] 0.38987592695452555
# call: [2.33518519 7.53909465 0.86707819 4.38888889 0.07427984] 0.38975608745344154
# call: [2.33518519 7.42386831 0.86707819 4.38888889 0.07427984] 0.39015762303694385
# call: [2.33518519 7.48148148 0.86707819 4.42592593 0.07427984] 0.3901283713600307
# call: [2.33518519 7.48148148 0.86707819 4.35185185 0.07427984] 0.39013060119384885
# call: [ 3.51666667 12.66666667  0.96666667  8.5         0.01666667] 0.5015741871842307
# call: [3.51666667 3.33333333 0.96666667 8.5        0.01666667] 0.47669858267575493
# call: [2.22777778 9.55555556 0.87777778 4.5        0.02777778] 0.4068618422653398
# call: [2.22777778 6.44444444 0.87777778 4.5        0.02777778] 0.3979960616081729
# call: [2.22777778 7.48148148 0.88518519 4.5        0.07592593] 0.3937052296182093
# call: [2.22777778 7.48148148 0.87037037 4.5        0.07592593] 0.39345252069374226
# call: [2.37098765 7.65432099 0.87037037 4.38888889 0.07716049] 0.3904010778787233
# call: [2.29938272 7.65432099 0.87037037 4.38888889 0.07716049] 0.39031579004930045
# call: [3.51666667 3.33333333 0.83333333 5.5        0.01666667] 0.4924171160873653
# call: [1.58333333 3.33333333 0.83333333 5.5        0.01666667] 0.7641502656226875
# call: [2.22777778e+00 9.55555556e+00 9.00000000e-01 4.50000000e+00
#  5.55555556e-03] 0.40724920523602376
# call: [2.22777778e+00 6.44444444e+00 9.00000000e-01 4.50000000e+00
#  5.55555556e-03] 0.39878174105134195
# call: [2.22777778 7.48148148 0.88518519 4.83333333 0.07222222] 0.39470092318366135
# call: [2.22777778 7.48148148 0.87037037 4.83333333 0.07222222] 0.39444217695634987
# call: [2.22777778 7.48148148 0.87777778 4.83333333 0.07592593] 0.39454278141175175
# call: [2.22777778 7.48148148 0.87777778 4.83333333 0.06851852] 0.39450966001566495
# call: [2.37098765 7.65432099 0.86790123 4.38888889 0.07469136] 0.3899439239956603
# call: [2.29938272 7.65432099 0.86790123 4.38888889 0.07469136] 0.3903294835600269
# call: [2.34711934 7.53909465 0.86707819 4.38888889 0.07427984] 0.3900081146508573
# call: [2.32325103 7.53909465 0.86707819 4.38888889 0.07427984] 0.3899160195558304
# call: [2.33518519 7.53909465 0.86707819 4.42592593 0.07427984] 0.389972152075827
# call: [2.33518519 7.53909465 0.86707819 4.35185185 0.07427984] 0.3898464655703669
# call: [3.51666667 3.33333333 0.83333333 5.5        0.05      ] 0.4921198307409645
# call: [1.58333333 3.33333333 0.83333333 5.5        0.05      ] 0.763637742234416
# call: [2.22777778 9.55555556 0.9        4.5        0.02777778] 0.40728084492092864
# call: [2.22777778 6.44444444 0.9        4.5        0.02777778] 0.39885306541964366
# call: [2.22777778 7.48148148 0.87037037 4.83333333 0.07592593] 0.394454989150885
# call: [2.22777778 7.48148148 0.87037037 4.83333333 0.06851852] 0.3944852791035489
# call: [2.37098765 7.48148148 0.86790123 4.38888889 0.07716049] 0.3897891936813376
# call: [2.29938272 7.48148148 0.86790123 4.38888889 0.07716049] 0.3902539181222973
# call: [2.33518519 7.65432099 0.86790123 4.38888889 0.07716049] 0.3899307906233012
# call: [2.33518519 7.30864198 0.86790123 4.38888889 0.07716049] 0.390574418458868
# call: [2.34711934 7.53909465 0.86707819 4.38888889 0.07469136] 0.3898822973397604
# call: [2.32325103 7.53909465 0.86707819 4.38888889 0.07469136] 0.3899157524786349
# call: [2.33518519 7.53909465 0.86707819 4.42592593 0.07469136] 0.3904631287368177
# call: [2.33518519 7.53909465 0.86707819 4.35185185 0.07469136] 0.3898081522682422
# call: [3.51666667 3.33333333 0.83333333 5.5        0.08333333] 0.49176986115358323
# call: [1.58333333 3.33333333 0.83333333 5.5        0.08333333] 0.7630764277290653
# call: [2.22777778 9.55555556 0.92222222 4.5        0.01666667] 0.4082881022880765
# call: [2.22777778 6.44444444 0.92222222 4.5        0.01666667] 0.4005170067217277
# call: [2.22777778 8.         0.92222222 4.5        0.02777778] 0.3975173926014947
# call: [2.22777778e+00 8.00000000e+00 9.22222222e-01 4.50000000e+00
#  5.55555556e-03] 0.39714311699875615
# call: [2.22777778 7.48148148 0.88518519 4.83333333 0.07592593] 0.3946922956714307
# call: [2.22777778 7.48148148 0.88518519 4.83333333 0.06851852] 0.39469595303799887
# call: [2.37098765 7.65432099 0.86790123 4.38888889 0.07716049] 0.3899373889323599
# call: [2.37098765 7.30864198 0.86790123 4.38888889 0.07716049] 0.39030614161662563
# call: [3.51666667 3.33333333 0.96666667 5.5        0.01666667] 0.4867087440399697
# call: [1.58333333 3.33333333 0.96666667 5.5        0.01666667] 0.7779923749115247
# call: [2.22777778e+00 9.55555556e+00 9.22222222e-01 4.50000000e+00
#  5.55555556e-03] 0.4082058608342882
# call: [2.22777778e+00 6.44444444e+00 9.22222222e-01 4.50000000e+00
#  5.55555556e-03] 0.4004513855512886
# call: [2.22777778 8.         0.88518519 4.16666667 0.07222222] 0.3950532921242275
# call: [2.22777778 8.         0.87037037 4.16666667 0.07222222] 0.39484434261476126
# call: [2.22777778 8.         0.87777778 4.16666667 0.07592593] 0.39501147619846283
# call: [2.22777778 8.         0.87777778 4.16666667 0.06851852] 0.3949739931825757
# call: [2.33518519 7.65432099 0.86790123 4.5        0.07716049] 0.38997593402097913
# call: [2.33518519 7.65432099 0.86790123 4.5        0.07469136] 0.39002473831988344
# call: [2.34711934 7.53909465 0.86790123 4.38888889 0.07469136] 0.389893381426878
# call: [2.32325103 7.53909465 0.86790123 4.38888889 0.07469136] 0.3898869694519176
# call: [2.33518519 7.53909465 0.86790123 4.42592593 0.07469136] 0.38995653819398773
# call: [2.33518519 7.53909465 0.86790123 4.35185185 0.07469136] 0.3898103898289274
# call: [2.33518519 7.53909465 0.86790123 4.38888889 0.07510288] 0.39027608519752566
# call: [2.33518519 7.53909465 0.86790123 4.38888889 0.07427984] 0.3897899160524142
# call: [3.51666667 3.33333333 0.96666667 5.5        0.05      ] 0.48608448643095137
# call: [1.58333333 3.33333333 0.96666667 5.5        0.05      ] 0.7774652728288802
# call: [2.22777778 9.55555556 0.92222222 4.5        0.02777778] 0.4082938014440078
# call: [2.22777778 6.44444444 0.92222222 4.5        0.02777778] 0.40058831551628654
# call: [2.22777778 8.         0.87037037 4.16666667 0.07592593] 0.3948766674745348
# call: [2.22777778 8.         0.87037037 4.16666667 0.06851852] 0.3947073998334072
# call: [2.37098765 7.48148148 0.87037037 4.16666667 0.06851852] 0.3902788977355794
# call: [2.29938272 7.48148148 0.87037037 4.16666667 0.06851852] 0.3905573842550545
# call: [2.33518519 7.65432099 0.87037037 4.16666667 0.06851852] 0.3899979058813003
# call: [2.33518519 7.30864198 0.87037037 4.16666667 0.06851852] 0.3904351932448237
# call: [2.33518519 7.48148148 0.87283951 4.16666667 0.06851852] 0.3901362340752676
# call: [2.33518519 7.48148148 0.86790123 4.16666667 0.06851852] 0.38997425238307515
# call: [2.33518519 7.48148148 0.87037037 4.27777778 0.06851852] 0.38992647609710035
# call: [2.33518519 7.48148148 0.87037037 4.05555556 0.06851852] 0.3906103926130851
# call: [2.33518519 7.48148148 0.87037037 4.16666667 0.06975309] 0.38997455723013463
# call: [2.33518519 7.48148148 0.87037037 4.16666667 0.06728395] 0.38996703652472275
# call: [2.38292181 7.65432099 0.87283951 4.5        0.07469136] 0.38987999175741517
# call: [2.3590535  7.65432099 0.87283951 4.5        0.07469136] 0.3898853931141444
# call: [2.37098765 7.71193416 0.87283951 4.5        0.07469136] 0.38992041877817973
# call: [2.37098765 7.59670782 0.87283951 4.5        0.07469136] 0.38971701166145856
# call: [2.37098765 7.65432099 0.87366255 4.5        0.07469136] 0.38979013084640385
# call: [2.37098765 7.65432099 0.87201646 4.5        0.07469136] 0.3897983283424999
# call: [2.37098765 7.65432099 0.87283951 4.53703704 0.07469136] 0.3898159119349449
# call: [2.37098765 7.65432099 0.87283951 4.46296296 0.07469136] 0.3898136660722239
# call: [2.37098765 7.65432099 0.87283951 4.5        0.07510288] 0.38990605489624497
# call: [2.37098765 7.65432099 0.87283951 4.5        0.07427984] 0.38981876341663746
# call: [3.51666667 3.33333333 0.96666667 5.5        0.08333333] 0.485836216342021
# call: [1.58333333 3.33333333 0.96666667 5.5        0.08333333] 0.7769780512438129
# call: [2.55000000e+00 9.55555556e+00 9.00000000e-01 4.50000000e+00
#  5.55555556e-03] 0.4123937353857272
# call: [2.55000000e+00 6.44444444e+00 9.00000000e-01 4.50000000e+00
#  5.55555556e-03] 0.3987796018574356
# call: [2.55000000e+00 8.00000000e+00 9.22222222e-01 4.50000000e+00
#  5.55555556e-03] 0.3986215789642519
# call: [2.55000000e+00 8.00000000e+00 8.77777778e-01 4.50000000e+00
#  5.55555556e-03] 0.3981218405528301
# call: [2.22777778 8.         0.88518519 4.16666667 0.07592593] 0.3950444401316932
# call: [2.22777778 8.         0.88518519 4.16666667 0.06851852] 0.39504989189060435
# call: [2.37098765 7.48148148 0.87037037 4.27777778 0.06851852] 0.3900121062878965
# call: [2.29938272 7.48148148 0.87037037 4.27777778 0.06851852] 0.39059594191905783
# call: [2.33518519 7.65432099 0.87037037 4.27777778 0.06851852] 0.38986157084700096
# call: [2.33518519 7.30864198 0.87037037 4.27777778 0.06851852] 0.39033154292224953
# call: [2.33518519 7.48148148 0.87283951 4.27777778 0.06851852] 0.3899352533459743
# call: [2.33518519 7.48148148 0.86790123 4.27777778 0.06851852] 0.3899037770654641
# call: [2.33518519 7.48148148 0.87037037 4.27777778 0.06975309] 0.389943116902549
# call: [2.33518519 7.48148148 0.87037037 4.27777778 0.06728395] 0.3899150166565845
# call: [2.38292181 7.59670782 0.87283951 4.5        0.07469136] 0.3898304604112108
# call: [2.3590535  7.59670782 0.87283951 4.5        0.07469136] 0.3897220301233532
# call: [2.37098765 7.59670782 0.87366255 4.5        0.07469136] 0.3897322307116232
# call: [2.37098765 7.59670782 0.87201646 4.5        0.07469136] 0.3897220225803436
# call: [2.37098765 7.59670782 0.87283951 4.53703704 0.07469136] 0.3897507557692537
# call: [2.37098765 7.59670782 0.87283951 4.46296296 0.07469136] 0.3897441162971228
# call: [2.37098765 7.59670782 0.87283951 4.5        0.07510288] 0.3897256238933584
# call: [2.37098765 7.59670782 0.87283951 4.5        0.07427984] 0.3897153580864399
# call: [ 3.51666667 12.66666667  0.9         5.5         0.08333333] 0.515204422865081
# call: [ 1.58333333 12.66666667  0.9         5.5         0.08333333] 0.6967117544666148
# call: [2.55       9.55555556 0.9        4.5        0.02777778] 0.4122843120798835
# ...
# call: [2.87222222e+00 8.00000000e+00 9.88888889e-01 7.50000000e+00
#  5.55555556e-03] 0.4255649293223965
# call: [2.22777778 7.48148148 0.81851852 4.5        0.0537037 ] 0.3930999736342533
# call: [2.22777778 7.48148148 0.8037037  4.5        0.0537037 ] 0.39328419676100784
# call: [2.37098765 7.65432099 0.87037037 4.38888889 0.03271605] 0.38973675935197555
# call: [2.37098765 7.30864198 0.87037037 4.38888889 0.03271605] 0.39009533457331735
# call: [2.87222222 6.44444444 0.98888889 7.5        0.02777778] 0.42423340289590605
# call: [2.87222222e+00 6.44444444e+00 9.88888889e-01 7.50000000e+00
#  5.55555556e-03] 0.4241736995956451
# call: [2.33518519 8.         0.81851852 4.5        0.05      ] 0.3935464655092071
# call: [2.33518519 8.         0.8037037  4.5        0.05      ] 0.3941006151423041
# call: [2.33518519 8.         0.81111111 4.83333333 0.05      ] 0.3946502756891132
# call: [2.33518519 8.         0.81111111 4.16666667 0.05      ] 0.39335524637638775
# call: [2.33518519 8.         0.81111111 4.5        0.0537037 ] 0.3935049224062745
# call: [2.33518519 8.         0.81111111 4.5        0.0462963 ] 0.3935720418311876
# call: [2.37098765 7.48148148 0.87283951 4.5        0.03518519] 0.3897811501354861
# call: [2.29938272 7.48148148 0.87283951 4.5        0.03518519] 0.390173703806681
# call: [2.33518519 7.65432099 0.87283951 4.5        0.03518519] 0.38996313335751326
# call: [2.33518519 7.30864198 0.87283951 4.5        0.03518519] 0.39019339570218337
# call: [2.33518519 7.48148148 0.87283951 4.61111111 0.03518519] 0.38988894456643197
# call: [2.33518519 7.48148148 0.87283951 4.38888889 0.03518519] 0.3902605715460891
# call: [2.33518519 7.48148148 0.87283951 4.5        0.03641975] 0.38972235931258264
# call: [2.33518519 7.48148148 0.87283951 4.5        0.03395062] 0.38972062579476496
# call: [2.55       6.44444444 0.98888889 7.5        0.02777778] 0.427223764830598
# call: [2.55000000e+00 6.44444444e+00 9.88888889e-01 7.50000000e+00
#  5.55555556e-03] 0.42747932646489456
# call: [2.33518519 8.         0.81851852 4.16666667 0.05      ] 0.39318098789402806
# call: [2.33518519 8.         0.8037037  4.16666667 0.05      ] 0.39363708643051465
# call: [2.33518519 8.         0.81111111 4.16666667 0.0537037 ] 0.39337368340983847
# call: [2.33518519 8.         0.81111111 4.16666667 0.0462963 ] 0.3934372349999763
# call: [2.37098765 7.48148148 0.87283951 4.5        0.03395062] 0.3898292680059447
# call: [2.29938272 7.48148148 0.87283951 4.5        0.03395062] 0.39016406629525335
# call: [2.33518519 7.65432099 0.87283951 4.5        0.03395062] 0.39016554774587
# call: [2.33518519 7.30864198 0.87283951 4.5        0.03395062] 0.390197356458949
# call: [2.33518519 7.48148148 0.87283951 4.61111111 0.03395062] 0.3900228162410039
# call: [2.33518519 7.48148148 0.87283951 4.38888889 0.03395062] 0.3897362939887355
# call: [2.87222222 8.         0.98888889 7.5        0.05      ] 0.42536112309654517
# call: [2.22777778 8.         0.98888889 7.5        0.05      ] 0.44944416669297993
# call: [2.55       9.55555556 0.98888889 7.5        0.05      ] 0.4428766509479885
# call: [2.55       6.44444444 0.98888889 7.5        0.05      ] 0.42750712006711433
# call: [2.55       8.         0.98888889 7.5        0.06111111] 0.42760660805504647
# call: [2.55       8.         0.98888889 7.5        0.03888889] 0.42731719065486073
# call: [2.33518519 8.         0.81851852 4.16666667 0.0537037 ] 0.3931938162385078
# call: [2.33518519 8.         0.81851852 4.16666667 0.0462963 ] 0.39316777242977524
# call: [2.37098765 7.48148148 0.87283951 4.5        0.03641975] 0.38976585756863347
# call: [2.29938272 7.48148148 0.87283951 4.5        0.03641975] 0.3901505467826091
# call: [2.33518519 7.65432099 0.87283951 4.5        0.03641975] 0.38996506891234123
# call: [2.33518519 7.30864198 0.87283951 4.5        0.03641975] 0.3901723781596459
# call: [2.33518519 7.48148148 0.87283951 4.61111111 0.03641975] 0.38988893570136457
# call: [2.33518519 7.48148148 0.87283951 4.38888889 0.03641975] 0.3901730144792329
# call: [2.87222222 9.55555556 0.98888889 7.5        0.05      ] 0.4419746735824483
# call: [2.87222222 6.44444444 0.98888889 7.5        0.05      ] 0.4244058251288033
# call: [2.87222222 8.         0.98888889 7.5        0.06111111] 0.42540031306994674
# call: [2.87222222 8.         0.98888889 7.5        0.03888889] 0.42537905044298374
# call: [2.33518519 8.         0.81851852 4.5        0.0537037 ] 0.3934893559100414
# call: [2.33518519 8.         0.8037037  4.5        0.0537037 ] 0.39378580224167253
# call: [2.37098765 7.48148148 0.87283951 4.38888889 0.03395062] 0.38971058441293976
# call: [2.29938272 7.48148148 0.87283951 4.38888889 0.03395062] 0.39052606234403847
# call: [2.33518519 7.65432099 0.87283951 4.38888889 0.03395062] 0.3897293411426607
# call: [2.33518519 7.30864198 0.87283951 4.38888889 0.03395062] 0.39037304935982536
# call: [2.87222222 6.44444444 0.98888889 7.5        0.06111111] 0.42444445174463585
# call: [2.87222222 6.44444444 0.98888889 7.5        0.03888889] 0.4243135384326357
# call: [2.33518519 8.         0.81851852 4.5        0.0462963 ] 0.3933001751913784
# call: [2.33518519 8.         0.8037037  4.5        0.0462963 ] 0.3940317556201596
# call: [2.37098765 7.65432099 0.87283951 4.38888889 0.03395062] 0.3897647259700121
# call: [2.37098765 7.30864198 0.87283951 4.38888889 0.03395062] 0.39010340385843745
# call: [2.55       9.55555556 0.98888889 7.5        0.03888889] 0.44261173352501393
# call: [2.55       6.44444444 0.98888889 7.5        0.03888889] 0.4271671888077393
# call: [2.33518519 8.         0.8037037  4.16666667 0.0537037 ] 0.3935829708872755
# call: [2.33518519 8.         0.8037037  4.16666667 0.0462963 ] 0.3936195321759944
# call: [2.37098765 7.65432099 0.87283951 4.5        0.03641975] 0.38970854003692096
# call: [2.37098765 7.30864198 0.87283951 4.5        0.03641975] 0.3900934689658026
# call: [2.37098765 7.48148148 0.87283951 4.61111111 0.03641975] 0.3897471927441659
# call: [2.37098765 7.48148148 0.87283951 4.38888889 0.03641975] 0.3896837815975696
# call: [2.55       9.55555556 0.98888889 7.5        0.06111111] 0.4427213497550137
# call: [2.55       6.44444444 0.98888889 7.5        0.06111111] 0.42773727021569585
# call: [2.22777778 7.48148148 0.81851852 4.83333333 0.05      ] 0.39502053954529076
# call: [2.22777778 7.48148148 0.8037037  4.83333333 0.05      ] 0.3946810360895578
# call: [2.22777778 7.48148148 0.81111111 4.83333333 0.0537037 ] 0.3945652091069116
# call: [2.22777778 7.48148148 0.81111111 4.83333333 0.0462963 ] 0.3945395149007772
# call: [2.37098765 7.65432099 0.87283951 4.38888889 0.03641975] 0.3897606508400065
# call: [2.37098765 7.30864198 0.87283951 4.38888889 0.03641975] 0.39016793689704926
# call: [2.87222222 8.         0.98888889 7.5        0.08333333] 0.4256508403125939
# call: [2.22777778 8.         0.98888889 7.5        0.08333333] 0.44974455889733367
# call: [2.55       9.55555556 0.98888889 7.5        0.08333333] 0.4428600708301115
# call: [2.55       6.44444444 0.98888889 7.5        0.08333333] 0.4275504351414134
# call: [2.55       8.         0.98888889 7.5        0.09444444] 0.4277434682338879
# call: [2.55       8.         0.98888889 7.5        0.07222222] 0.42754248420065605
# call: [2.22777778 7.48148148 0.81851852 4.83333333 0.0462963 ] 0.3944417394259217
# call: [2.22777778 7.48148148 0.8037037  4.83333333 0.0462963 ] 0.39467516549138726
# call: [2.37098765 7.65432099 0.87283951 4.61111111 0.03641975] 0.38983345347685905
# call: [2.37098765 7.30864198 0.87283951 4.61111111 0.03641975] 0.390336050689821
# call: [2.87222222 9.55555556 0.98888889 7.5        0.08333333] 0.44209882438570103
# call: [2.87222222 6.44444444 0.98888889 7.5        0.08333333] 0.42461785482763137
# call: [2.87222222 8.         0.98888889 7.5        0.09444444] 0.42555614348056064
# call: [2.87222222 8.         0.98888889 7.5        0.07222222] 0.4254619436456761
# call: [2.22777778 7.48148148 0.81851852 4.83333333 0.0537037 ] 0.3947389537819035
# call: [2.22777778 7.48148148 0.8037037  4.83333333 0.0537037 ] 0.39520916747679646
# call: [2.37098765 7.65432099 0.87037037 4.5        0.0154321 ] 0.389893664533129
# call: [2.37098765 7.30864198 0.87037037 4.5        0.0154321 ] 0.39002365069645256
# call: [2.87222222 6.44444444 0.98888889 7.5        0.09444444] 0.4247091272713501
# call: [2.87222222 6.44444444 0.98888889 7.5        0.07222222] 0.42491278950875366
# call: [2.33518519 8.         0.81851852 4.83333333 0.05      ] 0.3944018622814729
# call: [2.33518519 8.         0.8037037  4.83333333 0.05      ] 0.39519333616897845
# call: [2.33518519 8.         0.81111111 4.83333333 0.0537037 ] 0.39488598644435
# call: [2.33518519 8.         0.81111111 4.83333333 0.0462963 ] 0.39479328329037755
# call: [2.37098765 7.48148148 0.87777778 4.5        0.03148148] 0.389792635055705
# call: [2.29938272 7.48148148 0.87777778 4.5        0.03148148] 0.39019443722626096
# call: [2.33518519 7.65432099 0.87777778 4.5        0.03148148] 0.3899347756423741
# call: [2.33518519 7.30864198 0.87777778 4.5        0.03148148] 0.3902206195652468
# call: [2.33518519 7.48148148 0.88024691 4.5        0.03148148] 0.3897702317935844
# call: [2.33518519 7.48148148 0.87530864 4.5        0.03148148] 0.3897031969456924
# call: [2.33518519 7.48148148 0.87777778 4.61111111 0.03148148] 0.38990068181223736
# call: [2.33518519 7.48148148 0.87777778 4.38888889 0.03148148] 0.3897052583333824
# call: [2.33518519 7.48148148 0.87777778 4.5        0.03271605] 0.3897477597121287
# call: [2.33518519 7.48148148 0.87777778 4.5        0.03024691] 0.38976854059485727
# call: [2.55       9.55555556 0.98888889 7.5        0.07222222] 0.4429296695856848
# call: [2.55       6.44444444 0.98888889 7.5        0.07222222] 0.4274914334938763
# call: [2.33518519 8.         0.81851852 4.83333333 0.0537037 ] 0.39441088652989936
# call: [2.33518519 8.         0.81851852 4.83333333 0.0462963 ] 0.3947353531062024
# call: [2.37098765 7.48148148 0.87530864 4.5        0.03148148] 0.3903535862676363
# call: [2.29938272 7.48148148 0.87530864 4.5        0.03148148] 0.3902486659375042
# call: [2.33518519 7.65432099 0.87530864 4.5        0.03148148] 0.39004985814716964
# call: [2.33518519 7.30864198 0.87530864 4.5        0.03148148] 0.3902634064370866
# call: [2.33518519 7.48148148 0.87530864 4.61111111 0.03148148] 0.38989540684441276
# call: [2.33518519 7.48148148 0.87530864 4.38888889 0.03148148] 0.38972824120211996
# call: [2.33518519 7.48148148 0.87530864 4.5        0.03271605] 0.38972577288969495
# call: [2.33518519 7.48148148 0.87530864 4.5        0.03024691] 0.38970854412840067
# call: [2.55       9.55555556 0.98888889 7.5        0.09444444] 0.44289176190380686
# call: [2.55       6.44444444 0.98888889 7.5        0.09444444] 0.4276366181234848
# call: [2.22777778 8.         0.81851852 4.16666667 0.05      ] 0.3949428633818551
# call: [2.22777778 8.         0.8037037  4.16666667 0.05      ] 0.3950579028451914
# call: [2.22777778 8.         0.81111111 4.16666667 0.0537037 ] 0.3949372528637249
# call: [2.22777778 8.         0.81111111 4.16666667 0.0462963 ] 0.39500594488747764
# call: [2.37098765 7.48148148 0.87777778 4.38888889 0.03148148] 0.38973725307806406
# call: [2.29938272 7.48148148 0.87777778 4.38888889 0.03148148] 0.390593299347928
# call: [2.33518519 7.65432099 0.87777778 4.38888889 0.03148148] 0.3897589862384802
# call: [2.33518519 7.30864198 0.87777778 4.38888889 0.03148148] 0.3901864229711872
# call: [2.33518519 7.48148148 0.87777778 4.38888889 0.03271605] 0.39008558568089285
# call: [2.33518519 7.48148148 0.87777778 4.38888889 0.03024691] 0.38994297985066945
# call: [2.87222222 9.55555556 0.83333333 6.5        0.08333333] 0.44186140598290496
# call: [2.22777778 9.55555556 0.83333333 6.5        0.08333333] 0.4296822422867691
# call: [2.55       9.55555556 0.83333333 6.5        0.09444444] 0.4277254438959374
# call: [2.55       9.55555556 0.83333333 6.5        0.07222222] 0.4278840840687743
# call: [2.22777778 8.         0.81851852 4.16666667 0.0537037 ] 0.3949549283275074
# call: [2.22777778 8.         0.8037037  4.16666667 0.0537037 ] 0.39512204758345626
# call: [2.37098765 7.48148148 0.87530864 4.5        0.03024691] 0.38979604446592775
# call: [2.29938272 7.48148148 0.87530864 4.5        0.03024691] 0.39029817218892515
# call: [2.33518519 7.65432099 0.87530864 4.5        0.03024691] 0.38984231557142024
# call: [2.33518519 7.30864198 0.87530864 4.5        0.03024691] 0.39020102418234015
# call: [2.33518519 7.48148148 0.87530864 4.61111111 0.03024691] 0.39001108641033205
# call: [2.33518519 7.48148148 0.87530864 4.38888889 0.03024691] 0.3898273160260031
# call: [2.87222222 9.55555556 0.83333333 6.5        0.09444444] 0.44144430711200955
# call: [2.22777778 9.55555556 0.83333333 6.5        0.09444444] 0.4294922288063093
# call: [2.22777778 8.         0.81851852 4.16666667 0.0462963 ] 0.39494893609982046
# call: [2.22777778 8.         0.8037037  4.16666667 0.0462963 ] 0.39505149284311736
# call: [2.37098765 7.48148148 0.87530864 4.5        0.03271605] 0.38978270310960983
# call: [2.29938272 7.48148148 0.87530864 4.5        0.03271605] 0.3901576477344201
# call: [2.33518519 7.65432099 0.87530864 4.5        0.03271605] 0.39004334626320053
# call: [2.33518519 7.30864198 0.87530864 4.5        0.03271605] 0.3902088907516254
# call: [2.33518519 7.48148148 0.87530864 4.61111111 0.03271605] 0.3898845317175429
# call: [2.33518519 7.48148148 0.87530864 4.38888889 0.03271605] 0.39008842791685994
# call: [2.87222222 9.55555556 0.83333333 6.5        0.07222222] 0.4420464443113499
# call: [2.22777778 9.55555556 0.83333333 6.5        0.07222222] 0.4295279131821125
# call: [2.33518519 8.         0.8037037  4.83333333 0.0537037 ] 0.395095900949593
# call: [2.33518519 8.         0.8037037  4.83333333 0.0462963 ] 0.3950970443453872
# call: [2.37098765 7.48148148 0.87530864 4.38888889 0.03148148] 0.3897019076008662
# call: [2.29938272 7.48148148 0.87530864 4.38888889 0.03148148] 0.39053759476972594
# call: [2.33518519 7.65432099 0.87530864 4.38888889 0.03148148] 0.3896988280361199
# call: [2.33518519 7.30864198 0.87530864 4.38888889 0.03148148] 0.3901688379804071
# call: [2.87222222 9.55555556 0.83333333 6.5        0.05      ] 0.4421133553443603
# call: [2.22777778 9.55555556 0.83333333 6.5        0.05      ] 0.4295342752309786
# call: [2.55       9.55555556 0.83333333 6.5        0.06111111] 0.42791846296038755
# call: [2.55       9.55555556 0.83333333 6.5        0.03888889] 0.4280748696810112
# call: [2.22777778 8.         0.81851852 4.5        0.0462963 ] 0.3955078311100548
# call: [2.22777778 8.         0.8037037  4.5        0.0462963 ] 0.3957631620651248
# call: [2.37098765 7.65432099 0.87530864 4.38888889 0.03148148] 0.3897854864346999
# call: [2.29938272 7.65432099 0.87530864 4.38888889 0.03148148] 0.39011276311520265
# call: [2.87222222 9.55555556 0.83333333 6.5        0.06111111] 0.44200149186871157
# call: [2.22777778 9.55555556 0.83333333 6.5        0.06111111] 0.42950840482845065
# call: [2.33518519e+00 8.00000000e+00 9.00000000e-01 4.50000000e+00
#  5.55555556e-03] 0.3923007692705522
# call: [2.12037037e+00 8.00000000e+00 9.00000000e-01 4.50000000e+00
#  5.55555556e-03] 0.4053960979009516
# call: [2.22777778e+00 8.51851852e+00 9.00000000e-01 4.50000000e+00
#  5.55555556e-03] 0.3994029546366475
# call: [2.22777778e+00 7.48148148e+00 9.00000000e-01 4.50000000e+00
#  5.55555556e-03] 0.39388941792130766
# call: [2.22777778e+00 8.00000000e+00 9.07407407e-01 4.50000000e+00
#  5.55555556e-03] 0.39602730949852283
# call: [2.22777778e+00 8.00000000e+00 8.92592593e-01 4.50000000e+00
#  5.55555556e-03] 0.3957295279353087
# call: [2.22777778e+00 8.00000000e+00 9.00000000e-01 4.83333333e+00
#  5.55555556e-03] 0.39699614628182245
# call: [2.22777778e+00 8.00000000e+00 9.00000000e-01 4.16666667e+00
#  5.55555556e-03] 0.39544231536614105
# call: [2.22777778 8.         0.9        4.5        0.00925926] 0.39569047518761075
# call: [2.22777778e+00 8.00000000e+00 9.00000000e-01 4.50000000e+00
#  1.85185185e-03] 0.3959550659830218
# call: [2.37098765 7.65432099 0.87777778 4.38888889 0.03148148] 0.3897156272556405
# call: [2.37098765 7.30864198 0.87777778 4.38888889 0.03148148] 0.39020066833580214
# call: [2.37098765 7.48148148 0.87777778 4.38888889 0.03271605] 0.389733868040953
# call: [2.37098765 7.48148148 0.87777778 4.38888889 0.03024691] 0.38987011669849253

# %%
res
# Out:
#  message: Optimization terminated successfully.
#  success: True
#      fun: 0.3581448514255309
#     funl: [ 3.581e-01]
#        x: [ 2.923e+00  1.201e+00  7.320e-01  1.500e+00  4.021e-07]
#       xl: [[ 2.923e+00  1.201e+00  7.320e-01  1.500e+00  4.021e-07]]
#      nit: 1
#     nfev: 1162
#    nlfev: 1129
#    nljev: 100
#    nlhev: 0

# %%
res2
# Out:
#  message: Number of function evaluations done is larger than maxfun=10000
#  success: False
#   status: 1
#      fun: 0.3894589236541129
#        x: [ 2.347e+00  7.481e+00  8.597e-01  4.352e+00  6.859e-05]
#      nit: 962
#     nfev: 10007

# %%
plt.scatter(np.arange(10, 60, 5), res)
plt.show()

# %%
xs = np.arange(0, 10, 0.25)
mses = [get_acc((3.034e+00, 7.390e+00, 9.444e-01, a, 1.075e-03)) for a in xs]
# Out:
# call: (3.034, 7.39, 0.9444, 0.0, 0.001075) 0.4703094519796116
# call: (3.034, 7.39, 0.9444, 0.25, 0.001075) 0.3909731592957304
# call: (3.034, 7.39, 0.9444, 0.5, 0.001075) 0.3639903658527475
# call: (3.034, 7.39, 0.9444, 0.75, 0.001075) 0.34597978472156893
# call: (3.034, 7.39, 0.9444, 1.0, 0.001075) 0.33259369421307927
# call: (3.034, 7.39, 0.9444, 1.25, 0.001075) 0.32215529822180866
# call: (3.034, 7.39, 0.9444, 1.5, 0.001075) 0.3138728679782513
# call: (3.034, 7.39, 0.9444, 1.75, 0.001075) 0.30740538908494497
# call: (3.034, 7.39, 0.9444, 2.0, 0.001075) 0.3018336385975317
# call: (3.034, 7.39, 0.9444, 2.25, 0.001075) 0.297656436872067
# call: (3.034, 7.39, 0.9444, 2.5, 0.001075) 0.2940681115237744
# call: (3.034, 7.39, 0.9444, 2.75, 0.001075) 0.2913303518381439
# call: (3.034, 7.39, 0.9444, 3.0, 0.001075) 0.2892499463205639
# call: (3.034, 7.39, 0.9444, 3.25, 0.001075) 0.28769621835648035
# call: (3.034, 7.39, 0.9444, 3.5, 0.001075) 0.28669662423029646
# call: (3.034, 7.39, 0.9444, 3.75, 0.001075) 0.286255177396336
# call: (3.034, 7.39, 0.9444, 4.0, 0.001075) 0.28596365401936147
# call: (3.034, 7.39, 0.9444, 4.25, 0.001075) 0.2861012693073419
# call: (3.034, 7.39, 0.9444, 4.5, 0.001075) 0.28668061880049595
# call: (3.034, 7.39, 0.9444, 4.75, 0.001075) 0.28752544831002214
# call: (3.034, 7.39, 0.9444, 5.0, 0.001075) 0.28851638200420543
# call: (3.034, 7.39, 0.9444, 5.25, 0.001075) 0.289903259118075
# call: (3.034, 7.39, 0.9444, 5.5, 0.001075) 0.2914706856269081
# call: (3.034, 7.39, 0.9444, 5.75, 0.001075) 0.293325470083296
# call: (3.034, 7.39, 0.9444, 6.0, 0.001075) 0.29540896127397365
# call: (3.034, 7.39, 0.9444, 6.25, 0.001075) 0.2976900674598683
# call: (3.034, 7.39, 0.9444, 6.5, 0.001075) 0.30017087394485764
# call: (3.034, 7.39, 0.9444, 6.75, 0.001075) 0.30282430074559885
# call: (3.034, 7.39, 0.9444, 7.0, 0.001075) 0.3056663440265682
# call: (3.034, 7.39, 0.9444, 7.25, 0.001075) 0.30871280540761903
# call: (3.034, 7.39, 0.9444, 7.5, 0.001075) 0.3120831554269884
# call: (3.034, 7.39, 0.9444, 7.75, 0.001075) 0.3153500526357512
# call: (3.034, 7.39, 0.9444, 8.0, 0.001075) 0.3186930926644596
# call: (3.034, 7.39, 0.9444, 8.25, 0.001075) 0.3223537649834551
# call: (3.034, 7.39, 0.9444, 8.5, 0.001075) 0.32630564909551363
# call: (3.034, 7.39, 0.9444, 8.75, 0.001075) 0.3300990346980822
# call: (3.034, 7.39, 0.9444, 9.0, 0.001075) 0.3341979496739707
# call: (3.034, 7.39, 0.9444, 9.25, 0.001075) 0.33836666948010624
# call: (3.034, 7.39, 0.9444, 9.5, 0.001075) 0.34268545682275675
# call: (3.034, 7.39, 0.9444, 9.75, 0.001075) 0.3472619091859287

# %%
plt.scatter(xs, mses)
plt.show()

# %%
from analysis.analyzer import SongAnalyzer
from analysis.hash import get_hash
import math
from typing import Iterable, Iterator
from collections import deque

SPACING = 1
SUPPORT_RADIUS = 1.5 * SPACING
def _kernel(x):
    x = (x / SPACING) + 1.5
    if x <= 1:
        y = x * x / 2
    elif x <= 2:
        y = (2 - x) * (x - 1) + 0.5
    else:
        x = x - 3
        y = x * x / 2
    return y / SPACING

def get_seq(note_times: Iterable[float]) -> Iterator[float]:
    note_times = iter(note_times)
    queue = deque()
    # raises StopIteration if note_times is empty, which is desired
    first = next(note_times, None)
    if first is None:
        return
    sample_loc = math.ceil((first - SUPPORT_RADIUS) / SPACING) * SPACING
    queue.append(first)
    while queue:
        lbound = sample_loc - SUPPORT_RADIUS
        rbound = sample_loc + SUPPORT_RADIUS
        # add new notes, ensuring last note in queue is beyond the
        # window, if possible
        if queue[-1] < rbound:
            next_note = next(note_times, None)
            while next_note is not None and next_note < rbound:
                queue.append(next_note)
                next_note = next(note_times, None)
            if next_note is not None:
                queue.append(next_note)
        # clear old notes
        while queue and queue[0] < lbound:
            queue.popleft()

        accum = 0
        for time in queue:
            if time < rbound:
                accum += _kernel(sample_loc - time)
        yield accum
        sample_loc += SPACING

def handle_song(song, pack_name, seen_hashes):
    data = []
    song_analyzer = SongAnalyzer(song)
    song_str = f'{pack_name}/{song.title or ""}'

    for chart_analyzer in song_analyzer.chart_analyzers.values():
        chart = chart_analyzer.chart
        if (chart.stepstype or '').lower() != 'dance-single':
            continue
        diff = (chart.difficulty or '').lower()
        title = song_str
        if diff != 'challenge':
            title += f' ({diff})'

        chart_hash = get_hash(song, chart_analyzer.chart)
        if chart_hash in seen_hashes:
            print(f'skipping {title} (dupe hash)')
            continue
        seen_hashes.add(chart_hash)
        print(f'analyzing {title}')
        try:
            meter = int(chart_analyzer.chart.meter)
        except ValueError:
            print(song.title, ': invalid meter')
            continue

        note_times = chart_analyzer.get_note_times()
        seq = list(get_seq(note_times))
        if not seq:
            print(title, ': empty?')
            continue
        # print(seq)

        data.append((
            title,
            chart_hash,
            meter,
            str(seq)
        ))
    return data
# Out:
# c:\Users\Lenovo\Documents\code_projs\itg-difficulty-predictor\notebooks\.venv\Lib\site-packages\fs\__init__.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   __import__("pkg_resources").declare_namespace(__name__)  # type: ignore

# %%
def make_seq(bpm, measures):
    nps = bpm / 60 * 4
    length = math.floor(60 / bpm * 4 * measures + 1)
    last_val = 16*measures - nps*(length-1)
    arr = [nps] * length
    arr[-1] = last_val
    return np.array(arr)

seq = make_seq(500, 379)
p = predictor.to_score(seq)
print(predictor.predict_weighted_avg(np.array([[p]]), True) + 0.5)

for b in range(700, 800, 5):
    seq = make_seq(b, 32)
    p = predictor.to_score(seq)
    print(b, predictor.predict_weighted_avg(np.array([[p]]), True) + 0.5)
# Out:
# [49.34353034]
# 700 [69.4392583]
# 705 [70.09487988]
# 710 [70.76980268]
# 715 [71.46676255]
# 720 [72.16209587]
# 725 [72.84401959]
# 730 [73.54369322]
# 735 [74.25112181]
# 740 [74.94261485]
# 745 [75.64274952]
# 750 [76.35978051]
# 755 [77.06523443]
# 760 [77.76636673]
# 765 [78.48715901]
# 770 [79.08417134]
# 775 [79.76132666]
# 780 [80.48897801]
# 785 [81.21842732]
# 790 [81.93449076]
# 795 [82.65922156]

# %%
params
# Out:
# [2.387, 7.309, 0.9702, 4.66, 0.004047]

# %%
RESOLUTION = 100
STREAM_BOUNDS = (0, 16)
BPM_BOUNDS = (10, 600)
x, y = np.meshgrid(
    np.linspace(BPM_BOUNDS[0], BPM_BOUNDS[1], RESOLUTION),
    np.linspace(STREAM_BOUNDS[0], STREAM_BOUNDS[1], RESOLUTION)
)
inp = np.reshape(np.dstack((x, y)), (-1, 2))
scores = []
for item in inp:
    seq = make_seq(item[0], 2**item[1])
    score = predict_one(seq, *params)
    scores.append(score)
image = predictor.predict_weighted_avg(np.asarray(scores).reshape((-1, 1)), extrapolate=True)
image = image.reshape((RESOLUTION, RESOLUTION))

# %%
import matplotlib
from matplotlib.colors import ListedColormap, Normalize

vmin = np.min(image)
vmax = np.max(image)
print(vmin, vmax)
norm = Normalize(vmin=vmin-0.5, vmax=vmax+0.5)
#norm = Normalize(vmin=0, vmax=70)
cmap = matplotlib.colormaps['rainbow']
#cmap = ListedColormap(cmap(np.linspace(0, 7, int(500)) % 1))
cmap = ListedColormap(cmap(np.linspace(0, round(vmax-vmin+1)/10, int(vmax-vmin+1)) % 1))
# cmap = matplotlib.colormaps['viridis']

fig = plt.figure()
ax = fig.add_subplot()

#ax.view_init(elev=90, azim=-90, roll=0)
ax.set_xlabel('BPM')
ax.set_ylabel('Log2 of stream')
#ax.set_zlabel('Density')
pos = ax.imshow(image, origin='lower', cmap=cmap, alpha=1, extent=(*BPM_BOUNDS, *STREAM_BOUNDS),
          aspect='auto', norm=norm)
fig.colorbar(pos)
plt.show()
# Out:
# 1.0011568568155313 74.26563888442803

# %% [markdown]
# ## Chart tests

# %%
from simfile.dir import SimfilePack
import simfile
import glob

columns = ['Name', 'Hash', 'Meter', 'Seq']

glob_path = r"C:\Users\Lenovo\AppData\Roaming\ITGmania\Songs\Stamina RPG 9 Unlocks"
#glob_path = r'pack_archive\BLACKLIGHT'
real_test_data = []
seen_hashes = set()
for path in glob.glob(glob_path):
     pack = SimfilePack(path)
     for song in pack.simfiles(strict=False):
          real_test_data.extend(handle_song(song, pack.name, seen_hashes))

#song = simfile.open(r'C:\Users\Lenovo\AppData\Roaming\ITGmania\Songs\BemaniBeats 6\Deadly force\deadly.sm')
#real_test_data.extend(handle_song(song, '_misc', seen_hashes))

test_df = pd.DataFrame(real_test_data, columns=columns)
test_data = ChartDataset(test_df)
# Out:
# analyzing Stamina RPG 9 Unlocks/[11] [146] GDFR
# analyzing Stamina RPG 9 Unlocks/[11] [135] mnemonic
# analyzing Stamina RPG 9 Unlocks/[12] [143] another station
# analyzing Stamina RPG 9 Unlocks/[12] [128] BUNGEE
# analyzing Stamina RPG 9 Unlocks/[12] [135] Datamania
# analyzing Stamina RPG 9 Unlocks/[12] [156] Happily Ever After (Hard)
# analyzing Stamina RPG 9 Unlocks/[12] [150] Here We Go
# analyzing Stamina RPG 9 Unlocks/[12] [142] Megitsune
# analyzing Stamina RPG 9 Unlocks/[12] [175] My My My (Hard)
# analyzing Stamina RPG 9 Unlocks/[12] [137] Patchwork Eden
# analyzing Stamina RPG 9 Unlocks/[12] [164] Rookie (Hard)
# analyzing Stamina RPG 9 Unlocks/[12] [222] Say So
# analyzing Stamina RPG 9 Unlocks/[12] [220] The End (Feat. BABYMETAL)
# analyzing Stamina RPG 9 Unlocks/[12] [128] Winke Verkackt Aufpassen
# analyzing Stamina RPG 9 Unlocks/[12] [164] XIII
# analyzing Stamina RPG 9 Unlocks/[12] [176] You Will Know Our Names
# analyzing Stamina RPG 9 Unlocks/[13] [191] A
# analyzing Stamina RPG 9 Unlocks/[13] [145] EVERGREEN
# analyzing Stamina RPG 9 Unlocks/[13] [180] Firstmode
# analyzing Stamina RPG 9 Unlocks/[13] [128] Girls Night (Hard)
# analyzing Stamina RPG 9 Unlocks/[13] [158] Him
# analyzing Stamina RPG 9 Unlocks/[13] [174] Icarus
# analyzing Stamina RPG 9 Unlocks/[13] [146] Insane Techniques
# analyzing Stamina RPG 9 Unlocks/[13] [152] Must Be Dreaming
# analyzing Stamina RPG 9 Unlocks/[13] [160] Nihongo Hardbass
# analyzing Stamina RPG 9 Unlocks/[13] [244] No Tears Left to Cry
# analyzing Stamina RPG 9 Unlocks/[13] [145] PARANOiA Survivivivivivor MAX
# analyzing Stamina RPG 9 Unlocks/[13] [175] Regeneraxion
# analyzing Stamina RPG 9 Unlocks/[13] [138] Release
# analyzing Stamina RPG 9 Unlocks/[13] [184] Rintoshite Junjou
# analyzing Stamina RPG 9 Unlocks/[13] [165] She Grew Wings
# analyzing Stamina RPG 9 Unlocks/[14] [140] 3o3o3o3
# analyzing Stamina RPG 9 Unlocks/[14] [174] B L A C K - R A Y
# analyzing Stamina RPG 9 Unlocks/[14] [180] Blazin'
# analyzing Stamina RPG 9 Unlocks/[14] [270] Diabolic Enemy
# analyzing Stamina RPG 9 Unlocks/[14] [149] ETERNAL DRAIN
# analyzing Stamina RPG 9 Unlocks/[14] [202] Faster Than You!!!
# analyzing Stamina RPG 9 Unlocks/[14] [160] FestA of PandemoniuM
# analyzing Stamina RPG 9 Unlocks/[14] [150] FREEDOM DiVE
# analyzing Stamina RPG 9 Unlocks/[14] [160] Hana Ranman -Flowers-
# analyzing Stamina RPG 9 Unlocks/[14] [216] Jalaana
# analyzing Stamina RPG 9 Unlocks/[14] [192] Let me be your cure
# analyzing Stamina RPG 9 Unlocks/[14] [165] Party At
# analyzing Stamina RPG 9 Unlocks/[14] [156] Riding On The Wings
# analyzing Stamina RPG 9 Unlocks/[14] [175] Time Bomb
# analyzing Stamina RPG 9 Unlocks/[14] [136] What's Happenin' Forum?
# analyzing Stamina RPG 9 Unlocks/[14] [128] WORLD OF FANTASY
# analyzing Stamina RPG 9 Unlocks/[15] [240] ANU
# analyzing Stamina RPG 9 Unlocks/[15] [180] Baka Mitai
# analyzing Stamina RPG 9 Unlocks/[15] [205] Boku no yume, mechakuso mugen waki
# analyzing Stamina RPG 9 Unlocks/[15] [256] Chaos Time the DARK
# analyzing Stamina RPG 9 Unlocks/[15] [175] dica dica
# analyzing Stamina RPG 9 Unlocks/[15] [180] Duvet
# analyzing Stamina RPG 9 Unlocks/[15] [174] Feelin Sky
# analyzing Stamina RPG 9 Unlocks/[15] [200] Gateway to Psycho
# analyzing Stamina RPG 9 Unlocks/[15] [195] Gintlemen's Club
# analyzing Stamina RPG 9 Unlocks/[15] [170] Helicopter
# analyzing Stamina RPG 9 Unlocks/[15] [168] Kitsune Maison Freestyle
# analyzing Stamina RPG 9 Unlocks/[15] [160] SETUP SINOBUZ
# analyzing Stamina RPG 9 Unlocks/[15] [154] Synthesized [Part 5]
# analyzing Stamina RPG 9 Unlocks/[15] [140] Trails of Slow Stream
# analyzing Stamina RPG 9 Unlocks/[16] [228] c0pyf0x
# analyzing Stamina RPG 9 Unlocks/[16] [194] :3c
# analyzing Stamina RPG 9 Unlocks/[16] [147] Dancemania presents... E-Rotic Megamix
# analyzing Stamina RPG 9 Unlocks/[16] [170] Hell Hath No Fury
# analyzing Stamina RPG 9 Unlocks/[16] [190] Magenta
# analyzing Stamina RPG 9 Unlocks/[16] [138] Not Another Trance Mix
# analyzing Stamina RPG 9 Unlocks/[16] [153] or not to {b}e
# analyzing Stamina RPG 9 Unlocks/[16] [210] Snapping
# analyzing Stamina RPG 9 Unlocks/[16] [170] The Wind of Gold
# analyzing Stamina RPG 9 Unlocks/[16] [190] Time to Make History
# analyzing Stamina RPG 9 Unlocks/[17] [165] chill weeb shit
# analyzing Stamina RPG 9 Unlocks/[17] [155] Exospace Expedition
# analyzing Stamina RPG 9 Unlocks/[17] [168] ITC Jams EXTRA STAGE
# analyzing Stamina RPG 9 Unlocks/[17] [174] Liquid Bangers Mixtape
# analyzing Stamina RPG 9 Unlocks/[17] [195] Loli Bomb
# analyzing Stamina RPG 9 Unlocks/[17] [174] Makoto Essential Mix
# analyzing Stamina RPG 9 Unlocks/[17] [220] Need The Speed
# analyzing Stamina RPG 9 Unlocks/[17] [186] No Church In The Wild
# analyzing Stamina RPG 9 Unlocks/[17] [225] TurboFunk
# analyzing Stamina RPG 9 Unlocks/[18] [232] Baroke Bit
# analyzing Stamina RPG 9 Unlocks/[18] [180] Conclusio Catastropha
# analyzing Stamina RPG 9 Unlocks/[18] [182] Omnipresent
# analyzing Stamina RPG 9 Unlocks/[18] [170] TIMELESS BEATZ
# analyzing Stamina RPG 9 Unlocks/[18] [180] Upon the Wanderer's Path
# analyzing Stamina RPG 9 Unlocks/[19] [175] Camellia 2hrs+ 175BPM mix
# analyzing Stamina RPG 9 Unlocks/[19] [195] XXXV
# analyzing Stamina RPG 9 Unlocks/[20] [200] RS Ultralaiza XX
# analyzing Stamina RPG 9 Unlocks/[21] [208] Double Cheese With Added Cheese
# analyzing Stamina RPG 9 Unlocks/[22] [225] The Almanac
# analyzing Stamina RPG 9 Unlocks/[23] [272] Knives
# analyzing Stamina RPG 9 Unlocks/[23] [214] STARSTORM
# analyzing Stamina RPG 9 Unlocks/[23] [230] TeenaJ Mutant Patterned Hardcore
# analyzing Stamina RPG 9 Unlocks/[24] [230] cataclysm
# analyzing Stamina RPG 9 Unlocks/[25] [240] Get Delinsed
# analyzing Stamina RPG 9 Unlocks/[26] [260] The Biggest Beat
# analyzing Stamina RPG 9 Unlocks/[27] [270] In Memoriam (Side B)
# analyzing Stamina RPG 9 Unlocks/[27] [259] PetroDragonic Apocalypse (Continuous Mix)
# analyzing Stamina RPG 9 Unlocks/[28] [260] Doomsday
# analyzing Stamina RPG 9 Unlocks/[28] [318] You Don't Know What
# analyzing Stamina RPG 9 Unlocks/[29] [280] Arc Stream Works: Full Meter
# analyzing Stamina RPG 9 Unlocks/[29] [291] BIGSTAMINA SHARPNEL (part 4)
# analyzing Stamina RPG 9 Unlocks/[30] [300] BIGSTAMINA SHARPNEL (part 5)
# analyzing Stamina RPG 9 Unlocks/[31] [290] PATH OF THE GREATS
# analyzing Stamina RPG 9 Unlocks/[31] [310] Zeta Force
# analyzing Stamina RPG 9 Unlocks/[32] [320] Arc Stream Works: Full Meter REV2
# analyzing Stamina RPG 9 Unlocks/[34] [366] Boy Division
# analyzing Stamina RPG 9 Unlocks/[43] [450] Moon Over the Castle

# %%
test_x, test_y = predict(*predictor.params, test_data)

# %%
bokeh_display(test_y, test_x.reshape((-1,)), test_df, predictor=predictor)
# Out:
#   <div id="c09d04b6-0f43-4fb2-9ae4-511dae668516" data-root-id="p7667" style="display: contents;"></div>

# %% [markdown]
# ## Torch tests

# %%
all_data_torch = ChartDataset(df, True)

# %%
from spacecutter.models import OrdinalLogisticModel
from torch.nn import Parameter

def get_exhaust_torch(density, cp, recovery_fac, curve_fac):
    exhaust = torch.as_tensor(0.0)
    exhaust_arr = torch.empty((len(density),))
    for i, d in enumerate(density):
        exhaust_arr[i] = exhaust
        if d <= cp:
            exhaust *= recovery_fac
        else:
            #exhaust += math.exp(-exhaust*curve_fac) * (d-cp)
            exhaust += 1/(exhaust+1) * (d-cp) * curve_fac
    #print(exhaust_arr)
    return exhaust_arr

def get_exhaust_torch_vectorized(density, cp, recovery_fac, curve_fac):    
    # Create masks
    below_cp = density <= cp
    
    # Find segment boundaries
    condition_change = torch.cat([
        torch.tensor([True]),  # First element always starts a segment
        below_cp[1:] != below_cp[:-1]
    ])
    segment_ids = torch.cumsum(condition_change.long(), dim=0) - 1
    
    exhaust = torch.zeros_like(density, dtype=torch.float32)
    
    for seg_id in range(segment_ids.max() + 1):
        mask = segment_ids == seg_id
        indices = torch.where(mask)[0]
        
        start_idx = indices[0]
        prev_exhaust = exhaust[start_idx - 1].item() if start_idx > 0 else 0.0
        
        if below_cp[start_idx]:
            # Exponential decay: exhaust * recovery_fac^n
            n_steps = torch.arange(len(indices), device=density.device, dtype=density.dtype)
            exhaust[mask] = prev_exhaust * (recovery_fac ** n_steps)
        else:
            # Linear growth: cumulative sum of increments
            increments = (density[mask] - cp) * curve_fac
            cumulative_growth = torch.cumsum(increments, dim=0)
            # Shift by one: exhaust[i] is set BEFORE adding increment[i]
            exhaust[mask] = prev_exhaust + torch.cat([
                torch.tensor([0.0]), 
                cumulative_growth[:-1]
            ])
    
    return exhaust

@torch.jit.script
def get_exhaust_jit(density: torch.Tensor, cp: torch.Tensor, 
                     recovery_fac: torch.Tensor, curve_fac: torch.Tensor,
                     temperature: float = 0.1) -> torch.Tensor:
    n = density.shape[0]
    exhaust = torch.zeros(n, dtype=torch.float32)
    exhaust_val = torch.tensor(0.0)
    
    for i in range(n):
        exhaust[i] = exhaust_val
        
        is_below = torch.sigmoid(-(density[i] - cp) / temperature)
        decay_val = exhaust_val * recovery_fac
        growth_val = exhaust_val + (density[i] - cp) * curve_fac
        
        exhaust_val = is_below * decay_val + (1 - is_below) * growth_val
    
    return exhaust

class TorchPredictor(nn.Module):
    def __init__(self):
        super().__init__()

        self.a = Parameter(torch.tensor(2.0, dtype=torch.float32))
        self.cp = Parameter(torch.tensor(6.0, dtype=torch.float32))
        self.recovery_fac = Parameter(torch.tensor(0.9, dtype=torch.float32))
        self.curve_fac = Parameter(torch.tensor(1.0, dtype=torch.float32))

    def init_weights(self):
        with torch.no_grad():
            self.a.data.fill_(2.0)
            self.cp.data.fill_(6.0)
            self.recovery_fac.data.fill_(0.9)
            self.curve_fac.data.fill_(1.0)
    
    def clamp_params(self):
        with torch.no_grad():
            self.a.clamp_(1.1, 4)
            self.cp.clamp_(1, 20)
            self.recovery_fac.clamp_(0.8, 1)
            self.curve_fac.clamp_(0.1, 10)

    def forward(self, data):
        #print('new data', data.shape)
        scores = torch.empty((len(data),))
        for i, row in enumerate(data):
            #if i % 10 == 0: print('.', end='')
            #length = int(row[0])
            #row = row[1:length + 1]
            exhaust = 1 + get_exhaust_jit(row, self.cp, self.recovery_fac, self.curve_fac)
            p = torch.pow(self.a, row) - 1
            #print(exhaust.device, p.device, row.device, data.device)
            score = torch.log((p * exhaust).sum() + 1)
            scores[i] = score
        #print()
        return scores.unsqueeze(1)

#pre_pad = [torch.tensor(np.insert(i, 0, len(i), axis=0)) for i in all_data.data[0:2]]
pre_pad = all_data_torch.data[:2]
padded = torch.nn.utils.rnn.pad_sequence(
    pre_pad, batch_first=True, padding_value=0.0
)
print(padded.shape)
predictor = TorchPredictor()
predictor.init_weights()
model = OrdinalLogisticModel(predictor, 43)
predictor(padded)
# Out:
# torch.Size([2, 169])
# tensor([[14.3251],
#         [15.2532]], grad_fn=<UnsqueezeBackward0>)

# %%
import random
from spacecutter.callbacks import AscensionCallback
from spacecutter.losses import CumulativeLinkLoss

callback = AscensionCallback()

def train(model, dataset, optimizer, criterion, n_epoch=10, batch_size=64):
    # Keep track of losses for plotting
    current_loss = 0
    all_losses = []
    model.train()

    print(f"training on data set with n = {len(dataset)}")

    for epoch_i in range(1, n_epoch + 1):
        model.zero_grad() # clear the gradients

        # create some minibatches
        # we cannot use dataloaders because each of our names is a different length
        batches = list(range(len(dataset)))
        random.shuffle(batches)
        batches = np.array_split(batches, len(batches) // batch_size )

        for idx, batch in enumerate(batches):
            batch_loss = 0
            for i in batch: #for each example in this batch
                meter, density = dataset[i]
                output = model.forward(density.reshape((1, -1)))
                output = torch.sum((output * torch.arange(1, 44)), -1)
                loss = criterion(output, meter)
                batch_loss += loss

            # optimize parameters
            batch_loss.backward()
            # nn.utils.clip_grad_norm_(rnn.parameters(), 3)
            optimizer.step()
            optimizer.zero_grad()

            current_loss += batch_loss.item() / len(batch)

            model.predictor.clamp_params()
            callback.clip(model.link)

            print(f'epoch {epoch_i} batch {idx}/{len(batches)}: loss {batch_loss.item() / len(batch)}')

        all_losses.append(current_loss / len(batches) )
        print(f"{epoch_i} ({epoch_i / n_epoch:.0%}): \t average batch loss = {all_losses[-1]}")
        current_loss = 0

    return all_losses

predictor = TorchPredictor()
predictor.init_weights()
model = OrdinalLogisticModel(predictor, 43)
optimizer = torch.optim.Adam(model.parameters(), lr=0.2)
criterion = nn.MSELoss() #CumulativeLinkLoss()
all_losses = train(model, all_data_torch, optimizer, criterion)
# Out:
# training on data set with n = 3137
# c:\Users\Lenovo\Documents\code_projs\itg-difficulty-predictor\.venv\Lib\site-packages\torch\utils\_device.py:104: UserWarning: Using a target size (torch.Size([1, 1])) that is different to the input size (torch.Size([1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return func(*args, **kwargs)
# epoch 1 batch 0/49: loss 468.1190204326923
# epoch 1 batch 1/49: loss 432.4773254394531
# epoch 1 batch 2/49: loss 370.85107421875
# epoch 1 batch 3/49: loss 319.9359130859375
# epoch 1 batch 4/49: loss 240.8506317138672
# epoch 1 batch 5/49: loss 166.63929748535156
# epoch 1 batch 6/49: loss 180.49960327148438
# epoch 1 batch 7/49: loss 167.32994079589844
# epoch 1 batch 8/49: loss 189.5996551513672
# epoch 1 batch 9/49: loss 170.43775939941406
# epoch 1 batch 10/49: loss 110.79187774658203
# epoch 1 batch 11/49: loss 120.38109588623047
# epoch 1 batch 12/49: loss 132.0061492919922
# epoch 1 batch 13/49: loss 155.17120361328125
# epoch 1 batch 14/49: loss 130.63937377929688
# epoch 1 batch 15/49: loss 135.3848876953125
# epoch 1 batch 16/49: loss 132.0145263671875
# epoch 1 batch 17/49: loss 114.27297973632812
# epoch 1 batch 18/49: loss 128.8717803955078
# epoch 1 batch 19/49: loss 126.8470458984375
# epoch 1 batch 20/49: loss 109.42591094970703
# epoch 1 batch 21/49: loss 83.80388641357422
# epoch 1 batch 22/49: loss 97.98650360107422
# epoch 1 batch 23/49: loss 101.1517105102539
# epoch 1 batch 24/49: loss 94.09546661376953
# epoch 1 batch 25/49: loss 99.83182525634766
# epoch 1 batch 26/49: loss 87.27752685546875
# epoch 1 batch 27/49: loss 87.7092056274414
# epoch 1 batch 28/49: loss 64.31488037109375
# epoch 1 batch 29/49: loss 61.695465087890625
# epoch 1 batch 30/49: loss 77.8908920288086
# epoch 1 batch 31/49: loss 85.66751098632812
# epoch 1 batch 32/49: loss 72.8062973022461
# epoch 1 batch 33/49: loss 55.548583984375
# epoch 1 batch 34/49: loss 67.00540161132812
# epoch 1 batch 35/49: loss 47.99688720703125
# epoch 1 batch 36/49: loss 61.05134201049805
# epoch 1 batch 37/49: loss 53.84906005859375
# epoch 1 batch 38/49: loss 58.28367233276367
# epoch 1 batch 39/49: loss 51.13325500488281
# epoch 1 batch 40/49: loss 40.70889663696289
# epoch 1 batch 41/49: loss 45.52871322631836
# epoch 1 batch 42/49: loss 40.49911117553711
# epoch 1 batch 43/49: loss 51.51696014404297
# epoch 1 batch 44/49: loss 34.6672477722168
# epoch 1 batch 45/49: loss 38.49873733520508
# epoch 1 batch 46/49: loss 42.99916076660156
# epoch 1 batch 47/49: loss 35.61117172241211
# epoch 1 batch 48/49: loss 33.43503952026367
# 1 (10%): 	 average batch loss = 119.90023394933488
# epoch 2 batch 0/49: loss 31.60143103966346
# epoch 2 batch 1/49: loss 24.70972442626953
# epoch 2 batch 2/49: loss 33.28228759765625
# epoch 2 batch 3/49: loss 25.5537109375
# epoch 2 batch 4/49: loss 19.56379508972168
# epoch 2 batch 5/49: loss 13.684554100036621
# epoch 2 batch 6/49: loss 24.577930450439453
# epoch 2 batch 7/49: loss 17.881614685058594
# epoch 2 batch 8/49: loss 17.591800689697266
# epoch 2 batch 9/49: loss 18.506118774414062
# epoch 2 batch 10/49: loss 17.200515747070312
# epoch 2 batch 11/49: loss 18.246355056762695
# epoch 2 batch 12/49: loss 10.345568656921387
# epoch 2 batch 13/49: loss 9.208701133728027
# epoch 2 batch 14/49: loss 12.17352294921875
# epoch 2 batch 15/49: loss 12.782204627990723
# epoch 2 batch 16/49: loss 10.046122550964355
# epoch 2 batch 17/49: loss 10.457651138305664
# epoch 2 batch 18/49: loss 8.680734634399414
# epoch 2 batch 19/49: loss 9.219948768615723
# epoch 2 batch 20/49: loss 10.404718399047852
# epoch 2 batch 21/49: loss 10.092660903930664
# epoch 2 batch 22/49: loss 9.17841625213623
# epoch 2 batch 23/49: loss 7.333049774169922
# epoch 2 batch 24/49: loss 9.395467758178711
# epoch 2 batch 25/49: loss 10.201918601989746
# epoch 2 batch 26/49: loss 9.44989013671875
# epoch 2 batch 27/49: loss 9.688004493713379
# epoch 2 batch 28/49: loss 6.2099504470825195
# epoch 2 batch 29/49: loss 7.414687156677246
# epoch 2 batch 30/49: loss 7.983296871185303
# epoch 2 batch 31/49: loss 6.334112644195557
# epoch 2 batch 32/49: loss 10.278024673461914
# epoch 2 batch 33/49: loss 9.713332176208496
# epoch 2 batch 34/49: loss 6.689233303070068
# epoch 2 batch 35/49: loss 6.438253402709961
# epoch 2 batch 36/49: loss 7.558082580566406
# epoch 2 batch 37/49: loss 6.108394145965576
# epoch 2 batch 38/49: loss 8.079754829406738
# epoch 2 batch 39/49: loss 6.703855514526367
# epoch 2 batch 40/49: loss 5.457298755645752
# epoch 2 batch 41/49: loss 6.261561870574951
# epoch 2 batch 42/49: loss 6.014868259429932
# epoch 2 batch 43/49: loss 5.609247207641602
# epoch 2 batch 44/49: loss 5.433126926422119
# epoch 2 batch 45/49: loss 6.436168670654297
# epoch 2 batch 46/49: loss 4.056907653808594
# epoch 2 batch 47/49: loss 4.868490695953369
# epoch 2 batch 48/49: loss 5.161838531494141
# 2 (20%): 	 average batch loss = 11.425896034510206
# epoch 3 batch 0/49: loss 4.828502948467548
# epoch 3 batch 1/49: loss 4.662205219268799
# epoch 3 batch 2/49: loss 4.568325519561768
# epoch 3 batch 3/49: loss 6.466701984405518
# epoch 3 batch 4/49: loss 5.06904935836792
# epoch 3 batch 5/49: loss 4.241456985473633
# epoch 3 batch 6/49: loss 5.088610649108887
# epoch 3 batch 7/49: loss 4.611542701721191
# epoch 3 batch 8/49: loss 5.970178604125977
# epoch 3 batch 9/49: loss 6.866191387176514
# epoch 3 batch 10/49: loss 5.834245204925537
# epoch 3 batch 11/49: loss 4.538573741912842
# epoch 3 batch 12/49: loss 6.0158281326293945
# epoch 3 batch 13/49: loss 4.441655158996582
# epoch 3 batch 14/49: loss 4.459498405456543
# epoch 3 batch 15/49: loss 3.9612317085266113
# epoch 3 batch 16/49: loss 4.761078834533691
# epoch 3 batch 17/49: loss 5.098567485809326
# epoch 3 batch 18/49: loss 3.7266340255737305
# epoch 3 batch 19/49: loss 3.3554577827453613
# epoch 3 batch 20/49: loss 4.106204032897949
# epoch 3 batch 21/49: loss 3.7154078483581543
# epoch 3 batch 22/49: loss 4.454999923706055
# epoch 3 batch 23/49: loss 5.303327560424805
# epoch 3 batch 24/49: loss 5.374504566192627
# epoch 3 batch 25/49: loss 3.931138038635254
# epoch 3 batch 26/49: loss 3.5260791778564453
# epoch 3 batch 27/49: loss 2.952915906906128
# epoch 3 batch 28/49: loss 4.459293842315674
# epoch 3 batch 29/49: loss 4.121330738067627
# epoch 3 batch 30/49: loss 4.277915000915527
# epoch 3 batch 31/49: loss 3.7377004623413086
# epoch 3 batch 32/49: loss 4.199193954467773
# epoch 3 batch 33/49: loss 2.540907144546509
# epoch 3 batch 34/49: loss 4.878278732299805
# epoch 3 batch 35/49: loss 3.1989777088165283
# epoch 3 batch 36/49: loss 4.815992832183838
# epoch 3 batch 37/49: loss 3.5553805828094482
# epoch 3 batch 38/49: loss 2.9447550773620605
# epoch 3 batch 39/49: loss 2.7139546871185303
# epoch 3 batch 40/49: loss 4.245664596557617
# epoch 3 batch 41/49: loss 3.460481882095337
# epoch 3 batch 42/49: loss 4.252895355224609
# epoch 3 batch 43/49: loss 3.821768283843994
# epoch 3 batch 44/49: loss 4.3181328773498535
# epoch 3 batch 45/49: loss 3.5580968856811523
# epoch 3 batch 46/49: loss 3.4543442726135254
# epoch 3 batch 47/49: loss 2.5046350955963135
# epoch 3 batch 48/49: loss 3.7930796146392822
# 3 (30%): 	 average batch loss = 4.301691684094104
# epoch 4 batch 0/49: loss 4.845836932842548
# epoch 4 batch 1/49: loss 3.6446268558502197
# epoch 4 batch 2/49: loss 4.693538665771484
# epoch 4 batch 3/49: loss 4.186853408813477
# epoch 4 batch 4/49: loss 3.547157049179077
# epoch 4 batch 5/49: loss 2.9972970485687256
# epoch 4 batch 6/49: loss 3.6504199504852295
# epoch 4 batch 7/49: loss 3.780792236328125
# epoch 4 batch 8/49: loss 3.708160161972046
# epoch 4 batch 9/49: loss 3.9401724338531494
# epoch 4 batch 10/49: loss 2.903393268585205
# epoch 4 batch 11/49: loss 3.1640992164611816
# epoch 4 batch 12/49: loss 3.0332889556884766
# epoch 4 batch 13/49: loss 2.06169056892395
# epoch 4 batch 14/49: loss 2.2437853813171387
# epoch 4 batch 15/49: loss 3.3119921684265137
# epoch 4 batch 16/49: loss 3.643704652786255
# epoch 4 batch 17/49: loss 3.4624691009521484
# epoch 4 batch 18/49: loss 3.6905345916748047
# epoch 4 batch 19/49: loss 2.960393190383911
# epoch 4 batch 20/49: loss 4.168091297149658
# epoch 4 batch 21/49: loss 4.144163608551025
# epoch 4 batch 22/49: loss 3.571831226348877
# epoch 4 batch 23/49: loss 2.991178035736084
# epoch 4 batch 24/49: loss 3.881828784942627
# epoch 4 batch 25/49: loss 2.8536696434020996
# epoch 4 batch 26/49: loss 3.4082322120666504
# epoch 4 batch 27/49: loss 2.197500228881836
# epoch 4 batch 28/49: loss 3.2828867435455322
# epoch 4 batch 29/49: loss 3.505528450012207
# epoch 4 batch 30/49: loss 3.4337170124053955
# epoch 4 batch 31/49: loss 2.8432905673980713
# epoch 4 batch 32/49: loss 4.265523910522461
# epoch 4 batch 33/49: loss 2.7510130405426025
# epoch 4 batch 34/49: loss 2.3653829097747803
# epoch 4 batch 35/49: loss 2.9606194496154785
# epoch 4 batch 36/49: loss 3.799182653427124
# epoch 4 batch 37/49: loss 2.9771690368652344
# epoch 4 batch 38/49: loss 1.771414875984192
# epoch 4 batch 39/49: loss 2.838559865951538
# epoch 4 batch 40/49: loss 3.039842367172241
# epoch 4 batch 41/49: loss 2.9539577960968018
# epoch 4 batch 42/49: loss 2.892357587814331
# epoch 4 batch 43/49: loss 2.500506639480591
# epoch 4 batch 44/49: loss 2.8903744220733643
# epoch 4 batch 45/49: loss 1.910854697227478
# epoch 4 batch 46/49: loss 2.7320735454559326
# epoch 4 batch 47/49: loss 2.9113035202026367
# epoch 4 batch 48/49: loss 3.0715599060058594
# 4 (40%): 	 average batch loss = 3.2323228545615583
# epoch 5 batch 0/49: loss 2.115796602689303
# epoch 5 batch 1/49: loss 2.420759677886963
# epoch 5 batch 2/49: loss 2.6899967193603516
# epoch 5 batch 3/49: loss 1.887831449508667
# epoch 5 batch 4/49: loss 2.8178579807281494
# epoch 5 batch 5/49: loss 1.9913361072540283
# epoch 5 batch 6/49: loss 1.8937739133834839
# epoch 5 batch 7/49: loss 3.217684507369995
# epoch 5 batch 8/49: loss 2.198448657989502
# epoch 5 batch 9/49: loss 1.6872477531433105
# epoch 5 batch 10/49: loss 3.0412192344665527
# epoch 5 batch 11/49: loss 1.3878482580184937
# epoch 5 batch 12/49: loss 2.9225683212280273
# epoch 5 batch 13/49: loss 3.1847667694091797
# epoch 5 batch 14/49: loss 3.0918025970458984
# epoch 5 batch 15/49: loss 1.911536455154419
# epoch 5 batch 16/49: loss 2.743981122970581
# epoch 5 batch 17/49: loss 3.0971078872680664
# epoch 5 batch 18/49: loss 3.4273128509521484
# epoch 5 batch 19/49: loss 2.73408842086792
# epoch 5 batch 20/49: loss 3.3015024662017822
# epoch 5 batch 21/49: loss 3.108536720275879
# epoch 5 batch 22/49: loss 2.674448013305664
# epoch 5 batch 23/49: loss 1.461435317993164
# epoch 5 batch 24/49: loss 2.7315611839294434
# epoch 5 batch 25/49: loss 2.314035654067993
# epoch 5 batch 26/49: loss 2.176506996154785
# epoch 5 batch 27/49: loss 2.5039026737213135
# epoch 5 batch 28/49: loss 3.3719482421875
# epoch 5 batch 29/49: loss 2.7098677158355713
# epoch 5 batch 30/49: loss 2.7833216190338135
# epoch 5 batch 31/49: loss 2.833144426345825
# epoch 5 batch 32/49: loss 2.500807046890259
# epoch 5 batch 33/49: loss 2.0618581771850586
# epoch 5 batch 34/49: loss 3.393413543701172
# epoch 5 batch 35/49: loss 2.9284286499023438
# epoch 5 batch 36/49: loss 3.080765724182129
# epoch 5 batch 37/49: loss 1.8498486280441284
# epoch 5 batch 38/49: loss 3.3708088397979736
# epoch 5 batch 39/49: loss 1.84042227268219
# epoch 5 batch 40/49: loss 1.6566189527511597
# epoch 5 batch 41/49: loss 1.5438669919967651
# epoch 5 batch 42/49: loss 2.346827983856201
# epoch 5 batch 43/49: loss 1.7311557531356812
# epoch 5 batch 44/49: loss 2.362853527069092
# epoch 5 batch 45/49: loss 2.5767605304718018
# epoch 5 batch 46/49: loss 2.0102052688598633
# epoch 5 batch 47/49: loss 2.1416120529174805
# epoch 5 batch 48/49: loss 1.3697458505630493
# 5 (50%): 	 average batch loss = 2.4734525736684514
# epoch 6 batch 0/49: loss 1.9196473341721756
# epoch 6 batch 1/49: loss 2.7986562252044678
# epoch 6 batch 2/49: loss 2.0203001499176025
# epoch 6 batch 3/49: loss 2.762165069580078
# epoch 6 batch 4/49: loss 2.010122537612915
# epoch 6 batch 5/49: loss 1.9134392738342285
# epoch 6 batch 6/49: loss 2.382676839828491
# epoch 6 batch 7/49: loss 2.442652702331543
# epoch 6 batch 8/49: loss 2.6151387691497803
# epoch 6 batch 9/49: loss 2.8226840496063232
# epoch 6 batch 10/49: loss 1.8077929019927979
# epoch 6 batch 11/49: loss 2.044355630874634
# epoch 6 batch 12/49: loss 1.6967363357543945
# epoch 6 batch 13/49: loss 2.234891176223755
# epoch 6 batch 14/49: loss 2.222205400466919
# epoch 6 batch 15/49: loss 1.0256407260894775
# epoch 6 batch 16/49: loss 2.010674238204956
# epoch 6 batch 17/49: loss 2.6190619468688965
# epoch 6 batch 18/49: loss 2.0570077896118164
# epoch 6 batch 19/49: loss 2.0939104557037354
# epoch 6 batch 20/49: loss 2.2219512462615967
# epoch 6 batch 21/49: loss 1.973082423210144
# epoch 6 batch 22/49: loss 1.412651538848877
# epoch 6 batch 23/49: loss 3.532444715499878
# epoch 6 batch 24/49: loss 2.1926286220550537
# epoch 6 batch 25/49: loss 1.765062928199768
# epoch 6 batch 26/49: loss 1.917267918586731
# epoch 6 batch 27/49: loss 2.8228800296783447
# epoch 6 batch 28/49: loss 2.882256269454956
# epoch 6 batch 29/49: loss 2.135408401489258
# epoch 6 batch 30/49: loss 2.225733757019043
# epoch 6 batch 31/49: loss 2.376499652862549
# epoch 6 batch 32/49: loss 2.2719409465789795
# epoch 6 batch 33/49: loss 2.073617458343506
# epoch 6 batch 34/49: loss 2.159818649291992
# epoch 6 batch 35/49: loss 1.9515719413757324
# epoch 6 batch 36/49: loss 3.084582567214966
# epoch 6 batch 37/49: loss 2.0686469078063965
# epoch 6 batch 38/49: loss 1.6785024404525757
# epoch 6 batch 39/49: loss 1.5853323936462402
# epoch 6 batch 40/49: loss 2.095109224319458
# epoch 6 batch 41/49: loss 2.084686279296875
# epoch 6 batch 42/49: loss 1.5833650827407837
# epoch 6 batch 43/49: loss 1.9391717910766602
# epoch 6 batch 44/49: loss 1.478316068649292
# epoch 6 batch 45/49: loss 2.068821907043457
# epoch 6 batch 46/49: loss 2.4406187534332275
# epoch 6 batch 47/49: loss 2.7479608058929443
# epoch 6 batch 48/49: loss 1.3089905977249146
# 6 (60%): 	 average batch loss = 2.154666956552718
# epoch 7 batch 0/49: loss 2.394268094576322
# epoch 7 batch 1/49: loss 2.810497283935547
# epoch 7 batch 2/49: loss 2.0972743034362793
# epoch 7 batch 3/49: loss 1.3832273483276367
# epoch 7 batch 4/49: loss 1.7072319984436035
# epoch 7 batch 5/49: loss 2.7607245445251465
# epoch 7 batch 6/49: loss 3.796706199645996
# epoch 7 batch 7/49: loss 2.9838104248046875
# epoch 7 batch 8/49: loss 2.282169818878174
# epoch 7 batch 9/49: loss 1.5268619060516357
# epoch 7 batch 10/49: loss 3.087489366531372
# epoch 7 batch 11/49: loss 1.7471342086791992
# epoch 7 batch 12/49: loss 1.0499614477157593
# epoch 7 batch 13/49: loss 2.3220717906951904
# epoch 7 batch 14/49: loss 2.369537830352783
# epoch 7 batch 15/49: loss 2.4562923908233643
# epoch 7 batch 16/49: loss 1.2040181159973145
# epoch 7 batch 17/49: loss 2.2656733989715576
# epoch 7 batch 18/49: loss 2.6662940979003906
# epoch 7 batch 19/49: loss 1.5178157091140747
# epoch 7 batch 20/49: loss 2.012647867202759
# epoch 7 batch 21/49: loss 1.0761858224868774
# epoch 7 batch 22/49: loss 2.5640692710876465
# epoch 7 batch 23/49: loss 1.5206314325332642
# epoch 7 batch 24/49: loss 1.6013073921203613
# epoch 7 batch 25/49: loss 2.1007025241851807
# epoch 7 batch 26/49: loss 1.6596060991287231
# epoch 7 batch 27/49: loss 1.5618016719818115
# epoch 7 batch 28/49: loss 1.2654436826705933
# epoch 7 batch 29/49: loss 2.129847288131714
# epoch 7 batch 30/49: loss 1.7437822818756104
# epoch 7 batch 31/49: loss 1.5172804594039917
# epoch 7 batch 32/49: loss 1.6468251943588257
# epoch 7 batch 33/49: loss 1.1591931581497192
# epoch 7 batch 34/49: loss 1.044363260269165
# epoch 7 batch 35/49: loss 1.6812130212783813
# epoch 7 batch 36/49: loss 1.696892261505127
# epoch 7 batch 37/49: loss 1.6888152360916138
# epoch 7 batch 38/49: loss 2.063081741333008
# epoch 7 batch 39/49: loss 1.8817062377929688
# epoch 7 batch 40/49: loss 1.0647945404052734
# epoch 7 batch 41/49: loss 1.2184892892837524
# epoch 7 batch 42/49: loss 1.673889398574829
# epoch 7 batch 43/49: loss 1.9586687088012695
# epoch 7 batch 44/49: loss 2.366973638534546
# epoch 7 batch 45/49: loss 1.294566035270691
# epoch 7 batch 46/49: loss 2.143984317779541
# epoch 7 batch 47/49: loss 1.5710608959197998
# epoch 7 batch 48/49: loss 1.7986472845077515
# 7 (70%): 	 average batch loss = 1.9007251080014453
# epoch 8 batch 0/49: loss 1.1746748704176682
# epoch 8 batch 1/49: loss 1.5020065307617188
# epoch 8 batch 2/49: loss 1.5863795280456543
# epoch 8 batch 3/49: loss 0.9600638747215271
# epoch 8 batch 4/49: loss 2.2772200107574463
# epoch 8 batch 5/49: loss 1.5327236652374268
# epoch 8 batch 6/49: loss 1.4156771898269653
# epoch 8 batch 7/49: loss 1.264926791191101
# epoch 8 batch 8/49: loss 2.009152412414551
# epoch 8 batch 9/49: loss 1.2497996091842651
# epoch 8 batch 10/49: loss 1.261762022972107
# epoch 8 batch 11/49: loss 1.3710029125213623
# epoch 8 batch 12/49: loss 1.1622467041015625
# epoch 8 batch 13/49: loss 1.2827054262161255
# epoch 8 batch 14/49: loss 1.4577869176864624
# epoch 8 batch 15/49: loss 2.414778709411621
# epoch 8 batch 16/49: loss 1.481220006942749
# epoch 8 batch 17/49: loss 1.4649122953414917
# epoch 8 batch 18/49: loss 1.3359192609786987
# epoch 8 batch 19/49: loss 2.104318857192993
# epoch 8 batch 20/49: loss 1.692927360534668
# epoch 8 batch 21/49: loss 1.1589220762252808
# epoch 8 batch 22/49: loss 1.6863446235656738
# epoch 8 batch 23/49: loss 2.5760672092437744
# epoch 8 batch 24/49: loss 1.6966367959976196
# epoch 8 batch 25/49: loss 1.3065463304519653
# epoch 8 batch 26/49: loss 0.9603065252304077
# epoch 8 batch 27/49: loss 2.2429440021514893
# epoch 8 batch 28/49: loss 1.1600242853164673
# epoch 8 batch 29/49: loss 2.7567031383514404
# epoch 8 batch 30/49: loss 1.5968037843704224
# epoch 8 batch 31/49: loss 1.3005837202072144
# epoch 8 batch 32/49: loss 2.3746583461761475
# epoch 8 batch 33/49: loss 1.9045015573501587
# epoch 8 batch 34/49: loss 2.0928516387939453
# epoch 8 batch 35/49: loss 1.3813161849975586
# epoch 8 batch 36/49: loss 1.381637454032898
# epoch 8 batch 37/49: loss 1.4816869497299194
# epoch 8 batch 38/49: loss 1.513824224472046
# epoch 8 batch 39/49: loss 1.504264235496521
# epoch 8 batch 40/49: loss 1.1761072874069214
# epoch 8 batch 41/49: loss 1.9502217769622803
# epoch 8 batch 42/49: loss 0.7318191528320312
# epoch 8 batch 43/49: loss 1.3421388864517212
# epoch 8 batch 44/49: loss 1.6393053531646729
# epoch 8 batch 45/49: loss 2.266634225845337
# epoch 8 batch 46/49: loss 1.196007490158081
# epoch 8 batch 47/49: loss 1.6856193542480469
# epoch 8 batch 48/49: loss 2.201464891433716
# 8 (80%): 	 average batch loss = 1.5973091113698352
# epoch 9 batch 0/49: loss 2.6111107459435097
# epoch 9 batch 1/49: loss 1.4798322916030884
# epoch 9 batch 2/49: loss 1.7208826541900635
# epoch 9 batch 3/49: loss 1.4877355098724365
# epoch 9 batch 4/49: loss 1.4493563175201416
# epoch 9 batch 5/49: loss 2.160654067993164
# epoch 9 batch 6/49: loss 1.2643916606903076
# epoch 9 batch 7/49: loss 1.5020265579223633
# epoch 9 batch 8/49: loss 1.4532240629196167
# epoch 9 batch 9/49: loss 1.521506905555725
# epoch 9 batch 10/49: loss 1.3978520631790161
# epoch 9 batch 11/49: loss 1.040708065032959
# epoch 9 batch 12/49: loss 1.2606427669525146
# epoch 9 batch 13/49: loss 1.07352614402771
# epoch 9 batch 14/49: loss 1.4842278957366943
# epoch 9 batch 15/49: loss 1.451066493988037
# epoch 9 batch 16/49: loss 1.1252288818359375
# epoch 9 batch 17/49: loss 1.3501523733139038
# epoch 9 batch 18/49: loss 1.3434759378433228
# epoch 9 batch 19/49: loss 1.370615005493164
# epoch 9 batch 20/49: loss 1.3085966110229492
# epoch 9 batch 21/49: loss 1.4799933433532715
# epoch 9 batch 22/49: loss 0.9490160942077637
# epoch 9 batch 23/49: loss 1.2112513780593872
# epoch 9 batch 24/49: loss 1.9117740392684937
# epoch 9 batch 25/49: loss 1.6723731756210327
# epoch 9 batch 26/49: loss 1.2539514303207397
# epoch 9 batch 27/49: loss 1.9485760927200317
# epoch 9 batch 28/49: loss 2.1440088748931885
# epoch 9 batch 29/49: loss 1.6005052328109741
# epoch 9 batch 30/49: loss 1.5268985033035278
# epoch 9 batch 31/49: loss 1.1909983158111572
# epoch 9 batch 32/49: loss 1.157745599746704
# epoch 9 batch 33/49: loss 1.1578984260559082
# epoch 9 batch 34/49: loss 1.0828027725219727
# epoch 9 batch 35/49: loss 1.6683971881866455
# epoch 9 batch 36/49: loss 1.406728982925415
# epoch 9 batch 37/49: loss 1.0762865543365479
# epoch 9 batch 38/49: loss 0.9120187163352966
# epoch 9 batch 39/49: loss 1.4666074514389038
# epoch 9 batch 40/49: loss 1.2326874732971191
# epoch 9 batch 41/49: loss 1.35434889793396
# epoch 9 batch 42/49: loss 1.1854795217514038
# epoch 9 batch 43/49: loss 1.2229918241500854
# epoch 9 batch 44/49: loss 1.2671093940734863
# epoch 9 batch 45/49: loss 1.792700171470642
# epoch 9 batch 46/49: loss 1.0249375104904175
# epoch 9 batch 47/49: loss 1.6372120380401611
# epoch 9 batch 48/49: loss 0.7446200251579285
# 9 (90%): 	 average batch loss = 1.4109537151207916
# epoch 10 batch 0/49: loss 1.2124069213867188
# epoch 10 batch 1/49: loss 1.704437017440796
# epoch 10 batch 2/49: loss 1.772434949874878
# epoch 10 batch 3/49: loss 1.8700557947158813
# epoch 10 batch 4/49: loss 1.9862298965454102
# epoch 10 batch 5/49: loss 1.6603400707244873
# epoch 10 batch 6/49: loss 1.1685248613357544
# epoch 10 batch 7/49: loss 1.3313008546829224
# epoch 10 batch 8/49: loss 0.918383002281189
# epoch 10 batch 9/49: loss 1.1663552522659302
# epoch 10 batch 10/49: loss 1.2207473516464233
# epoch 10 batch 11/49: loss 1.6242780685424805
# epoch 10 batch 12/49: loss 1.3271383047103882
# epoch 10 batch 13/49: loss 0.874199390411377
# epoch 10 batch 14/49: loss 0.9290211200714111
# epoch 10 batch 15/49: loss 1.2056620121002197
# epoch 10 batch 16/49: loss 1.675316333770752
# epoch 10 batch 17/49: loss 1.375819444656372
# epoch 10 batch 18/49: loss 1.4273890256881714
# epoch 10 batch 19/49: loss 1.0336040258407593
# epoch 10 batch 20/49: loss 1.2084987163543701
# epoch 10 batch 21/49: loss 1.108086109161377
# epoch 10 batch 22/49: loss 0.743958592414856
# epoch 10 batch 23/49: loss 1.2984133958816528
# epoch 10 batch 24/49: loss 2.028801441192627
# epoch 10 batch 25/49: loss 1.3021947145462036
# epoch 10 batch 26/49: loss 0.9451234340667725
# epoch 10 batch 27/49: loss 0.8989921808242798
# epoch 10 batch 28/49: loss 1.0891140699386597
# epoch 10 batch 29/49: loss 1.169705867767334
# epoch 10 batch 30/49: loss 0.7881335020065308
# epoch 10 batch 31/49: loss 0.9040224552154541
# epoch 10 batch 32/49: loss 1.1347087621688843
# epoch 10 batch 33/49: loss 0.9934757351875305
# epoch 10 batch 34/49: loss 1.0490531921386719
# epoch 10 batch 35/49: loss 0.8454537391662598
# epoch 10 batch 36/49: loss 0.7659921646118164
# epoch 10 batch 37/49: loss 1.5562474727630615
# epoch 10 batch 38/49: loss 0.767549455165863
# epoch 10 batch 39/49: loss 2.1434085369110107
# epoch 10 batch 40/49: loss 1.0725271701812744
# epoch 10 batch 41/49: loss 1.7497787475585938
# epoch 10 batch 42/49: loss 1.285212755203247
# epoch 10 batch 43/49: loss 0.8621563911437988
# epoch 10 batch 44/49: loss 0.935360848903656
# epoch 10 batch 45/49: loss 1.1624099016189575
# epoch 10 batch 46/49: loss 1.2809966802597046
# epoch 10 batch 47/49: loss 1.4345006942749023
# epoch 10 batch 48/49: loss 1.1978121995925903
# 10 (100%): 	 average batch loss = 1.2490884209165767

# %%
all_losses_2 = all_losses + all_losses_3

# %%
all_losses_3 = train(model, all_data_torch, optimizer, criterion, n_epoch=30)
# Out:
# training on data set with n = 3137
# c:\Users\Lenovo\Documents\code_projs\itg-difficulty-predictor\.venv\Lib\site-packages\torch\utils\_device.py:104: UserWarning: Using a target size (torch.Size([1, 1])) that is different to the input size (torch.Size([1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return func(*args, **kwargs)
# 1 (3%): 	 average batch loss = 0.42935194988827124
# 2 (7%): 	 average batch loss = 0.42268605829688777
# 3 (10%): 	 average batch loss = 0.41240327769489826
# 4 (13%): 	 average batch loss = 0.3879203762092994
# 5 (17%): 	 average batch loss = 0.3927660571536988
# 6 (20%): 	 average batch loss = 0.389337077086537
# 7 (23%): 	 average batch loss = 0.3785747273610188
# 8 (27%): 	 average batch loss = 0.40089996189487226
# 9 (30%): 	 average batch loss = 0.3747033819766771
# 10 (33%): 	 average batch loss = 0.39487809741422186
# 11 (37%): 	 average batch loss = 0.36280196899521855
# 12 (40%): 	 average batch loss = 0.36109698710486504
# 13 (43%): 	 average batch loss = 0.3579294020658011
# 14 (47%): 	 average batch loss = 0.3536988897591221
# 15 (50%): 	 average batch loss = 0.36305359329683257
# 16 (53%): 	 average batch loss = 0.35619166147671466
# 17 (57%): 	 average batch loss = 0.34662699338218295
# 18 (60%): 	 average batch loss = 0.35344240204131394
# 19 (63%): 	 average batch loss = 0.3574032872540985
# 20 (67%): 	 average batch loss = 0.35470411997855733
# 21 (70%): 	 average batch loss = 0.3458415924426712
# 22 (73%): 	 average batch loss = 0.350552424358049
# 23 (77%): 	 average batch loss = 0.343637609477133
# 24 (80%): 	 average batch loss = 0.35296762604354126
# 25 (83%): 	 average batch loss = 0.34942869716199637
# 26 (87%): 	 average batch loss = 0.3475879660019508
# 27 (90%): 	 average batch loss = 0.34782383925218596
# 28 (93%): 	 average batch loss = 0.3490745061280402
# 29 (97%): 	 average batch loss = 0.3500348484778142
# 30 (100%): 	 average batch loss = 0.3356118994614393

# %%
list(model.parameters())
# Out:
# [Parameter containing:
#  tensor(2.3201, requires_grad=True),
#  Parameter containing:
#  tensor(17.5264, requires_grad=True),
#  Parameter containing:
#  tensor(0.8000, requires_grad=True),
#  Parameter containing:
#  tensor(0.1000, requires_grad=True),
#  Parameter containing:
#  tensor([ 7.1923,  7.2177,  7.2692,  7.2736,  7.2761,  7.2861,  7.3292,  7.7303,
#          10.9453, 10.9498, 11.7326, 14.5587, 14.5646, 14.5796, 14.5849, 15.9687,
#          17.8961, 18.3348, 18.3439, 18.3530, 18.3600, 18.3661, 18.3727, 18.3783,
#          22.4498, 22.9345, 24.3501, 24.9932, 25.7555, 27.0193, 27.6003, 27.8188,
#          27.9032, 27.9340, 30.8282, 30.8299, 32.5532, 32.6200, 32.6596, 32.6597,
#          32.6598, 32.7083], requires_grad=True)]

# %%
model.eval()
scores = []
pred_meters = []
meters = []
with torch.no_grad():
    for meter, density in all_data_torch:
        output = model(density.reshape((1, -1)))
        avg = torch.sum((output * torch.arange(1, 44)), -1)
        scores.append(model.predictor(density.reshape((1, -1))).item())
        pred_meters.append(avg.item())
        meters.append(meter.item())
        #print(avg, meter)

# %%
scores, meters
# Out:
# ([tensor([[10.9138]]),
#   tensor([[11.0547]]),
#   tensor([[10.8959]]),
#   tensor([[10.5898]]),
#   tensor([[11.0140]]),
#   tensor([[10.5737]]),
#   tensor([[10.9128]]),
#   tensor([[11.3243]]),
#   tensor([[10.0415]]),
#   tensor([[10.4481]]),
#   tensor([[10.6130]]),
#   tensor([[10.9563]]),
#   tensor([[11.0320]]),
#   tensor([[11.5681]]),
#   tensor([[12.3018]]),
#   tensor([[12.2364]]),
#   tensor([[11.8676]]),
#   tensor([[11.9113]]),
#   tensor([[11.1665]]),
#   tensor([[12.1820]]),
#   tensor([[12.2576]]),
#   tensor([[11.8340]]),
#   tensor([[12.2052]]),
#   tensor([[11.8486]]),
#   tensor([[12.3026]]),
#   tensor([[12.1114]]),
#   tensor([[11.5891]]),
#   tensor([[12.2810]]),
#   tensor([[11.3942]]),
#   tensor([[12.1938]]),
#   tensor([[11.7758]]),
#   tensor([[11.7463]]),
#   tensor([[12.5977]]),
#   tensor([[12.8465]]),
#   tensor([[13.1513]]),
#   tensor([[12.3891]]),
#   tensor([[12.3248]]),
#   tensor([[12.9234]]),
#   tensor([[12.6001]]),
#   tensor([[12.4457]]),
#   tensor([[12.5673]]),
#   tensor([[12.4890]]),
#   tensor([[12.4855]]),
#   tensor([[12.4198]]),
#   tensor([[12.8262]]),
#   tensor([[12.5416]]),
#   tensor([[12.7719]]),
#   tensor([[12.7890]]),
#   tensor([[12.3797]]),
#   tensor([[13.1886]]),
#   tensor([[12.4162]]),
#   tensor([[12.8105]]),
#   tensor([[12.4978]]),
#   tensor([[12.5797]]),
#   tensor([[12.9125]]),
#   tensor([[13.3840]]),
#   tensor([[13.2578]]),
#   tensor([[13.0711]]),
#   tensor([[13.3559]]),
#   tensor([[13.5179]]),
#   tensor([[13.1037]]),
#   tensor([[13.3235]]),
#   tensor([[13.0570]]),
#   tensor([[13.2021]]),
#   tensor([[12.8505]]),
#   tensor([[12.6933]]),
#   tensor([[13.0126]]),
#   tensor([[13.0476]]),
#   tensor([[13.3310]]),
#   tensor([[13.5622]]),
#   tensor([[13.2984]]),
#   tensor([[13.1575]]),
#   tensor([[13.1642]]),
#   tensor([[12.9872]]),
#   tensor([[13.8372]]),
#   tensor([[12.7358]]),
#   tensor([[13.9805]]),
#   tensor([[14.2232]]),
#   tensor([[13.9290]]),
#   tensor([[13.5908]]),
#   tensor([[13.9390]]),
#   tensor([[13.3604]]),
#   tensor([[13.6316]]),
#   tensor([[13.6487]]),
#   tensor([[13.5732]]),
#   tensor([[13.4178]]),
#   tensor([[14.1133]]),
#   tensor([[13.7476]]),
#   tensor([[14.1324]]),
#   tensor([[13.5814]]),
#   tensor([[14.1290]]),
#   tensor([[13.4439]]),
#   tensor([[13.4532]]),
#   tensor([[13.6206]]),
#   tensor([[14.0789]]),
#   tensor([[13.2550]]),
#   tensor([[13.8144]]),
#   tensor([[13.9531]]),
#   tensor([[14.3532]]),
#   tensor([[14.5190]]),
#   tensor([[14.2704]]),
#   tensor([[14.6733]]),
#   tensor([[14.3765]]),
#   tensor([[14.6996]]),
#   tensor([[14.3435]]),
#   tensor([[14.6123]]),
#   tensor([[14.4150]]),
#   tensor([[14.2068]]),
#   tensor([[14.8302]]),
#   tensor([[14.0681]]),
#   tensor([[14.5991]]),
#   tensor([[14.6029]]),
#   tensor([[14.0959]]),
#   tensor([[14.0244]]),
#   tensor([[14.0432]]),
#   tensor([[14.3639]]),
#   tensor([[14.2477]]),
#   tensor([[14.9691]]),
#   tensor([[14.9640]]),
#   tensor([[15.0017]]),
#   tensor([[14.9894]]),
#   tensor([[15.1718]]),
#   tensor([[14.7907]]),
#   tensor([[15.0818]]),
#   tensor([[15.0804]]),
#   tensor([[14.8105]]),
#   tensor([[14.7559]]),
#   tensor([[14.8553]]),
#   tensor([[15.2897]]),
#   tensor([[14.8357]]),
#   tensor([[14.8045]]),
#   tensor([[14.6152]]),
#   tensor([[15.4719]]),
#   tensor([[15.2251]]),
#   tensor([[15.2131]]),
#   tensor([[10.4520]]),
#   tensor([[10.8671]]),
#   tensor([[11.2876]]),
#   tensor([[11.7135]]),
#   tensor([[12.1362]]),
#   tensor([[12.5741]]),
#   tensor([[13.0062]]),
#   tensor([[13.4453]]),
#   tensor([[13.8854]]),
#   tensor([[14.3273]]),
#   tensor([[14.7703]]),
#   tensor([[15.2179]]),
#   tensor([[15.6630]]),
#   tensor([[16.1157]]),
#   tensor([[17.0030]]),
#   tensor([[17.8788]]),
#   tensor([[19.2742]]),
#   tensor([[18.6068]]),
#   tensor([[19.8872]]),
#   tensor([[20.4731]]),
#   tensor([[21.0259]]),
#   tensor([[21.5964]]),
#   tensor([[22.1286]]),
#   tensor([[22.6690]]),
#   tensor([[10.2478]]),
#   tensor([[11.3360]]),
#   tensor([[10.4309]]),
#   tensor([[11.3680]]),
#   tensor([[10.9545]]),
#   tensor([[10.8713]]),
#   tensor([[10.7816]]),
#   tensor([[10.8135]]),
#   tensor([[10.6900]]),
#   tensor([[11.1297]]),
#   tensor([[11.3800]]),
#   tensor([[10.3087]]),
#   tensor([[11.2757]]),
#   tensor([[11.4847]]),
#   tensor([[11.2550]]),
#   tensor([[11.7551]]),
#   tensor([[11.8799]]),
#   tensor([[12.2445]]),
#   tensor([[11.4453]]),
#   tensor([[11.9119]]),
#   tensor([[12.0529]]),
#   tensor([[11.8502]]),
#   tensor([[11.3234]]),
#   tensor([[11.7420]]),
#   tensor([[11.5697]]),
#   tensor([[11.9617]]),
#   tensor([[11.5952]]),
#   tensor([[12.1315]]),
#   tensor([[11.6294]]),
#   tensor([[12.1385]]),
#   tensor([[11.4696]]),
#   tensor([[11.3401]]),
#   tensor([[11.8638]]),
#   tensor([[11.4245]]),
#   tensor([[11.5382]]),
#   tensor([[11.9994]]),
#   tensor([[12.7926]]),
#   tensor([[12.0485]]),
#   tensor([[12.3292]]),
#   tensor([[12.6456]]),
#   tensor([[12.1425]]),
#   tensor([[12.4034]]),
#   tensor([[12.4860]]),
#   tensor([[12.4494]]),
#   tensor([[13.0186]]),
#   tensor([[12.7226]]),
#   tensor([[12.5617]]),
#   tensor([[12.5907]]),
#   tensor([[12.5079]]),
#   tensor([[12.8964]]),
#   tensor([[12.7348]]),
#   tensor([[12.8773]]),
#   tensor([[12.4526]]),
#   tensor([[12.4191]]),
#   tensor([[12.9176]]),
#   tensor([[12.7921]]),
#   tensor([[12.9531]]),
#   tensor([[12.8200]]),
#   tensor([[13.1996]]),
#   tensor([[12.9616]]),
#   tensor([[12.9800]]),
#   tensor([[13.2196]]),
#   tensor([[13.1539]]),
#   tensor([[13.4460]]),
#   tensor([[13.4416]]),
#   tensor([[13.2050]]),
#   tensor([[13.4302]]),
#   tensor([[13.5852]]),
#   tensor([[13.5637]]),
#   tensor([[13.1978]]),
#   tensor([[13.5864]]),
#   tensor([[13.0783]]),
#   tensor([[13.0913]]),
#   tensor([[12.9336]]),
#   tensor([[13.2542]]),
#   tensor([[13.4095]]),
#   tensor([[13.3400]]),
#   tensor([[13.5209]]),
#   tensor([[13.6155]]),
#   tensor([[13.4904]]),
#   tensor([[13.7174]]),
#   tensor([[13.3848]]),
#   tensor([[13.5714]]),
#   tensor([[13.6044]]),
#   tensor([[13.7254]]),
#   tensor([[13.5100]]),
#   tensor([[13.8012]]),
#   tensor([[14.1714]]),
#   tensor([[14.0013]]),
#   tensor([[14.0239]]),
#   tensor([[13.9670]]),
#   tensor([[13.5561]]),
#   tensor([[14.0425]]),
#   tensor([[13.2861]]),
#   tensor([[13.7732]]),
#   tensor([[14.0153]]),
#   tensor([[13.9245]]),
#   tensor([[14.2994]]),
#   tensor([[13.2215]]),
#   tensor([[14.1262]]),
#   tensor([[14.4611]]),
#   tensor([[14.3318]]),
#   tensor([[14.5528]]),
#   tensor([[14.3363]]),
#   tensor([[14.2446]]),
#   tensor([[14.2123]]),
#   tensor([[14.4658]]),
#   tensor([[14.8596]]),
#   tensor([[14.4781]]),
#   tensor([[14.1135]]),
#   tensor([[14.0609]]),
#   tensor([[14.1880]]),
#   tensor([[14.6718]]),
#   tensor([[14.1253]]),
#   tensor([[14.2484]]),
#   tensor([[14.5719]]),
#   tensor([[14.8405]]),
#   tensor([[14.2190]]),
#   tensor([[15.2469]]),
#   tensor([[14.8881]]),
#   tensor([[15.0066]]),
#   tensor([[14.8347]]),
#   tensor([[14.5781]]),
#   tensor([[14.8060]]),
#   tensor([[14.8016]]),
#   tensor([[14.6283]]),
#   tensor([[14.9015]]),
#   tensor([[14.8954]]),
#   tensor([[14.7415]]),
#   tensor([[14.7973]]),
#   tensor([[14.8762]]),
#   tensor([[14.7182]]),
#   tensor([[15.1827]]),
#   tensor([[14.9091]]),
#   tensor([[14.6573]]),
#   tensor([[14.6433]]),
#   tensor([[14.5261]]),
#   tensor([[15.0416]]),
#   tensor([[14.8228]]),
#   tensor([[15.3469]]),
#   tensor([[14.7161]]),
#   tensor([[14.6371]]),
#   tensor([[15.0181]]),
#   tensor([[15.2021]]),
#   tensor([[15.2416]]),
#   tensor([[15.5584]]),
#   tensor([[15.4051]]),
#   tensor([[15.2774]]),
#   tensor([[15.1899]]),
#   tensor([[15.5540]]),
#   tensor([[15.4348]]),
#   tensor([[15.3591]]),
#   tensor([[15.5117]]),
#   tensor([[15.1830]]),
#   tensor([[15.7515]]),
#   tensor([[15.4759]]),
#   tensor([[15.5772]]),
#   tensor([[15.6100]]),
#   tensor([[15.3054]]),
#   tensor([[15.3360]]),
#   tensor([[15.5318]]),
#   tensor([[15.3332]]),
#   tensor([[15.4779]]),
#   tensor([[15.9545]]),
#   tensor([[15.7656]]),
#   tensor([[15.9458]]),
#   tensor([[15.8591]]),
#   tensor([[16.0043]]),
#   tensor([[16.1748]]),
#   tensor([[16.0106]]),
#   tensor([[15.8136]]),
#   tensor([[15.8563]]),
#   tensor([[15.7771]]),
#   tensor([[16.4118]]),
#   tensor([[16.4040]]),
#   tensor([[16.3644]]),
#   tensor([[16.3946]]),
#   tensor([[12.6495]]),
#   tensor([[13.3532]]),
#   tensor([[13.8419]]),
#   tensor([[14.6715]]),
#   tensor([[14.6232]]),
#   tensor([[16.2935]]),
#   tensor([[15.5278]]),
#   tensor([[16.3820]]),
#   tensor([[16.5354]]),
#   tensor([[17.2538]]),
#   tensor([[17.9658]]),
#   tensor([[17.7348]]),
#   tensor([[19.1612]]),
#   tensor([[19.4065]]),
#   tensor([[19.5900]]),
#   tensor([[21.4152]]),
#   tensor([[21.1737]]),
#   tensor([[22.7649]]),
#   tensor([[14.9234]]),
#   tensor([[14.9035]]),
#   tensor([[15.2133]]),
#   tensor([[15.0559]]),
#   tensor([[15.1764]]),
#   tensor([[15.7785]]),
#   tensor([[15.8573]]),
#   tensor([[15.6709]]),
#   tensor([[15.7081]]),
#   tensor([[15.4404]]),
#   tensor([[15.3923]]),
#   tensor([[15.4536]]),
#   tensor([[15.5313]]),
#   tensor([[15.4290]]),
#   tensor([[15.6546]]),
#   tensor([[15.2008]]),
#   tensor([[15.7253]]),
#   tensor([[15.8446]]),
#   tensor([[16.2379]]),
#   tensor([[15.6666]]),
#   tensor([[15.8150]]),
#   tensor([[16.1025]]),
#   tensor([[15.9081]]),
#   tensor([[16.1233]]),
#   tensor([[15.7988]]),
#   tensor([[16.0304]]),
#   tensor([[15.7822]]),
#   tensor([[15.5089]]),
#   tensor([[15.8137]]),
#   tensor([[15.5474]]),
#   tensor([[15.7197]]),
#   tensor([[15.8959]]),
#   tensor([[16.0443]]),
#   tensor([[16.6047]]),
#   tensor([[16.1764]]),
#   tensor([[16.0239]]),
#   tensor([[16.5730]]),
#   tensor([[16.0157]]),
#   tensor([[16.4419]]),
#   tensor([[16.2812]]),
#   tensor([[16.3017]]),
#   tensor([[16.6427]]),
#   tensor([[16.5020]]),
#   tensor([[16.2672]]),
#   tensor([[16.3344]]),
#   tensor([[16.4262]]),
#   tensor([[16.3084]]),
#   tensor([[15.9717]]),
#   tensor([[16.2777]]),
#   tensor([[16.2224]]),
#   tensor([[16.2422]]),
#   tensor([[16.3267]]),
#   tensor([[16.3501]]),
#   tensor([[16.3920]]),
#   tensor([[16.4525]]),
#   tensor([[17.0217]]),
#   tensor([[16.8053]]),
#   tensor([[16.7588]]),
#   tensor([[16.5610]]),
#   tensor([[16.8180]]),
#   tensor([[17.1765]]),
#   tensor([[16.5267]]),
#   tensor([[16.4791]]),
#   tensor([[16.7806]]),
#   tensor([[16.6147]]),
#   tensor([[16.7849]]),
#   tensor([[16.5645]]),
#   tensor([[16.7691]]),
#   tensor([[16.4534]]),
#   tensor([[16.6740]]),
#   tensor([[16.7961]]),
#   tensor([[16.9792]]),
#   tensor([[16.7753]]),
#   tensor([[16.7532]]),
#   tensor([[17.0073]]),
#   tensor([[16.9345]]),
#   tensor([[17.1538]]),
#   tensor([[16.9790]]),
#   tensor([[16.9016]]),
#   tensor([[16.6278]]),
#   tensor([[17.2881]]),
#   tensor([[16.9633]]),
#   tensor([[17.3119]]),
#   tensor([[17.1891]]),
#   tensor([[17.2374]]),
#   tensor([[17.4584]]),
#   tensor([[17.3732]]),
#   tensor([[17.1465]]),
#   tensor([[17.4421]]),
#   tensor([[17.3193]]),
#   tensor([[17.5542]]),
#   tensor([[16.7489]]),
#   tensor([[16.9895]]),
#   tensor([[16.7760]]),
#   tensor([[17.0705]]),
#   tensor([[17.1654]]),
#   tensor([[17.5820]]),
#   tensor([[16.8408]]),
#   tensor([[17.1430]]),
#   tensor([[16.9614]]),
#   tensor([[17.2443]]),
#   tensor([[16.9620]]),
#   tensor([[17.7079]]),
#   tensor([[17.6959]]),
#   tensor([[17.5982]]),
#   tensor([[17.9013]]),
#   tensor([[17.2393]]),
#   tensor([[17.2131]]),
#   tensor([[17.3326]]),
#   tensor([[17.2452]]),
#   tensor([[17.3892]]),
#   tensor([[17.3420]]),
#   tensor([[17.8370]]),
#   tensor([[17.1535]]),
#   tensor([[17.3583]]),
#   tensor([[17.5783]]),
#   tensor([[17.3435]]),
#   tensor([[17.2378]]),
#   tensor([[18.2119]]),
#   tensor([[18.0682]]),
#   tensor([[18.6488]]),
#   tensor([[17.8099]]),
#   tensor([[18.7575]]),
#   tensor([[18.0795]]),
#   tensor([[18.0226]]),
#   tensor([[18.2713]]),
#   tensor([[18.1569]]),
#   tensor([[17.8838]]),
#   tensor([[17.6957]]),
#   tensor([[17.6306]]),
#   tensor([[17.6039]]),
#   tensor([[18.7430]]),
#   tensor([[18.2175]]),
#   tensor([[17.9252]]),
#   tensor([[18.8507]]),
#   tensor([[19.3896]]),
#   tensor([[18.8152]]),
#   tensor([[18.4516]]),
#   tensor([[19.1066]]),
#   tensor([[18.5366]]),
#   tensor([[20.0471]]),
#   tensor([[18.3986]]),
#   tensor([[19.1652]]),
#   tensor([[19.2664]]),
#   tensor([[18.4347]]),
#   tensor([[19.0420]]),
#   tensor([[18.1145]]),
#   tensor([[19.1807]]),
#   tensor([[19.5164]]),
#   tensor([[19.2052]]),
#   tensor([[20.2855]]),
#   tensor([[20.5664]]),
#   tensor([[20.9142]]),
#   tensor([[20.3865]]),
#   tensor([[20.2264]]),
#   tensor([[19.3917]]),
#   tensor([[20.1175]]),
#   tensor([[19.9068]]),
#   tensor([[19.9638]]),
#   tensor([[20.1188]]),
#   tensor([[20.2798]]),
#   tensor([[20.6068]]),
#   tensor([[20.8255]]),
#   tensor([[20.4116]]),
#   tensor([[19.1358]]),
#   tensor([[20.6554]]),
#   tensor([[20.7721]]),
#   tensor([[20.8451]]),
#   tensor([[20.9035]]),
#   tensor([[20.9615]]),
#   tensor([[21.2297]]),
#   tensor([[21.5232]]),
#   tensor([[21.4944]]),
#   tensor([[20.9522]]),
#   tensor([[20.7664]]),
#   tensor([[22.0822]]),
#   tensor([[21.8518]]),
#   tensor([[22.7548]]),
#   tensor([[11.6172]]),
#   tensor([[10.7982]]),
#   tensor([[10.8267]]),
#   tensor([[10.7899]]),
#   tensor([[11.8501]]),
#   tensor([[10.0387]]),
#   tensor([[10.6078]]),
#   tensor([[10.7762]]),
#   tensor([[11.0418]]),
#   tensor([[11.0213]]),
#   tensor([[10.8190]]),
#   tensor([[11.3382]]),
#   tensor([[11.4134]]),
#   tensor([[11.5683]]),
#   tensor([[11.9667]]),
#   tensor([[11.8568]]),
#   tensor([[11.7877]]),
#   tensor([[11.9124]]),
#   tensor([[12.2128]]),
#   tensor([[12.0044]]),
#   tensor([[12.3129]]),
#   tensor([[12.4147]]),
#   tensor([[11.4826]]),
#   tensor([[12.2025]]),
#   tensor([[11.9936]]),
#   tensor([[11.3516]]),
#   tensor([[11.7880]]),
#   tensor([[11.9605]]),
#   tensor([[11.9170]]),
#   tensor([[11.4051]]),
#   tensor([[12.3681]]),
#   tensor([[13.0822]]),
#   tensor([[12.9413]]),
#   tensor([[12.4624]]),
#   tensor([[12.1276]]),
#   tensor([[12.7278]]),
#   tensor([[12.7075]]),
#   tensor([[12.2191]]),
#   tensor([[12.6036]]),
#   tensor([[12.8708]]),
#   tensor([[11.9484]]),
#   tensor([[12.6244]]),
#   tensor([[12.3744]]),
#   tensor([[12.8033]]),
#   tensor([[12.5072]]),
#   tensor([[12.6013]]),
#   tensor([[12.4084]]),
#   tensor([[12.5830]]),
#   tensor([[12.5744]]),
#   tensor([[12.2013]]),
#   tensor([[12.8058]]),
#   tensor([[13.1982]]),
#   tensor([[13.3062]]),
#   tensor([[13.1802]]),
#   tensor([[13.5898]]),
#   tensor([[13.2923]]),
#   tensor([[13.9781]]),
#   tensor([[13.4951]]),
#   tensor([[13.0076]]),
#   tensor([[12.8448]]),
#   tensor([[13.2933]]),
#   tensor([[12.9971]]),
#   tensor([[13.1337]]),
#   tensor([[13.3470]]),
#   tensor([[13.7250]]),
#   tensor([[12.7337]]),
#   tensor([[14.1085]]),
#   tensor([[13.7152]]),
#   tensor([[13.3952]]),
#   tensor([[13.2612]]),
#   tensor([[13.4983]]),
#   tensor([[14.0077]]),
#   tensor([[13.7763]]),
#   tensor([[13.9527]]),
#   tensor([[13.8348]]),
#   tensor([[13.4866]]),
#   tensor([[13.6463]]),
#   tensor([[14.0780]]),
#   tensor([[13.9615]]),
#   tensor([[14.0573]]),
#   tensor([[13.5135]]),
#   tensor([[13.9126]]),
#   tensor([[13.4509]]),
#   tensor([[13.3935]]),
#   tensor([[14.4033]]),
#   tensor([[14.5985]]),
#   tensor([[14.2893]]),
#   tensor([[14.6053]]),
#   tensor([[14.3697]]),
#   tensor([[14.0825]]),
#   tensor([[14.3712]]),
#   tensor([[14.2269]]),
#   tensor([[13.9621]]),
#   tensor([[13.9246]]),
#   tensor([[14.7550]]),
#   tensor([[14.4637]]),
#   tensor([[13.9575]]),
#   tensor([[14.4142]]),
#   tensor([[14.7518]]),
#   tensor([[13.8695]]),
#   tensor([[14.1111]]),
#   tensor([[14.6269]]),
#   tensor([[15.1460]]),
#   tensor([[14.8530]]),
#   tensor([[14.9670]]),
#   tensor([[14.7553]]),
#   tensor([[14.7512]]),
#   tensor([[15.1544]]),
#   tensor([[15.2321]]),
#   tensor([[14.9576]]),
#   tensor([[14.7872]]),
#   tensor([[15.0350]]),
#   tensor([[14.5823]]),
#   tensor([[14.9127]]),
#   tensor([[14.5876]]),
#   tensor([[14.6739]]),
#   tensor([[15.0861]]),
#   tensor([[15.1458]]),
#   tensor([[15.0264]]),
#   tensor([[15.2779]]),
#   tensor([[15.5236]]),
#   tensor([[15.2654]]),
#   tensor([[15.5436]]),
#   tensor([[15.5348]]),
#   tensor([[15.5107]]),
#   tensor([[15.4798]]),
#   tensor([[15.5357]]),
#   tensor([[15.3545]]),
#   tensor([[15.7494]]),
#   tensor([[15.8742]]),
#   tensor([[15.9449]]),
#   tensor([[15.8068]]),
#   tensor([[15.8995]]),
#   tensor([[16.4390]]),
#   tensor([[16.4154]]),
#   tensor([[12.1977]]),
#   tensor([[13.0410]]),
#   tensor([[13.4036]]),
#   tensor([[14.7245]]),
#   tensor([[14.8749]]),
#   tensor([[15.5253]]),
#   tensor([[15.8420]]),
#   tensor([[16.2224]]),
#   tensor([[16.9918]]),
#   tensor([[17.1936]]),
#   tensor([[17.9871]]),
#   tensor([[17.9290]]),
#   tensor([[19.3330]]),
#   tensor([[19.5181]]),
#   tensor([[19.6610]]),
#   tensor([[21.2831]]),
#   tensor([[21.8261]]),
#   tensor([[14.9509]]),
#   tensor([[14.8422]]),
#   tensor([[15.2474]]),
#   tensor([[15.6665]]),
#   tensor([[15.5649]]),
#   tensor([[15.8399]]),
#   tensor([[15.4087]]),
#   tensor([[15.4986]]),
#   tensor([[15.4867]]),
#   tensor([[15.8351]]),
#   tensor([[15.8464]]),
#   tensor([[15.9818]]),
#   tensor([[15.9125]]),
#   tensor([[16.0028]]),
#   tensor([[15.7420]]),
#   tensor([[15.9737]]),
#   tensor([[16.0468]]),
#   tensor([[15.6398]]),
#   tensor([[15.8339]]),
#   tensor([[16.2914]]),
#   tensor([[16.3527]]),
#   tensor([[16.4601]]),
#   tensor([[16.4506]]),
#   tensor([[17.1237]]),
#   tensor([[16.3878]]),
#   tensor([[16.1273]]),
#   tensor([[16.2989]]),
#   tensor([[16.3519]]),
#   tensor([[16.1950]]),
#   tensor([[17.0710]]),
#   tensor([[16.3184]]),
#   tensor([[16.6069]]),
#   tensor([[16.8482]]),
#   tensor([[16.5198]]),
#   tensor([[16.9213]]),
#   tensor([[16.9144]]),
#   tensor([[16.8482]]),
#   tensor([[17.1152]]),
#   tensor([[16.7534]]),
#   tensor([[16.8288]]),
#   tensor([[16.7198]]),
#   tensor([[16.8934]]),
#   tensor([[16.5563]]),
#   tensor([[16.9287]]),
#   tensor([[17.0882]]),
#   tensor([[17.1102]]),
#   tensor([[17.4024]]),
#   tensor([[17.3137]]),
#   tensor([[17.5692]]),
#   tensor([[17.2406]]),
#   tensor([[17.4011]]),
#   tensor([[17.4128]]),
#   tensor([[17.1499]]),
#   tensor([[17.1912]]),
#   tensor([[17.2979]]),
#   tensor([[17.6894]]),
#   tensor([[17.2038]]),
#   tensor([[17.9403]]),
#   tensor([[17.3337]]),
#   tensor([[17.5693]]),
#   tensor([[17.1818]]),
#   tensor([[17.7264]]),
#   tensor([[17.6278]]),
#   tensor([[17.6838]]),
#   tensor([[18.7936]]),
#   tensor([[18.2511]]),
#   tensor([[18.9479]]),
#   tensor([[17.8309]]),
#   tensor([[17.9504]]),
#   tensor([[18.1278]]),
#   tensor([[17.7873]]),
#   tensor([[19.6154]]),
#   tensor([[19.6720]]),
#   tensor([[18.3263]]),
#   tensor([[19.0348]]),
#   tensor([[18.6018]]),
#   tensor([[18.3102]]),
#   tensor([[19.8063]]),
#   tensor([[19.5492]]),
#   tensor([[20.3541]]),
#   tensor([[20.0172]]),
#   tensor([[21.0283]]),
#   tensor([[20.7947]]),
#   tensor([[20.4806]]),
#   tensor([[20.3802]]),
#   tensor([[19.8768]]),
#   tensor([[18.8998]]),
#   tensor([[21.0985]]),
#   tensor([[21.4679]]),
#   tensor([[21.3892]]),
#   tensor([[21.7840]]),
#   tensor([[21.3611]]),
#   tensor([[20.5253]]),
#   tensor([[21.0155]]),
#   tensor([[21.3617]]),
#   tensor([[22.1604]]),
#   tensor([[22.2845]]),
#   tensor([[22.0071]]),
#   tensor([[22.4864]]),
#   tensor([[22.0362]]),
#   tensor([[22.5539]]),
#   tensor([[21.9892]]),
#   tensor([[22.5727]]),
#   tensor([[22.9954]]),
#   tensor([[23.4710]]),
#   tensor([[10.5724]]),
#   tensor([[10.3898]]),
#   tensor([[11.0524]]),
#   tensor([[10.3410]]),
#   tensor([[11.2171]]),
#   tensor([[11.1682]]),
#   tensor([[10.5539]]),
#   tensor([[11.3699]]),
#   tensor([[10.9636]]),
#   tensor([[11.9269]]),
#   tensor([[12.0680]]),
#   tensor([[11.6691]]),
#   tensor([[12.4955]]),
#   tensor([[12.2226]]),
#   tensor([[11.5700]]),
#   tensor([[12.2012]]),
#   tensor([[11.7594]]),
#   tensor([[11.4482]]),
#   tensor([[11.2532]]),
#   tensor([[11.5920]]),
#   tensor([[12.0542]]),
#   tensor([[12.0152]]),
#   tensor([[11.9733]]),
#   tensor([[12.4385]]),
#   tensor([[12.8347]]),
#   tensor([[12.4416]]),
#   tensor([[12.3467]]),
#   tensor([[12.3288]]),
#   tensor([[12.7053]]),
#   tensor([[12.7125]]),
#   tensor([[12.5426]]),
#   tensor([[12.3119]]),
#   tensor([[12.6598]]),
#   tensor([[12.5547]]),
#   tensor([[12.6039]]),
#   tensor([[13.1504]]),
#   tensor([[13.6360]]),
#   tensor([[13.3136]]),
#   tensor([[13.4078]]),
#   tensor([[13.3935]]),
#   tensor([[13.6037]]),
#   tensor([[13.1211]]),
#   tensor([[12.8715]]),
#   tensor([[13.0260]]),
#   tensor([[13.4978]]),
#   tensor([[13.1419]]),
#   tensor([[13.1739]]),
#   tensor([[13.2429]]),
#   tensor([[13.7254]]),
#   tensor([[13.5162]]),
#   tensor([[13.6834]]),
#   tensor([[13.8575]]),
#   tensor([[13.5017]]),
#   tensor([[13.6996]]),
#   tensor([[14.2348]]),
#   tensor([[13.8230]]),
#   tensor([[14.0348]]),
#   tensor([[13.7277]]),
#   tensor([[13.8962]]),
#   tensor([[14.5731]]),
#   tensor([[14.2711]]),
#   tensor([[15.0164]]),
#   tensor([[14.4724]]),
#   tensor([[14.5457]]),
#   tensor([[14.3563]]),
#   tensor([[14.2859]]),
#   tensor([[14.6726]]),
#   tensor([[13.9464]]),
#   tensor([[14.1995]]),
#   tensor([[14.5845]]),
#   tensor([[14.2065]]),
#   tensor([[14.0749]]),
#   tensor([[14.1949]]),
#   tensor([[14.5091]]),
#   tensor([[15.2655]]),
#   tensor([[15.2742]]),
#   tensor([[14.9758]]),
#   tensor([[14.9613]]),
#   tensor([[14.8544]]),
#   tensor([[14.6078]]),
#   tensor([[14.9801]]),
#   tensor([[14.8475]]),
#   tensor([[14.9730]]),
#   tensor([[14.8625]]),
#   tensor([[14.9375]]),
#   tensor([[15.3560]]),
#   tensor([[15.5865]]),
#   tensor([[15.3948]]),
#   tensor([[15.0680]]),
#   tensor([[15.6087]]),
#   tensor([[15.3440]]),
#   tensor([[15.2426]]),
#   tensor([[15.4498]]),
#   tensor([[15.9636]]),
#   tensor([[15.8759]]),
#   tensor([[16.1035]]),
#   tensor([[16.5990]]),
#   tensor([[12.4571]]),
#   tensor([[13.4888]]),
#   tensor([[14.2799]]),
#   tensor([[14.2367]]),
#   tensor([[14.9192]]),
#   tensor([[15.2131]]),
#   tensor([[16.2241]]),
#   tensor([[16.7846]]),
#   tensor([[17.0773]]),
#   tensor([[17.0803]]),
#   tensor([[17.9914]]),
#   tensor([[18.1304]]),
#   tensor([[19.0113]]),
#   tensor([[19.1396]]),
#   tensor([[15.2732]]),
#   tensor([[15.1839]]),
#   tensor([[15.5303]]),
#   tensor([[15.5036]]),
#   tensor([[15.7772]]),
#   tensor([[15.6583]]),
#   tensor([[15.7455]]),
#   tensor([[15.8360]]),
#   tensor([[16.1407]]),
#   tensor([[16.0792]]),
#   tensor([[16.1071]]),
#   tensor([[15.7918]]),
#   tensor([[16.1678]]),
#   tensor([[16.3723]]),
#   tensor([[16.0749]]),
#   tensor([[16.3759]]),
#   tensor([[16.5072]]),
#   tensor([[16.4318]]),
#   tensor([[16.4037]]),
#   tensor([[16.4730]]),
#   tensor([[16.6358]]),
#   tensor([[16.6308]]),
#   tensor([[16.9694]]),
#   tensor([[16.6145]]),
#   tensor([[16.5556]]),
#   tensor([[16.7574]]),
#   tensor([[16.5532]]),
#   tensor([[17.0220]]),
#   tensor([[17.3435]]),
#   tensor([[17.2402]]),
#   tensor([[17.1256]]),
#   tensor([[17.5642]]),
#   tensor([[17.3121]]),
#   tensor([[16.8744]]),
#   tensor([[17.1569]]),
#   tensor([[17.5041]]),
#   tensor([[17.6948]]),
#   tensor([[17.6601]]),
#   tensor([[17.4837]]),
#   tensor([[18.0374]]),
#   tensor([[17.7503]]),
#   tensor([[17.1833]]),
#   tensor([[17.4307]]),
#   tensor([[18.0966]]),
#   tensor([[18.2880]]),
#   tensor([[18.6616]]),
#   tensor([[17.9277]]),
#   tensor([[18.1094]]),
#   tensor([[17.8387]]),
#   tensor([[18.1737]]),
#   tensor([[18.9766]]),
#   tensor([[18.3489]]),
#   tensor([[18.5556]]),
#   tensor([[19.6728]]),
#   tensor([[19.7299]]),
#   tensor([[19.0777]]),
#   tensor([[19.1077]]),
#   tensor([[19.5927]]),
#   tensor([[18.9118]]),
#   tensor([[20.9738]]),
#   tensor([[19.6217]]),
#   tensor([[20.0139]]),
#   tensor([[20.4331]]),
#   tensor([[19.4397]]),
#   tensor([[19.8082]]),
#   tensor([[20.7942]]),
#   tensor([[20.5236]]),
#   tensor([[20.9474]]),
#   tensor([[21.3186]]),
#   tensor([[20.9432]]),
#   tensor([[20.8536]]),
#   tensor([[21.5106]]),
#   tensor([[21.3924]]),
#   tensor([[21.6153]]),
#   tensor([[21.8122]]),
#   tensor([[21.9412]]),
#   tensor([[22.5783]]),
#   tensor([[22.0038]]),
#   tensor([[22.6027]]),
#   tensor([[22.6024]]),
#   tensor([[22.6162]]),
#   tensor([[22.7929]]),
#   tensor([[22.3543]]),
#   tensor([[23.5703]]),
#   tensor([[23.4874]]),
#   tensor([[23.3409]]),
#   tensor([[22.7857]]),
#   tensor([[22.3237]]),
#   tensor([[23.0433]]),
#   tensor([[22.9114]]),
#   tensor([[24.4692]]),
#   tensor([[23.6411]]),
#   tensor([[23.5171]]),
#   tensor([[23.9313]]),
#   tensor([[25.9668]]),
#   tensor([[24.9693]]),
#   tensor([[25.7555]]),
#   tensor([[26.5387]]),
#   tensor([[24.4056]]),
#   tensor([[24.9604]]),
#   ...],
#  [11.0,
#   11.0,
#   11.0,
#   11.0,
#   11.0,
#   11.0,
#   11.0,
#   11.0,
#   11.0,
#   11.0,
#   11.0,
#   11.0,
#   11.0,
#   12.0,
#   12.0,
#   12.0,
#   12.0,
#   12.0,
#   12.0,
#   12.0,
#   12.0,
#   12.0,
#   12.0,
#   12.0,
#   12.0,
#   12.0,
#   12.0,
#   12.0,
#   12.0,
#   12.0,
#   12.0,
#   12.0,
#   13.0,
#   13.0,
#   13.0,
#   13.0,
#   13.0,
#   13.0,
#   13.0,
#   13.0,
#   13.0,
#   13.0,
#   13.0,
#   13.0,
#   13.0,
#   13.0,
#   13.0,
#   13.0,
#   13.0,
#   13.0,
#   13.0,
#   13.0,
#   13.0,
#   13.0,
#   14.0,
#   14.0,
#   14.0,
#   14.0,
#   14.0,
#   14.0,
#   14.0,
#   14.0,
#   14.0,
#   14.0,
#   14.0,
#   14.0,
#   14.0,
#   14.0,
#   14.0,
#   14.0,
#   14.0,
#   14.0,
#   14.0,
#   14.0,
#   14.0,
#   14.0,
#   15.0,
#   15.0,
#   15.0,
#   15.0,
#   15.0,
#   15.0,
#   15.0,
#   15.0,
#   15.0,
#   15.0,
#   15.0,
#   15.0,
#   15.0,
#   15.0,
#   15.0,
#   15.0,
#   15.0,
#   15.0,
#   15.0,
#   15.0,
#   15.0,
#   15.0,
#   16.0,
#   16.0,
#   16.0,
#   16.0,
#   16.0,
#   16.0,
#   16.0,
#   16.0,
#   16.0,
#   16.0,
#   16.0,
#   16.0,
#   16.0,
#   16.0,
#   16.0,
#   16.0,
#   16.0,
#   16.0,
#   16.0,
#   17.0,
#   17.0,
#   17.0,
#   17.0,
#   17.0,
#   17.0,
#   17.0,
#   17.0,
#   17.0,
#   17.0,
#   17.0,
#   17.0,
#   17.0,
#   17.0,
#   17.0,
#   17.0,
#   17.0,
#   17.0,
#   11.0,
#   12.0,
#   12.0,
#   12.0,
#   13.0,
#   13.0,
#   14.0,
#   15.0,
#   15.0,
#   16.0,
#   17.0,
#   18.0,
#   19.0,
#   21.0,
#   22.0,
#   23.0,
#   24.0,
#   24.0,
#   25.0,
#   26.0,
#   26.0,
#   27.0,
#   28.0,
#   29.0,
#   11.0,
#   11.0,
#   11.0,
#   11.0,
#   11.0,
#   11.0,
#   11.0,
#   11.0,
#   11.0,
#   11.0,
#   11.0,
#   11.0,
#   12.0,
#   12.0,
#   12.0,
#   12.0,
#   12.0,
#   12.0,
#   12.0,
#   12.0,
#   12.0,
#   12.0,
#   12.0,
#   12.0,
#   12.0,
#   12.0,
#   12.0,
#   12.0,
#   12.0,
#   12.0,
#   12.0,
#   12.0,
#   12.0,
#   12.0,
#   12.0,
#   12.0,
#   13.0,
#   13.0,
#   13.0,
#   13.0,
#   13.0,
#   13.0,
#   13.0,
#   13.0,
#   13.0,
#   13.0,
#   13.0,
#   13.0,
#   13.0,
#   13.0,
#   13.0,
#   13.0,
#   13.0,
#   13.0,
#   13.0,
#   13.0,
#   14.0,
#   14.0,
#   14.0,
#   14.0,
#   14.0,
#   14.0,
#   14.0,
#   14.0,
#   14.0,
#   14.0,
#   14.0,
#   14.0,
#   14.0,
#   14.0,
#   14.0,
#   14.0,
#   14.0,
#   14.0,
#   14.0,
#   14.0,
#   14.0,
#   15.0,
#   15.0,
#   15.0,
#   15.0,
#   15.0,
#   15.0,
#   15.0,
#   15.0,
#   15.0,
#   15.0,
#   15.0,
#   15.0,
#   15.0,
#   15.0,
#   15.0,
#   15.0,
#   15.0,
#   15.0,
#   15.0,
#   15.0,
#   15.0,
#   15.0,
#   16.0,
#   16.0,
#   16.0,
#   16.0,
#   16.0,
#   16.0,
#   16.0,
#   16.0,
#   16.0,
#   16.0,
#   16.0,
#   16.0,
#   16.0,
#   16.0,
#   16.0,
#   16.0,
#   16.0,
#   16.0,
#   16.0,
#   17.0,
#   17.0,
#   17.0,
#   17.0,
#   17.0,
#   17.0,
#   17.0,
#   17.0,
#   17.0,
#   17.0,
#   17.0,
#   17.0,
#   17.0,
#   17.0,
#   17.0,
#   17.0,
#   17.0,
#   17.0,
#   17.0,
#   17.0,
#   17.0,
#   17.0,
#   17.0,
#   17.0,
#   17.0,
#   17.0,
#   18.0,
#   18.0,
#   18.0,
#   18.0,
#   18.0,
#   18.0,
#   18.0,
#   18.0,
#   18.0,
#   18.0,
#   18.0,
#   18.0,
#   18.0,
#   18.0,
#   18.0,
#   18.0,
#   18.0,
#   18.0,
#   18.0,
#   19.0,
#   19.0,
#   19.0,
#   19.0,
#   19.0,
#   19.0,
#   19.0,
#   19.0,
#   19.0,
#   19.0,
#   20.0,
#   20.0,
#   20.0,
#   20.0,
#   12.0,
#   13.0,
#   14.0,
#   16.0,
#   16.0,
#   18.0,
#   18.0,
#   18.0,
#   19.0,
#   21.0,
#   22.0,
#   22.0,
#   26.0,
#   26.0,
#   27.0,
#   28.0,
#   28.0,
#   29.0,
#   16.0,
#   17.0,
#   17.0,
#   17.0,
#   17.0,
#   18.0,
#   18.0,
#   18.0,
#   18.0,
#   18.0,
#   18.0,
#   18.0,
#   18.0,
#   18.0,
#   18.0,
#   18.0,
#   18.0,
#   19.0,
#   19.0,
#   19.0,
#   19.0,
#   19.0,
#   19.0,
#   19.0,
#   19.0,
#   19.0,
#   19.0,
#   19.0,
#   19.0,
#   19.0,
#   19.0,
#   19.0,
#   19.0,
#   20.0,
#   20.0,
#   20.0,
#   20.0,
#   20.0,
#   20.0,
#   20.0,
#   20.0,
#   20.0,
#   20.0,
#   20.0,
#   20.0,
#   20.0,
#   20.0,
#   20.0,
#   20.0,
#   20.0,
#   20.0,
#   20.0,
#   20.0,
#   20.0,
#   20.0,
#   21.0,
#   21.0,
#   21.0,
#   21.0,
#   21.0,
#   21.0,
#   21.0,
#   21.0,
#   21.0,
#   21.0,
#   21.0,
#   21.0,
#   21.0,
#   21.0,
#   21.0,
#   21.0,
#   21.0,
#   21.0,
#   21.0,
#   21.0,
#   21.0,
#   21.0,
#   21.0,
#   21.0,
#   21.0,
#   21.0,
#   22.0,
#   22.0,
#   22.0,
#   22.0,
#   22.0,
#   22.0,
#   22.0,
#   22.0,
#   22.0,
#   22.0,
#   22.0,
#   22.0,
#   22.0,
#   22.0,
#   22.0,
#   22.0,
#   22.0,
#   22.0,
#   22.0,
#   22.0,
#   22.0,
#   23.0,
#   23.0,
#   23.0,
#   23.0,
#   23.0,
#   23.0,
#   23.0,
#   23.0,
#   23.0,
#   23.0,
#   23.0,
#   23.0,
#   23.0,
#   23.0,
#   23.0,
#   23.0,
#   24.0,
#   24.0,
#   24.0,
#   24.0,
#   24.0,
#   24.0,
#   24.0,
#   24.0,
#   24.0,
#   24.0,
#   24.0,
#   24.0,
#   24.0,
#   24.0,
#   24.0,
#   24.0,
#   25.0,
#   25.0,
#   25.0,
#   25.0,
#   25.0,
#   25.0,
#   25.0,
#   25.0,
#   25.0,
#   25.0,
#   25.0,
#   25.0,
#   25.0,
#   25.0,
#   25.0,
#   25.0,
#   26.0,
#   26.0,
#   26.0,
#   26.0,
#   26.0,
#   26.0,
#   26.0,
#   26.0,
#   26.0,
#   26.0,
#   26.0,
#   26.0,
#   26.0,
#   26.0,
#   26.0,
#   27.0,
#   27.0,
#   27.0,
#   27.0,
#   27.0,
#   27.0,
#   27.0,
#   27.0,
#   27.0,
#   27.0,
#   28.0,
#   28.0,
#   28.0,
#   11.0,
#   11.0,
#   11.0,
#   11.0,
#   11.0,
#   11.0,
#   11.0,
#   11.0,
#   11.0,
#   11.0,
#   11.0,
#   11.0,
#   12.0,
#   12.0,
#   12.0,
#   12.0,
#   12.0,
#   12.0,
#   12.0,
#   12.0,
#   12.0,
#   12.0,
#   12.0,
#   12.0,
#   12.0,
#   12.0,
#   12.0,
#   12.0,
#   12.0,
#   12.0,
#   13.0,
#   13.0,
#   13.0,
#   13.0,
#   13.0,
#   13.0,
#   13.0,
#   13.0,
#   13.0,
#   13.0,
#   13.0,
#   13.0,
#   13.0,
#   13.0,
#   13.0,
#   13.0,
#   13.0,
#   13.0,
#   13.0,
#   13.0,
#   14.0,
#   14.0,
#   14.0,
#   14.0,
#   14.0,
#   14.0,
#   14.0,
#   14.0,
#   14.0,
#   14.0,
#   14.0,
#   14.0,
#   14.0,
#   14.0,
#   14.0,
#   14.0,
#   15.0,
#   15.0,
#   15.0,
#   15.0,
#   15.0,
#   15.0,
#   15.0,
#   15.0,
#   15.0,
#   15.0,
#   15.0,
#   15.0,
#   15.0,
#   15.0,
#   15.0,
#   15.0,
#   15.0,
#   15.0,
#   16.0,
#   16.0,
#   16.0,
#   16.0,
#   16.0,
#   16.0,
#   16.0,
#   16.0,
#   16.0,
#   16.0,
#   16.0,
#   16.0,
#   16.0,
#   16.0,
#   16.0,
#   16.0,
#   16.0,
#   16.0,
#   17.0,
#   17.0,
#   17.0,
#   17.0,
#   17.0,
#   17.0,
#   17.0,
#   17.0,
#   17.0,
#   17.0,
#   17.0,
#   17.0,
#   17.0,
#   17.0,
#   17.0,
#   18.0,
#   18.0,
#   18.0,
#   18.0,
#   18.0,
#   18.0,
#   18.0,
#   18.0,
#   18.0,
#   18.0,
#   18.0,
#   19.0,
#   19.0,
#   19.0,
#   19.0,
#   19.0,
#   20.0,
#   20.0,
#   12.0,
#   13.0,
#   13.0,
#   16.0,
#   16.0,
#   17.0,
#   18.0,
#   19.0,
#   20.0,
#   21.0,
#   22.0,
#   22.0,
#   25.0,
#   26.0,
#   27.0,
#   28.0,
#   28.0,
#   16.0,
#   17.0,
#   17.0,
#   18.0,
#   18.0,
#   18.0,
#   18.0,
#   18.0,
#   18.0,
#   18.0,
#   19.0,
#   19.0,
#   19.0,
#   19.0,
#   19.0,
#   19.0,
#   19.0,
#   19.0,
#   19.0,
#   20.0,
#   20.0,
#   20.0,
#   20.0,
#   20.0,
#   20.0,
#   20.0,
#   20.0,
#   20.0,
#   20.0,
#   21.0,
#   21.0,
#   21.0,
#   21.0,
#   21.0,
#   21.0,
#   21.0,
#   21.0,
#   21.0,
#   21.0,
#   21.0,
#   21.0,
#   21.0,
#   21.0,
#   22.0,
#   22.0,
#   22.0,
#   22.0,
#   22.0,
#   22.0,
#   22.0,
#   22.0,
#   22.0,
#   22.0,
#   22.0,
#   22.0,
#   23.0,
#   23.0,
#   23.0,
#   23.0,
#   23.0,
#   23.0,
#   23.0,
#   23.0,
#   24.0,
#   24.0,
#   24.0,
#   24.0,
#   24.0,
#   24.0,
#   24.0,
#   24.0,
#   25.0,
#   25.0,
#   25.0,
#   25.0,
#   25.0,
#   25.0,
#   25.0,
#   25.0,
#   26.0,
#   26.0,
#   26.0,
#   26.0,
#   26.0,
#   26.0,
#   26.0,
#   26.0,
#   27.0,
#   27.0,
#   27.0,
#   27.0,
#   27.0,
#   27.0,
#   27.0,
#   27.0,
#   28.0,
#   28.0,
#   28.0,
#   28.0,
#   28.0,
#   28.0,
#   28.0,
#   29.0,
#   29.0,
#   29.0,
#   11.0,
#   11.0,
#   11.0,
#   11.0,
#   11.0,
#   11.0,
#   11.0,
#   11.0,
#   11.0,
#   12.0,
#   12.0,
#   12.0,
#   13.0,
#   12.0,
#   12.0,
#   12.0,
#   12.0,
#   12.0,
#   12.0,
#   12.0,
#   12.0,
#   12.0,
#   12.0,
#   13.0,
#   13.0,
#   13.0,
#   13.0,
#   13.0,
#   13.0,
#   13.0,
#   13.0,
#   13.0,
#   13.0,
#   13.0,
#   13.0,
#   14.0,
#   14.0,
#   14.0,
#   14.0,
#   14.0,
#   14.0,
#   14.0,
#   14.0,
#   14.0,
#   14.0,
#   14.0,
#   14.0,
#   14.0,
#   15.0,
#   15.0,
#   15.0,
#   15.0,
#   15.0,
#   15.0,
#   15.0,
#   15.0,
#   15.0,
#   15.0,
#   15.0,
#   15.0,
#   15.0,
#   16.0,
#   16.0,
#   16.0,
#   16.0,
#   16.0,
#   16.0,
#   16.0,
#   16.0,
#   16.0,
#   16.0,
#   16.0,
#   16.0,
#   16.0,
#   17.0,
#   17.0,
#   17.0,
#   17.0,
#   17.0,
#   17.0,
#   17.0,
#   17.0,
#   17.0,
#   17.0,
#   17.0,
#   18.0,
#   18.0,
#   18.0,
#   18.0,
#   18.0,
#   18.0,
#   18.0,
#   18.0,
#   19.0,
#   19.0,
#   19.0,
#   20.0,
#   12.0,
#   14.0,
#   15.0,
#   15.0,
#   16.0,
#   17.0,
#   18.0,
#   19.0,
#   20.0,
#   20.0,
#   22.0,
#   23.0,
#   24.0,
#   25.0,
#   17.0,
#   17.0,
#   18.0,
#   18.0,
#   18.0,
#   18.0,
#   18.0,
#   19.0,
#   19.0,
#   19.0,
#   19.0,
#   19.0,
#   20.0,
#   20.0,
#   20.0,
#   20.0,
#   20.0,
#   20.0,
#   20.0,
#   21.0,
#   21.0,
#   21.0,
#   21.0,
#   21.0,
#   21.0,
#   21.0,
#   21.0,
#   22.0,
#   22.0,
#   22.0,
#   22.0,
#   22.0,
#   22.0,
#   22.0,
#   22.0,
#   23.0,
#   23.0,
#   23.0,
#   23.0,
#   23.0,
#   23.0,
#   23.0,
#   23.0,
#   24.0,
#   24.0,
#   24.0,
#   24.0,
#   24.0,
#   24.0,
#   24.0,
#   24.0,
#   25.0,
#   25.0,
#   25.0,
#   25.0,
#   25.0,
#   25.0,
#   25.0,
#   25.0,
#   26.0,
#   26.0,
#   26.0,
#   26.0,
#   26.0,
#   26.0,
#   26.0,
#   26.0,
#   27.0,
#   27.0,
#   27.0,
#   27.0,
#   27.0,
#   27.0,
#   27.0,
#   27.0,
#   28.0,
#   28.0,
#   28.0,
#   28.0,
#   28.0,
#   28.0,
#   28.0,
#   28.0,
#   29.0,
#   29.0,
#   29.0,
#   29.0,
#   29.0,
#   29.0,
#   29.0,
#   30.0,
#   30.0,
#   30.0,
#   31.0,
#   33.0,
#   32.0,
#   33.0,
#   34.0,
#   31.0,
#   32.0,
#   ...])

# %%
bokeh_display(meters, pred_meters, df)
# Out:
#   <div id="d7ce10d5-a353-4d2f-b9e0-dd451bcfb713" data-root-id="p7494" style="display: contents;"></div>

# %%
model.link
# Out:
# LogisticCumulativeLink()

# %%
from skorch import NeuralNet

from spacecutter.callbacks import AscensionCallback
from spacecutter.losses import CumulativeLinkLoss
from skorch.callbacks import Callback

class Printer(Callback):
    def on_batch_begin(self, net, *args, **kwargs) -> None:
        print('hi')
    def on_batch_end(self, net, *args, **kwargs) -> None:
        print('bye')

predictor = TorchPredictor()
predictor.init_weights()
skorch_model = NeuralNet(
    module=OrdinalLogisticModel,
    module__predictor=predictor,
    module__num_classes=43,
    criterion=CumulativeLinkLoss,
    train_split=None,
    callbacks=[
        ('ascension', AscensionCallback()),
        #('printer', Printer()),
    ],
    batch_size=64
    #device='cuda'
)

pre_pad = [torch.tensor(np.insert(i, 0, len(i), axis=0)) for i in all_data.data[:500]]
padded = torch.nn.utils.rnn.pad_sequence(
    pre_pad, batch_first=True, padding_value=0.0
)
skorch_model.fit(padded, torch.as_tensor(all_data.meters[:500], dtype=torch.int64).unsqueeze(1) - 1)
# Out:
# .......
# <class 'skorch.net.NeuralNet'>[initialized](
#   module_=OrdinalLogisticModel(
#     (predictor): TorchPredictor()
#     (link): LogisticCumulativeLink()
#   ),
# )
